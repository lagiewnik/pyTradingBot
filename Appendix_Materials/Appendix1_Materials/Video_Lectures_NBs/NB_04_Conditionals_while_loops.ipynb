# %% [markdown]
# # Appendix 1: Python Crash Course

# %% [markdown]
# ## Part 4:  Conditional Statements and while loops

# %% [markdown]
# ### Conditional Statements (if, elif, else)

# %%
cf = [-200, 20, 50, 70, 100, 50]

# %%
cf[1] > 0
# Out:
# True

# %%
if cf[1] > 0:
    print("positive")
# Out:
# positive

# %%
if cf[0] > 0:
    print("positive")
else:
    print("negative")
# Out:
# negative

# %%
for i in cf:
    if i > 0:
        print("positive")
    else:
        print("negative")
# Out:
# negative
# positive
# positive
# positive
# positive
# positive

# %%
for i in cf:
    if i > 0:
        print("{} is a positive Cashflow".format(i))
    else: 
        print("{} is a negative Cashflow".format(i))
# Out:
# -200 is a negative Cashflow
# 20 is a positive Cashflow
# 50 is a positive Cashflow
# 70 is a positive Cashflow
# 100 is a positive Cashflow
# 50 is a positive Cashflow

# %%
cf.insert(3, 0)

# %%
cf
# Out:
# [-200, 20, 50, 0, 70, 100, 50]

# %%
for i in cf:
    if i > 0:
        print("{} is a positive Cashflow".format(i))
    elif i < 0: 
        print("{} is a negative Cashflow".format(i))
    else:
        print("No Cashflow")
# Out:
# -200 is a negative Cashflow
# 20 is a positive Cashflow
# 50 is a positive Cashflow
# No Cashflow
# 70 is a positive Cashflow
# 100 is a positive Cashflow
# 50 is a positive Cashflow

# %%
for i in cf:
    if i > 0:
        print("{} is a positive Cashflow".format(i))
    elif i < 0: 
        print("{} is a negative Cashflow".format(i))
    elif i == 0:
        print("No Cashflow")
# Out:
# -200 is a negative Cashflow
# 20 is a positive Cashflow
# 50 is a positive Cashflow
# No Cashflow
# 70 is a positive Cashflow
# 100 is a positive Cashflow
# 50 is a positive Cashflow

# %%
cf_pos =[]
cf_neg =[]

for i in cf:
    if i > 0:
        cf_pos.append(i)
    else:
        cf_neg.append(i)
print(cf_pos, cf_neg)
# Out:
# [20, 50, 70, 100, 50] [-200, 0]

# %%
cf_pos =[]
cf_neg =[]

for i in cf:
    if i > 0:
        cf_pos.append(i)
    elif i < 0:
        cf_neg.append(i)
print(cf_pos, cf_neg)
# Out:
# [20, 50, 70, 100, 50] [-200]

# %% [markdown]
# ### Keywords pass, continue and break

# %%
cf = [-200, 20, 50, 70, 0, 100, 50]

# %%
cf_pos =[]
cf_neg =[]

for i in cf:
    if i > 0:
        cf_pos.append(i)
    elif i < 0:
        cf_neg.append(i)
    else:
        pass
print(cf_pos, cf_neg)
# Out:
# [20, 50, 70, 100, 50] [-200]

# %%
cf_pos =[]
cf_neg =[]


for i in cf:
    if i == 0:
        pass
    elif i > 0:
        cf_pos.append(i)
    else:
        cf_neg.append(i)
print(cf_pos, cf_neg)
# Out:
# [20, 50, 70, 100, 50] [-200]

# %%
cf_pos =[]
cf_neg =[]


for i in cf:
    if i == 0:
        continue
        print("This is 0")
    elif i > 0:
        cf_pos.append(i)
    else:
        cf_neg.append(i)
print(cf_pos, cf_neg)
# Out:
# [20, 50, 70, 100, 50] [-200]

# %%
cf = [-200, -100, -50, -10, 20, 50, 100, 300, 500, 1000]

# %%
n = 0
for i in cf:
    if i > 0:
        print("Year {} is the first profitable year!".format(n))
        break
    n += 1
# Out:
# Year 1 is the first profitable year!

# %%
for i in range(len(cf)):
    if cf[i] > 0:
        print("Year {} is the first profitable year!".format(i))
        break
# Out:
# Year 1 is the first profitable year!

# %% [markdown]
# ### Calculate a Project´s Payback Period

# %% [markdown]
# The XYZ Company evaluates to buy an additional machine that will increase profits/cashflows by
# - 20 USD in t1,
# - 50 USD in t2,
# - 70 USD in t3,
# - 100 USD in t4,
# - 50 USD in t5. (each cf at period´s end)
#
# The machine costs 200 USD (Investment in to).
#
# - Calulate the __Payback Period__ (Time until initial Investment is recovered).

# %%
cf = [-200, 20, 50, 70, 100, 50]

# %%
cum_cf = 0
for i in range(len(cf)):
    cum_cf += cf[i]
    #print(cum_cf)
    if cum_cf > 0:
        print("The Project´s Payback Period is {} Years!".format(i) )
        break
# Out:
# The Project´s Payback Period is 4 Years!

# %%
cf = [-200, -150, 50, 70, 100, 50]

# %%
cum_cf = 0
for i in range(len(cf)):
    cum_cf += cf[i]
    #print(cum_cf)
    if cum_cf > 0:
        print("The Project´s Payback Period is {} Years!".format(i) )
        break
    elif cum_cf <= 0 and i == len(cf)-1:
        print("The Project does not break even!")
# Out:
# The Project does not break even!

# %% [markdown]
# ### While Loops

# %%
a = 10
b = 5

# %%
diff = 0

# %%
if a > b:
    print((a, b), "a is still greater than b!")
    a -= 1
    diff += 1
else:
    print("The difference is {}!".format(diff))
# Out:
# (10, 5) a is still greater than b!

# %%
print(a,b)
# Out:
# 9 5

# %%
a = 10
b = 5
diff = 0

for i in range(4):
    if a > b:
        print((a, b), "a is still greater than b!")
        a -= 1
        diff += 1
    else:
        print("The difference is {}!".format(diff))
        break
# Out:
# (10, 5) a is still greater than b!
# (9, 5) a is still greater than b!
# (8, 5) a is still greater than b!
# (7, 5) a is still greater than b!

# %%
a = 10
b = 5
diff = 0
while a > b:
    print((a, b), "a is still greater than b!")
    a -= 1
    diff += 1
print("The difference is {}!".format(diff))
# Out:
# (10, 5) a is still greater than b!
# (9, 5) a is still greater than b!
# (8, 5) a is still greater than b!
# (7, 5) a is still greater than b!
# (6, 5) a is still greater than b!
# The difference is 5!

# %%
a
# Out:
# 5

# %%
# this gives an infinite while loop!!! You have to interrupt the Kernel.

a = 10
b = 5
diff = 0
while a > b:
    print((a, b), "a is still greater than b!")
    a += 1
    diff += 1
print("The difference is {}!".format(diff))
# Out:
# (10, 5) a is still greater than b!
# (11, 5) a is still greater than b!
# (12, 5) a is still greater than b!
# (13, 5) a is still greater than b!
# (14, 5) a is still greater than b!
# (15, 5) a is still greater than b!
# (16, 5) a is still greater than b!
# (17, 5) a is still greater than b!
# (18, 5) a is still greater than b!
# (19, 5) a is still greater than b!
# (20, 5) a is still greater than b!
# (21, 5) a is still greater than b!
# (22, 5) a is still greater than b!
# (23, 5) a is still greater than b!
# (24, 5) a is still greater than b!
# (25, 5) a is still greater than b!
# (26, 5) a is still greater than b!
# (27, 5) a is still greater than b!
# (28, 5) a is still greater than b!
# (29, 5) a is still greater than b!
# (30, 5) a is still greater than b!
# (31, 5) a is still greater than b!
# (32, 5) a is still greater than b!
# (33, 5) a is still greater than b!
# (34, 5) a is still greater than b!
# (35, 5) a is still greater than b!
# (36, 5) a is still greater than b!
# (37, 5) a is still greater than b!
# (38, 5) a is still greater than b!
# (39, 5) a is still greater than b!
# (40, 5) a is still greater than b!
# (41, 5) a is still greater than b!
# (42, 5) a is still greater than b!
# (43, 5) a is still greater than b!
# (44, 5) a is still greater than b!
# (45, 5) a is still greater than b!
# (46, 5) a is still greater than b!
# (47, 5) a is still greater than b!
# (48, 5) a is still greater than b!
# (49, 5) a is still greater than b!
# (50, 5) a is still greater than b!
# (51, 5) a is still greater than b!
# (52, 5) a is still greater than b!
# (53, 5) a is still greater than b!
# (54, 5) a is still greater than b!
# (55, 5) a is still greater than b!
# (56, 5) a is still greater than b!
# (57, 5) a is still greater than b!
# (58, 5) a is still greater than b!
# (59, 5) a is still greater than b!
# (60, 5) a is still greater than b!
# (61, 5) a is still greater than b!
# (62, 5) a is still greater than b!
# (63, 5) a is still greater than b!
# (64, 5) a is still greater than b!
# (65, 5) a is still greater than b!
# (66, 5) a is still greater than b!
# (67, 5) a is still greater than b!
# (68, 5) a is still greater than b!
# (69, 5) a is still greater than b!
# (70, 5) a is still greater than b!
# (71, 5) a is still greater than b!
# (72, 5) a is still greater than b!
# (73, 5) a is still greater than b!
# (74, 5) a is still greater than b!
# (75, 5) a is still greater than b!
# (76, 5) a is still greater than b!
# (77, 5) a is still greater than b!
# (78, 5) a is still greater than b!
# (79, 5) a is still greater than b!
# (80, 5) a is still greater than b!
# (81, 5) a is still greater than b!
# (82, 5) a is still greater than b!
# (83, 5) a is still greater than b!
# (84, 5) a is still greater than b!
# (85, 5) a is still greater than b!
# (86, 5) a is still greater than b!
# (87, 5) a is still greater than b!
# (88, 5) a is still greater than b!
# (89, 5) a is still greater than b!
# (90, 5) a is still greater than b!
# (91, 5) a is still greater than b!
# (92, 5) a is still greater than b!
# (93, 5) a is still greater than b!
# (94, 5) a is still greater than b!
# (95, 5) a is still greater than b!
# (96, 5) a is still greater than b!
# (97, 5) a is still greater than b!
# (98, 5) a is still greater than b!
# (99, 5) a is still greater than b!
# (100, 5) a is still greater than b!
# (101, 5) a is still greater than b!
# (102, 5) a is still greater than b!
# (103, 5) a is still greater than b!
# (104, 5) a is still greater than b!
# (105, 5) a is still greater than b!
# (106, 5) a is still greater than b!
# (107, 5) a is still greater than b!
# (108, 5) a is still greater than b!
# (109, 5) a is still greater than b!
# (110, 5) a is still greater than b!
# (111, 5) a is still greater than b!
# (112, 5) a is still greater than b!
# (113, 5) a is still greater than b!
# (114, 5) a is still greater than b!
# (115, 5) a is still greater than b!
# (116, 5) a is still greater than b!
# (117, 5) a is still greater than b!
# (118, 5) a is still greater than b!
# (119, 5) a is still greater than b!
# (120, 5) a is still greater than b!
# (121, 5) a is still greater than b!
# (122, 5) a is still greater than b!
# (123, 5) a is still greater than b!
# (124, 5) a is still greater than b!
# (125, 5) a is still greater than b!
# (126, 5) a is still greater than b!
# (127, 5) a is still greater than b!
# (128, 5) a is still greater than b!
# (129, 5) a is still greater than b!
# (130, 5) a is still greater than b!
# (131, 5) a is still greater than b!
# (132, 5) a is still greater than b!
# (133, 5) a is still greater than b!
# (134, 5) a is still greater than b!
# (135, 5) a is still greater than b!
# (136, 5) a is still greater than b!
# (137, 5) a is still greater than b!
# (138, 5) a is still greater than b!
# (139, 5) a is still greater than b!
# (140, 5) a is still greater than b!
# (141, 5) a is still greater than b!
# (142, 5) a is still greater than b!
# (143, 5) a is still greater than b!
# (144, 5) a is still greater than b!
# (145, 5) a is still greater than b!
# (146, 5) a is still greater than b!
# (147, 5) a is still greater than b!
# (148, 5) a is still greater than b!
# (149, 5) a is still greater than b!
# (150, 5) a is still greater than b!
# (151, 5) a is still greater than b!
# (152, 5) a is still greater than b!
# (153, 5) a is still greater than b!
# (154, 5) a is still greater than b!
# (155, 5) a is still greater than b!
# (156, 5) a is still greater than b!
# (157, 5) a is still greater than b!
# (158, 5) a is still greater than b!
# (159, 5) a is still greater than b!
# (160, 5) a is still greater than b!
# (161, 5) a is still greater than b!
# (162, 5) a is still greater than b!
# (163, 5) a is still greater than b!
# (164, 5) a is still greater than b!
# (165, 5) a is still greater than b!
# (166, 5) a is still greater than b!
# (167, 5) a is still greater than b!
# (168, 5) a is still greater than b!
# (169, 5) a is still greater than b!
# (170, 5) a is still greater than b!
# (171, 5) a is still greater than b!
# (172, 5) a is still greater than b!
# (173, 5) a is still greater than b!
# (174, 5) a is still greater than b!
# (175, 5) a is still greater than b!
# (176, 5) a is still greater than b!
# (177, 5) a is still greater than b!
# (178, 5) a is still greater than b!
# (179, 5) a is still greater than b!
# (180, 5) a is still greater than b!
# (181, 5) a is still greater than b!
# (182, 5) a is still greater than b!
# (183, 5) a is still greater than b!
# (184, 5) a is still greater than b!
# (185, 5) a is still greater than b!
# (186, 5) a is still greater than b!
# (187, 5) a is still greater than b!
# (188, 5) a is still greater than b!
# (189, 5) a is still greater than b!
# (190, 5) a is still greater than b!
# (191, 5) a is still greater than b!
# (192, 5) a is still greater than b!
# (193, 5) a is still greater than b!
# (194, 5) a is still greater than b!
# (195, 5) a is still greater than b!
# (196, 5) a is still greater than b!
# (197, 5) a is still greater than b!
# (198, 5) a is still greater than b!
# (199, 5) a is still greater than b!
# (200, 5) a is still greater than b!
# (201, 5) a is still greater than b!
# (202, 5) a is still greater than b!
# (203, 5) a is still greater than b!
# (204, 5) a is still greater than b!
# (205, 5) a is still greater than b!
# (206, 5) a is still greater than b!
# (207, 5) a is still greater than b!
# (208, 5) a is still greater than b!
# (209, 5) a is still greater than b!
# (210, 5) a is still greater than b!
# (211, 5) a is still greater than b!
# (212, 5) a is still greater than b!
# (213, 5) a is still greater than b!
# (214, 5) a is still greater than b!
# (215, 5) a is still greater than b!
# (216, 5) a is still greater than b!
# (217, 5) a is still greater than b!
# (218, 5) a is still greater than b!
# (219, 5) a is still greater than b!
# (220, 5) a is still greater than b!
# (221, 5) a is still greater than b!
# (222, 5) a is still greater than b!
# (223, 5) a is still greater than b!
# (224, 5) a is still greater than b!
# (225, 5) a is still greater than b!
# (226, 5) a is still greater than b!
# (227, 5) a is still greater than b!
# (228, 5) a is still greater than b!
# (229, 5) a is still greater than b!
# (230, 5) a is still greater than b!
# (231, 5) a is still greater than b!
# (232, 5) a is still greater than b!
# (233, 5) a is still greater than b!
# (234, 5) a is still greater than b!
# (235, 5) a is still greater than b!
# (236, 5) a is still greater than b!
# (237, 5) a is still greater than b!
# (238, 5) a is still greater than b!
# (239, 5) a is still greater than b!
# (240, 5) a is still greater than b!
# (241, 5) a is still greater than b!
# (242, 5) a is still greater than b!
# (243, 5) a is still greater than b!
# (244, 5) a is still greater than b!
# (245, 5) a is still greater than b!
# (246, 5) a is still greater than b!
# (247, 5) a is still greater than b!
# (248, 5) a is still greater than b!
# (249, 5) a is still greater than b!
# (250, 5) a is still greater than b!
# (251, 5) a is still greater than b!
# (252, 5) a is still greater than b!
# (253, 5) a is still greater than b!
# (254, 5) a is still greater than b!
# (255, 5) a is still greater than b!
# (256, 5) a is still greater than b!
# (257, 5) a is still greater than b!
# (258, 5) a is still greater than b!
# (259, 5) a is still greater than b!
# (260, 5) a is still greater than b!
# (261, 5) a is still greater than b!
# (262, 5) a is still greater than b!
# (263, 5) a is still greater than b!
# (264, 5) a is still greater than b!
# (265, 5) a is still greater than b!
# (266, 5) a is still greater than b!
# (267, 5) a is still greater than b!
# (268, 5) a is still greater than b!
# (269, 5) a is still greater than b!
# (270, 5) a is still greater than b!
# (271, 5) a is still greater than b!
# (272, 5) a is still greater than b!
# (273, 5) a is still greater than b!
# (274, 5) a is still greater than b!
# (275, 5) a is still greater than b!
# (276, 5) a is still greater than b!
# (277, 5) a is still greater than b!
# (278, 5) a is still greater than b!
# (279, 5) a is still greater than b!
# (280, 5) a is still greater than b!
# (281, 5) a is still greater than b!
# (282, 5) a is still greater than b!
# (283, 5) a is still greater than b!
# (284, 5) a is still greater than b!
# (285, 5) a is still greater than b!
# (286, 5) a is still greater than b!
# (287, 5) a is still greater than b!
# (288, 5) a is still greater than b!
# (289, 5) a is still greater than b!
# (290, 5) a is still greater than b!
# (291, 5) a is still greater than b!
# (292, 5) a is still greater than b!
# (293, 5) a is still greater than b!
# (294, 5) a is still greater than b!
# (295, 5) a is still greater than b!
# (296, 5) a is still greater than b!
# (297, 5) a is still greater than b!
# (298, 5) a is still greater than b!
# (299, 5) a is still greater than b!
# (300, 5) a is still greater than b!
# (301, 5) a is still greater than b!
# (302, 5) a is still greater than b!
# (303, 5) a is still greater than b!
# (304, 5) a is still greater than b!
# (305, 5) a is still greater than b!
# (306, 5) a is still greater than b!
# (307, 5) a is still greater than b!
# (308, 5) a is still greater than b!
# (309, 5) a is still greater than b!
# (310, 5) a is still greater than b!
# (311, 5) a is still greater than b!
# (312, 5) a is still greater than b!
# (313, 5) a is still greater than b!
# (314, 5) a is still greater than b!
# (315, 5) a is still greater than b!
# (316, 5) a is still greater than b!
# (317, 5) a is still greater than b!
# (318, 5) a is still greater than b!
# (319, 5) a is still greater than b!
# (320, 5) a is still greater than b!
# (321, 5) a is still greater than b!
# (322, 5) a is still greater than b!
# (323, 5) a is still greater than b!
# (324, 5) a is still greater than b!
# (325, 5) a is still greater than b!
# (326, 5) a is still greater than b!
# (327, 5) a is still greater than b!
# (328, 5) a is still greater than b!
# (329, 5) a is still greater than b!
# (330, 5) a is still greater than b!
# (331, 5) a is still greater than b!
# (332, 5) a is still greater than b!
# (333, 5) a is still greater than b!
# (334, 5) a is still greater than b!
# (335, 5) a is still greater than b!
# (336, 5) a is still greater than b!
# (337, 5) a is still greater than b!
# (338, 5) a is still greater than b!
# (339, 5) a is still greater than b!
# (340, 5) a is still greater than b!
# (341, 5) a is still greater than b!
# (342, 5) a is still greater than b!
# (343, 5) a is still greater than b!
# (344, 5) a is still greater than b!
# (345, 5) a is still greater than b!
# (346, 5) a is still greater than b!
# (347, 5) a is still greater than b!
# (348, 5) a is still greater than b!
# (349, 5) a is still greater than b!
# (350, 5) a is still greater than b!
# (351, 5) a is still greater than b!
# (352, 5) a is still greater than b!
# (353, 5) a is still greater than b!
# (354, 5) a is still greater than b!
# (355, 5) a is still greater than b!
# (356, 5) a is still greater than b!
# (357, 5) a is still greater than b!
# (358, 5) a is still greater than b!
# (359, 5) a is still greater than b!
# (360, 5) a is still greater than b!
# (361, 5) a is still greater than b!
# (362, 5) a is still greater than b!
# (363, 5) a is still greater than b!
# (364, 5) a is still greater than b!
# (365, 5) a is still greater than b!
# (366, 5) a is still greater than b!
# (367, 5) a is still greater than b!
# (368, 5) a is still greater than b!
# (369, 5) a is still greater than b!
# (370, 5) a is still greater than b!
# (371, 5) a is still greater than b!
# (372, 5) a is still greater than b!
# (373, 5) a is still greater than b!
# (374, 5) a is still greater than b!
# (375, 5) a is still greater than b!
# (376, 5) a is still greater than b!
# (377, 5) a is still greater than b!
# (378, 5) a is still greater than b!
# (379, 5) a is still greater than b!
# (380, 5) a is still greater than b!
# (381, 5) a is still greater than b!
# (382, 5) a is still greater than b!
# (383, 5) a is still greater than b!
# (384, 5) a is still greater than b!
# (385, 5) a is still greater than b!
# (386, 5) a is still greater than b!
# (387, 5) a is still greater than b!
# (388, 5) a is still greater than b!
# (389, 5) a is still greater than b!
# (390, 5) a is still greater than b!
# (391, 5) a is still greater than b!
# (392, 5) a is still greater than b!
# (393, 5) a is still greater than b!
# (394, 5) a is still greater than b!
# (395, 5) a is still greater than b!
# (396, 5) a is still greater than b!
# (397, 5) a is still greater than b!
# (398, 5) a is still greater than b!
# (399, 5) a is still greater than b!
# (400, 5) a is still greater than b!
# (401, 5) a is still greater than b!
# (402, 5) a is still greater than b!
# (403, 5) a is still greater than b!
# (404, 5) a is still greater than b!
# (405, 5) a is still greater than b!
# (406, 5) a is still greater than b!
# (407, 5) a is still greater than b!
# (408, 5) a is still greater than b!
# (409, 5) a is still greater than b!
# (410, 5) a is still greater than b!
# (411, 5) a is still greater than b!
# (412, 5) a is still greater than b!
# (413, 5) a is still greater than b!
# (414, 5) a is still greater than b!
# (415, 5) a is still greater than b!
# (416, 5) a is still greater than b!
# (417, 5) a is still greater than b!
# (418, 5) a is still greater than b!
# (419, 5) a is still greater than b!
# (420, 5) a is still greater than b!
# (421, 5) a is still greater than b!
# (422, 5) a is still greater than b!
# (423, 5) a is still greater than b!
# (424, 5) a is still greater than b!
# (425, 5) a is still greater than b!
# (426, 5) a is still greater than b!
# (427, 5) a is still greater than b!
# (428, 5) a is still greater than b!
# (429, 5) a is still greater than b!
# (430, 5) a is still greater than b!
# (431, 5) a is still greater than b!
# (432, 5) a is still greater than b!
# (433, 5) a is still greater than b!
# (434, 5) a is still greater than b!
# (435, 5) a is still greater than b!
# (436, 5) a is still greater than b!
# (437, 5) a is still greater than b!
# (438, 5) a is still greater than b!
# (439, 5) a is still greater than b!
# (440, 5) a is still greater than b!
# (441, 5) a is still greater than b!
# (442, 5) a is still greater than b!
# (443, 5) a is still greater than b!
# (444, 5) a is still greater than b!
# (445, 5) a is still greater than b!
# (446, 5) a is still greater than b!
# (447, 5) a is still greater than b!
# (448, 5) a is still greater than b!
# (449, 5) a is still greater than b!
# (450, 5) a is still greater than b!
# (451, 5) a is still greater than b!
# (452, 5) a is still greater than b!
# (453, 5) a is still greater than b!
# (454, 5) a is still greater than b!
# (455, 5) a is still greater than b!
# (456, 5) a is still greater than b!
# (457, 5) a is still greater than b!
# (458, 5) a is still greater than b!
# (459, 5) a is still greater than b!
# (460, 5) a is still greater than b!
# (461, 5) a is still greater than b!
# (462, 5) a is still greater than b!
# (463, 5) a is still greater than b!
# (464, 5) a is still greater than b!
# (465, 5) a is still greater than b!
# (466, 5) a is still greater than b!
# (467, 5) a is still greater than b!
# (468, 5) a is still greater than b!
# (469, 5) a is still greater than b!
# (470, 5) a is still greater than b!
# (471, 5) a is still greater than b!
# (472, 5) a is still greater than b!
# (473, 5) a is still greater than b!
# (474, 5) a is still greater than b!
# (475, 5) a is still greater than b!
# (476, 5) a is still greater than b!
# (477, 5) a is still greater than b!
# (478, 5) a is still greater than b!
# (479, 5) a is still greater than b!
# (480, 5) a is still greater than b!
# (481, 5) a is still greater than b!
# (482, 5) a is still greater than b!
# (483, 5) a is still greater than b!
# (484, 5) a is still greater than b!
# (485, 5) a is still greater than b!
# (486, 5) a is still greater than b!
# (487, 5) a is still greater than b!
# (488, 5) a is still greater than b!
# (489, 5) a is still greater than b!
# (490, 5) a is still greater than b!
# (491, 5) a is still greater than b!
# (492, 5) a is still greater than b!
# (493, 5) a is still greater than b!
# (494, 5) a is still greater than b!
# (495, 5) a is still greater than b!
# (496, 5) a is still greater than b!
# (497, 5) a is still greater than b!
# (498, 5) a is still greater than b!
# (499, 5) a is still greater than b!
# (500, 5) a is still greater than b!
# (501, 5) a is still greater than b!
# (502, 5) a is still greater than b!
# (503, 5) a is still greater than b!
# (504, 5) a is still greater than b!
# (505, 5) a is still greater than b!
# (506, 5) a is still greater than b!
# (507, 5) a is still greater than b!
# (508, 5) a is still greater than b!
# (509, 5) a is still greater than b!
# (510, 5) a is still greater than b!
# (511, 5) a is still greater than b!
# (512, 5) a is still greater than b!
# (513, 5) a is still greater than b!
# (514, 5) a is still greater than b!
# (515, 5) a is still greater than b!
# (516, 5) a is still greater than b!
# (517, 5) a is still greater than b!
# (518, 5) a is still greater than b!
# (519, 5) a is still greater than b!
# (520, 5) a is still greater than b!
# (521, 5) a is still greater than b!
# (522, 5) a is still greater than b!
# (523, 5) a is still greater than b!
# (524, 5) a is still greater than b!
# (525, 5) a is still greater than b!
# (526, 5) a is still greater than b!
# (527, 5) a is still greater than b!
# (528, 5) a is still greater than b!
# (529, 5) a is still greater than b!
# (530, 5) a is still greater than b!
# (531, 5) a is still greater than b!
# (532, 5) a is still greater than b!
# (533, 5) a is still greater than b!
# (534, 5) a is still greater than b!
# (535, 5) a is still greater than b!
# (536, 5) a is still greater than b!
# (537, 5) a is still greater than b!
# (538, 5) a is still greater than b!
# (539, 5) a is still greater than b!
# (540, 5) a is still greater than b!
# (541, 5) a is still greater than b!
# (542, 5) a is still greater than b!
# (543, 5) a is still greater than b!
# (544, 5) a is still greater than b!
# (545, 5) a is still greater than b!
# (546, 5) a is still greater than b!
# (547, 5) a is still greater than b!
# (548, 5) a is still greater than b!
# (549, 5) a is still greater than b!
# (550, 5) a is still greater than b!
# (551, 5) a is still greater than b!
# (552, 5) a is still greater than b!
# (553, 5) a is still greater than b!
# (554, 5) a is still greater than b!
# (555, 5) a is still greater than b!
# (556, 5) a is still greater than b!
# (557, 5) a is still greater than b!
# (558, 5) a is still greater than b!
# (559, 5) a is still greater than b!
# (560, 5) a is still greater than b!
# (561, 5) a is still greater than b!
# (562, 5) a is still greater than b!
# (563, 5) a is still greater than b!
# (564, 5) a is still greater than b!
# (565, 5) a is still greater than b!
# (566, 5) a is still greater than b!
# (567, 5) a is still greater than b!
# (568, 5) a is still greater than b!
# (569, 5) a is still greater than b!
# (570, 5) a is still greater than b!
# (571, 5) a is still greater than b!
# (572, 5) a is still greater than b!
# (573, 5) a is still greater than b!
# (574, 5) a is still greater than b!
# (575, 5) a is still greater than b!
# (576, 5) a is still greater than b!
# (577, 5) a is still greater than b!
# (578, 5) a is still greater than b!
# (579, 5) a is still greater than b!
# (580, 5) a is still greater than b!
# (581, 5) a is still greater than b!
# (582, 5) a is still greater than b!
# (583, 5) a is still greater than b!
# (584, 5) a is still greater than b!
# (585, 5) a is still greater than b!
# (586, 5) a is still greater than b!
# (587, 5) a is still greater than b!
# (588, 5) a is still greater than b!
# (589, 5) a is still greater than b!
# (590, 5) a is still greater than b!
# (591, 5) a is still greater than b!
# (592, 5) a is still greater than b!
# (593, 5) a is still greater than b!
# (594, 5) a is still greater than b!
# (595, 5) a is still greater than b!
# (596, 5) a is still greater than b!
# (597, 5) a is still greater than b!
# (598, 5) a is still greater than b!
# (599, 5) a is still greater than b!
# (600, 5) a is still greater than b!
# (601, 5) a is still greater than b!
# (602, 5) a is still greater than b!
# (603, 5) a is still greater than b!
# (604, 5) a is still greater than b!
# (605, 5) a is still greater than b!
# (606, 5) a is still greater than b!
# (607, 5) a is still greater than b!
# (608, 5) a is still greater than b!
# (609, 5) a is still greater than b!
# (610, 5) a is still greater than b!
# (611, 5) a is still greater than b!
# (612, 5) a is still greater than b!
# (613, 5) a is still greater than b!
# (614, 5) a is still greater than b!
# (615, 5) a is still greater than b!
# (616, 5) a is still greater than b!
# (617, 5) a is still greater than b!
# (618, 5) a is still greater than b!
# (619, 5) a is still greater than b!
# (620, 5) a is still greater than b!
# (621, 5) a is still greater than b!
# (622, 5) a is still greater than b!
# (623, 5) a is still greater than b!
# (624, 5) a is still greater than b!
# (625, 5) a is still greater than b!
# (626, 5) a is still greater than b!
# (627, 5) a is still greater than b!
# (628, 5) a is still greater than b!
# (629, 5) a is still greater than b!
# (630, 5) a is still greater than b!
# (631, 5) a is still greater than b!
# (632, 5) a is still greater than b!
# (633, 5) a is still greater than b!
# (634, 5) a is still greater than b!
# (635, 5) a is still greater than b!
# (636, 5) a is still greater than b!
# (637, 5) a is still greater than b!
# (638, 5) a is still greater than b!
# (639, 5) a is still greater than b!
# (640, 5) a is still greater than b!
# (641, 5) a is still greater than b!
# (642, 5) a is still greater than b!
# (643, 5) a is still greater than b!
# (644, 5) a is still greater than b!
# (645, 5) a is still greater than b!
# (646, 5) a is still greater than b!
# (647, 5) a is still greater than b!
# (648, 5) a is still greater than b!
# (649, 5) a is still greater than b!
# (650, 5) a is still greater than b!
# (651, 5) a is still greater than b!
# (652, 5) a is still greater than b!
# (653, 5) a is still greater than b!
# (654, 5) a is still greater than b!
# (655, 5) a is still greater than b!
# (656, 5) a is still greater than b!
# (657, 5) a is still greater than b!
# (658, 5) a is still greater than b!
# (659, 5) a is still greater than b!
# (660, 5) a is still greater than b!
# (661, 5) a is still greater than b!
# (662, 5) a is still greater than b!
# (663, 5) a is still greater than b!
# (664, 5) a is still greater than b!
# (665, 5) a is still greater than b!
# (666, 5) a is still greater than b!
# (667, 5) a is still greater than b!
# (668, 5) a is still greater than b!
# (669, 5) a is still greater than b!
# (670, 5) a is still greater than b!
# (671, 5) a is still greater than b!
# (672, 5) a is still greater than b!
# (673, 5) a is still greater than b!
# (674, 5) a is still greater than b!
# (675, 5) a is still greater than b!
# (676, 5) a is still greater than b!
# (677, 5) a is still greater than b!
# (678, 5) a is still greater than b!
# (679, 5) a is still greater than b!
# (680, 5) a is still greater than b!
# (681, 5) a is still greater than b!
# (682, 5) a is still greater than b!
# (683, 5) a is still greater than b!
# (684, 5) a is still greater than b!
# (685, 5) a is still greater than b!
# (686, 5) a is still greater than b!
# (687, 5) a is still greater than b!
# (688, 5) a is still greater than b!
# (689, 5) a is still greater than b!
# (690, 5) a is still greater than b!
# (691, 5) a is still greater than b!
# (692, 5) a is still greater than b!
# (693, 5) a is still greater than b!
# (694, 5) a is still greater than b!
# (695, 5) a is still greater than b!
# (696, 5) a is still greater than b!
# (697, 5) a is still greater than b!
# (698, 5) a is still greater than b!
# (699, 5) a is still greater than b!
# (700, 5) a is still greater than b!
# (701, 5) a is still greater than b!
# (702, 5) a is still greater than b!
# (703, 5) a is still greater than b!
# (704, 5) a is still greater than b!
# (705, 5) a is still greater than b!
# (706, 5) a is still greater than b!
# (707, 5) a is still greater than b!
# (708, 5) a is still greater than b!
# (709, 5) a is still greater than b!
# (710, 5) a is still greater than b!
# (711, 5) a is still greater than b!
# (712, 5) a is still greater than b!
# (713, 5) a is still greater than b!
# (714, 5) a is still greater than b!
# (715, 5) a is still greater than b!
# (716, 5) a is still greater than b!
# (717, 5) a is still greater than b!
# (718, 5) a is still greater than b!
# (719, 5) a is still greater than b!
# (720, 5) a is still greater than b!
# (721, 5) a is still greater than b!
# (722, 5) a is still greater than b!
# (723, 5) a is still greater than b!
# (724, 5) a is still greater than b!
# (725, 5) a is still greater than b!
# (726, 5) a is still greater than b!
# (727, 5) a is still greater than b!
# (728, 5) a is still greater than b!
# (729, 5) a is still greater than b!
# (730, 5) a is still greater than b!
# (731, 5) a is still greater than b!
# (732, 5) a is still greater than b!
# (733, 5) a is still greater than b!
# (734, 5) a is still greater than b!
# (735, 5) a is still greater than b!
# (736, 5) a is still greater than b!
# (737, 5) a is still greater than b!
# (738, 5) a is still greater than b!
# (739, 5) a is still greater than b!
# (740, 5) a is still greater than b!
# (741, 5) a is still greater than b!
# (742, 5) a is still greater than b!
# (743, 5) a is still greater than b!
# (744, 5) a is still greater than b!
# (745, 5) a is still greater than b!
# (746, 5) a is still greater than b!
# (747, 5) a is still greater than b!
# (748, 5) a is still greater than b!
# (749, 5) a is still greater than b!
# (750, 5) a is still greater than b!
# (751, 5) a is still greater than b!
# (752, 5) a is still greater than b!
# (753, 5) a is still greater than b!
# (754, 5) a is still greater than b!
# (755, 5) a is still greater than b!
# (756, 5) a is still greater than b!
# (757, 5) a is still greater than b!
# (758, 5) a is still greater than b!
# (759, 5) a is still greater than b!
# (760, 5) a is still greater than b!
# (761, 5) a is still greater than b!
# (762, 5) a is still greater than b!
# (763, 5) a is still greater than b!
# (764, 5) a is still greater than b!
# (765, 5) a is still greater than b!
# (766, 5) a is still greater than b!
# (767, 5) a is still greater than b!
# (768, 5) a is still greater than b!
# (769, 5) a is still greater than b!
# (770, 5) a is still greater than b!
# (771, 5) a is still greater than b!
# (772, 5) a is still greater than b!
# (773, 5) a is still greater than b!
# (774, 5) a is still greater than b!
# (775, 5) a is still greater than b!
# (776, 5) a is still greater than b!
# (777, 5) a is still greater than b!
# (778, 5) a is still greater than b!
# (779, 5) a is still greater than b!
# (780, 5) a is still greater than b!
# (781, 5) a is still greater than b!
# (782, 5) a is still greater than b!
# (783, 5) a is still greater than b!
# (784, 5) a is still greater than b!
# (785, 5) a is still greater than b!
# (786, 5) a is still greater than b!
# (787, 5) a is still greater than b!
# (788, 5) a is still greater than b!
# (789, 5) a is still greater than b!
# (790, 5) a is still greater than b!
# (791, 5) a is still greater than b!
# (792, 5) a is still greater than b!
# (793, 5) a is still greater than b!
# (794, 5) a is still greater than b!
# (795, 5) a is still greater than b!
# (796, 5) a is still greater than b!
# (797, 5) a is still greater than b!
# (798, 5) a is still greater than b!
# (799, 5) a is still greater than b!
# (800, 5) a is still greater than b!
# (801, 5) a is still greater than b!
# (802, 5) a is still greater than b!
# (803, 5) a is still greater than b!
# (804, 5) a is still greater than b!
# (805, 5) a is still greater than b!
# (806, 5) a is still greater than b!
# (807, 5) a is still greater than b!
# (808, 5) a is still greater than b!
# (809, 5) a is still greater than b!
# (810, 5) a is still greater than b!
# (811, 5) a is still greater than b!
# (812, 5) a is still greater than b!
# (813, 5) a is still greater than b!
# (814, 5) a is still greater than b!
# (815, 5) a is still greater than b!
# (816, 5) a is still greater than b!
# (817, 5) a is still greater than b!
# (818, 5) a is still greater than b!
# (819, 5) a is still greater than b!
# (820, 5) a is still greater than b!
# (821, 5) a is still greater than b!
# (822, 5) a is still greater than b!
# (823, 5) a is still greater than b!
# (824, 5) a is still greater than b!
# (825, 5) a is still greater than b!
# (826, 5) a is still greater than b!
# (827, 5) a is still greater than b!
# (828, 5) a is still greater than b!
# (829, 5) a is still greater than b!
# (830, 5) a is still greater than b!
# (831, 5) a is still greater than b!
# (832, 5) a is still greater than b!
# (833, 5) a is still greater than b!
# (834, 5) a is still greater than b!
# (835, 5) a is still greater than b!
# (836, 5) a is still greater than b!
# (837, 5) a is still greater than b!
# (838, 5) a is still greater than b!
# (839, 5) a is still greater than b!
# (840, 5) a is still greater than b!
# (841, 5) a is still greater than b!
# (842, 5) a is still greater than b!
# (843, 5) a is still greater than b!
# (844, 5) a is still greater than b!
# (845, 5) a is still greater than b!
# (846, 5) a is still greater than b!
# (847, 5) a is still greater than b!
# (848, 5) a is still greater than b!
# (849, 5) a is still greater than b!
# (850, 5) a is still greater than b!
# (851, 5) a is still greater than b!
# (852, 5) a is still greater than b!
# (853, 5) a is still greater than b!
# (854, 5) a is still greater than b!
# (855, 5) a is still greater than b!
# (856, 5) a is still greater than b!
# (857, 5) a is still greater than b!
# (858, 5) a is still greater than b!
# (859, 5) a is still greater than b!
# (860, 5) a is still greater than b!
# (861, 5) a is still greater than b!
# (862, 5) a is still greater than b!
# (863, 5) a is still greater than b!
# (864, 5) a is still greater than b!
# (865, 5) a is still greater than b!
# (866, 5) a is still greater than b!
# (867, 5) a is still greater than b!
# (868, 5) a is still greater than b!
# (869, 5) a is still greater than b!
# (870, 5) a is still greater than b!
# (871, 5) a is still greater than b!
# (872, 5) a is still greater than b!
# (873, 5) a is still greater than b!
# (874, 5) a is still greater than b!
# (875, 5) a is still greater than b!
# (876, 5) a is still greater than b!
# (877, 5) a is still greater than b!
# (878, 5) a is still greater than b!
# (879, 5) a is still greater than b!
# (880, 5) a is still greater than b!
# (881, 5) a is still greater than b!
# (882, 5) a is still greater than b!
# (883, 5) a is still greater than b!
# (884, 5) a is still greater than b!
# (885, 5) a is still greater than b!
# (886, 5) a is still greater than b!
# (887, 5) a is still greater than b!
# (888, 5) a is still greater than b!
# (889, 5) a is still greater than b!
# (890, 5) a is still greater than b!
# (891, 5) a is still greater than b!
# (892, 5) a is still greater than b!
# (893, 5) a is still greater than b!
# (894, 5) a is still greater than b!
# (895, 5) a is still greater than b!
# (896, 5) a is still greater than b!
# (897, 5) a is still greater than b!
# (898, 5) a is still greater than b!
# (899, 5) a is still greater than b!
# (900, 5) a is still greater than b!
# (901, 5) a is still greater than b!
# (902, 5) a is still greater than b!
# (903, 5) a is still greater than b!
# (904, 5) a is still greater than b!
# (905, 5) a is still greater than b!
# (906, 5) a is still greater than b!
# (907, 5) a is still greater than b!
# (908, 5) a is still greater than b!
# (909, 5) a is still greater than b!
# (910, 5) a is still greater than b!
# (911, 5) a is still greater than b!
# (912, 5) a is still greater than b!
# (913, 5) a is still greater than b!
# (914, 5) a is still greater than b!
# (915, 5) a is still greater than b!
# (916, 5) a is still greater than b!
# (917, 5) a is still greater than b!
# (918, 5) a is still greater than b!
# (919, 5) a is still greater than b!
# (920, 5) a is still greater than b!
# (921, 5) a is still greater than b!
# (922, 5) a is still greater than b!
# (923, 5) a is still greater than b!
# (924, 5) a is still greater than b!
# (925, 5) a is still greater than b!
# (926, 5) a is still greater than b!
# (927, 5) a is still greater than b!
# (928, 5) a is still greater than b!
# (929, 5) a is still greater than b!
# (930, 5) a is still greater than b!
# (931, 5) a is still greater than b!
# (932, 5) a is still greater than b!
# (933, 5) a is still greater than b!
# (934, 5) a is still greater than b!
# (935, 5) a is still greater than b!
# (936, 5) a is still greater than b!
# (937, 5) a is still greater than b!
# (938, 5) a is still greater than b!
# (939, 5) a is still greater than b!
# (940, 5) a is still greater than b!
# (941, 5) a is still greater than b!
# (942, 5) a is still greater than b!
# (943, 5) a is still greater than b!
# (944, 5) a is still greater than b!
# (945, 5) a is still greater than b!
# (946, 5) a is still greater than b!
# (947, 5) a is still greater than b!
# (948, 5) a is still greater than b!
# (949, 5) a is still greater than b!
# (950, 5) a is still greater than b!
# (951, 5) a is still greater than b!
# (952, 5) a is still greater than b!
# (953, 5) a is still greater than b!
# (954, 5) a is still greater than b!
# (955, 5) a is still greater than b!
# (956, 5) a is still greater than b!
# (957, 5) a is still greater than b!
# (958, 5) a is still greater than b!
# (959, 5) a is still greater than b!
# (960, 5) a is still greater than b!
# (961, 5) a is still greater than b!
# (962, 5) a is still greater than b!
# (963, 5) a is still greater than b!
# (964, 5) a is still greater than b!
# (965, 5) a is still greater than b!
# (966, 5) a is still greater than b!
# (967, 5) a is still greater than b!
# (968, 5) a is still greater than b!
# (969, 5) a is still greater than b!
# (970, 5) a is still greater than b!
# (971, 5) a is still greater than b!
# (972, 5) a is still greater than b!
# (973, 5) a is still greater than b!
# (974, 5) a is still greater than b!
# (975, 5) a is still greater than b!
# (976, 5) a is still greater than b!
# (977, 5) a is still greater than b!
# (978, 5) a is still greater than b!
# (979, 5) a is still greater than b!
# (980, 5) a is still greater than b!
# (981, 5) a is still greater than b!
# (982, 5) a is still greater than b!
# (983, 5) a is still greater than b!
# (984, 5) a is still greater than b!
# (985, 5) a is still greater than b!
# (986, 5) a is still greater than b!
# (987, 5) a is still greater than b!
# (988, 5) a is still greater than b!
# (989, 5) a is still greater than b!
# (990, 5) a is still greater than b!
# (991, 5) a is still greater than b!
# (992, 5) a is still greater than b!
# (993, 5) a is still greater than b!
# (994, 5) a is still greater than b!
# (995, 5) a is still greater than b!
# (996, 5) a is still greater than b!
# (997, 5) a is still greater than b!
# (998, 5) a is still greater than b!
# (999, 5) a is still greater than b!
# (1000, 5) a is still greater than b!
# (1001, 5) a is still greater than b!
# (1002, 5) a is still greater than b!
# (1003, 5) a is still greater than b!
# (1004, 5) a is still greater than b!
# (1005, 5) a is still greater than b!
# (1006, 5) a is still greater than b!
# (1007, 5) a is still greater than b!
# (1008, 5) a is still greater than b!
# (1009, 5) a is still greater than b!
# (1010, 5) a is still greater than b!
# (1011, 5) a is still greater than b!
# (1012, 5) a is still greater than b!
# (1013, 5) a is still greater than b!
# (1014, 5) a is still greater than b!
# (1015, 5) a is still greater than b!
# (1016, 5) a is still greater than b!
# (1017, 5) a is still greater than b!
# (1018, 5) a is still greater than b!
# (1019, 5) a is still greater than b!
# (1020, 5) a is still greater than b!
# (1021, 5) a is still greater than b!
# (1022, 5) a is still greater than b!
# (1023, 5) a is still greater than b!
# (1024, 5) a is still greater than b!
# (1025, 5) a is still greater than b!
# (1026, 5) a is still greater than b!
# (1027, 5) a is still greater than b!
# (1028, 5) a is still greater than b!
# (1029, 5) a is still greater than b!
# (1030, 5) a is still greater than b!
# (1031, 5) a is still greater than b!
# (1032, 5) a is still greater than b!
# (1033, 5) a is still greater than b!
# (1034, 5) a is still greater than b!
# (1035, 5) a is still greater than b!
# (1036, 5) a is still greater than b!
# (1037, 5) a is still greater than b!
# (1038, 5) a is still greater than b!
# (1039, 5) a is still greater than b!
# (1040, 5) a is still greater than b!
# (1041, 5) a is still greater than b!
# (1042, 5) a is still greater than b!
# (1043, 5) a is still greater than b!
# (1044, 5) a is still greater than b!
# (1045, 5) a is still greater than b!
# (1046, 5) a is still greater than b!
# (1047, 5) a is still greater than b!
# (1048, 5) a is still greater than b!
# (1049, 5) a is still greater than b!
# (1050, 5) a is still greater than b!
# (1051, 5) a is still greater than b!
# (1052, 5) a is still greater than b!
# (1053, 5) a is still greater than b!
# (1054, 5) a is still greater than b!
# (1055, 5) a is still greater than b!
# (1056, 5) a is still greater than b!
# (1057, 5) a is still greater than b!
# (1058, 5) a is still greater than b!
# (1059, 5) a is still greater than b!
# (1060, 5) a is still greater than b!
# (1061, 5) a is still greater than b!
# (1062, 5) a is still greater than b!
# (1063, 5) a is still greater than b!
# (1064, 5) a is still greater than b!
# (1065, 5) a is still greater than b!
# (1066, 5) a is still greater than b!
# (1067, 5) a is still greater than b!
# (1068, 5) a is still greater than b!
# (1069, 5) a is still greater than b!
# (1070, 5) a is still greater than b!
# (1071, 5) a is still greater than b!
# (1072, 5) a is still greater than b!
# (1073, 5) a is still greater than b!
# (1074, 5) a is still greater than b!
# (1075, 5) a is still greater than b!
# (1076, 5) a is still greater than b!
# (1077, 5) a is still greater than b!
# (1078, 5) a is still greater than b!
# (1079, 5) a is still greater than b!
# (1080, 5) a is still greater than b!
# (1081, 5) a is still greater than b!
# (1082, 5) a is still greater than b!
# (1083, 5) a is still greater than b!
# (1084, 5) a is still greater than b!
# (1085, 5) a is still greater than b!
# (1086, 5) a is still greater than b!
# (1087, 5) a is still greater than b!
# (1088, 5) a is still greater than b!
# (1089, 5) a is still greater than b!
# (1090, 5) a is still greater than b!
# (1091, 5) a is still greater than b!
# (1092, 5) a is still greater than b!
# (1093, 5) a is still greater than b!
# (1094, 5) a is still greater than b!
# (1095, 5) a is still greater than b!
# (1096, 5) a is still greater than b!
# (1097, 5) a is still greater than b!
# (1098, 5) a is still greater than b!
# (1099, 5) a is still greater than b!
# (1100, 5) a is still greater than b!
# (1101, 5) a is still greater than b!
# (1102, 5) a is still greater than b!
# (1103, 5) a is still greater than b!
# (1104, 5) a is still greater than b!
# (1105, 5) a is still greater than b!
# (1106, 5) a is still greater than b!
# (1107, 5) a is still greater than b!
# (1108, 5) a is still greater than b!
# (1109, 5) a is still greater than b!
# (1110, 5) a is still greater than b!
# (1111, 5) a is still greater than b!
# (1112, 5) a is still greater than b!
# (1113, 5) a is still greater than b!
# (1114, 5) a is still greater than b!
# (1115, 5) a is still greater than b!
# (1116, 5) a is still greater than b!
# (1117, 5) a is still greater than b!
# (1118, 5) a is still greater than b!
# (1119, 5) a is still greater than b!
# (1120, 5) a is still greater than b!
# (1121, 5) a is still greater than b!
# (1122, 5) a is still greater than b!
# (1123, 5) a is still greater than b!
# (1124, 5) a is still greater than b!
# (1125, 5) a is still greater than b!
# (1126, 5) a is still greater than b!
# (1127, 5) a is still greater than b!
# (1128, 5) a is still greater than b!
# (1129, 5) a is still greater than b!
# (1130, 5) a is still greater than b!
# (1131, 5) a is still greater than b!
# (1132, 5) a is still greater than b!
# (1133, 5) a is still greater than b!
# (1134, 5) a is still greater than b!
# (1135, 5) a is still greater than b!
# (1136, 5) a is still greater than b!
# (1137, 5) a is still greater than b!
# (1138, 5) a is still greater than b!
# (1139, 5) a is still greater than b!
# (1140, 5) a is still greater than b!
# (1141, 5) a is still greater than b!
# (1142, 5) a is still greater than b!
# (1143, 5) a is still greater than b!
# (1144, 5) a is still greater than b!
# (1145, 5) a is still greater than b!
# (1146, 5) a is still greater than b!
# (1147, 5) a is still greater than b!
# (1148, 5) a is still greater than b!
# (1149, 5) a is still greater than b!
# (1150, 5) a is still greater than b!
# (1151, 5) a is still greater than b!
# (1152, 5) a is still greater than b!
# (1153, 5) a is still greater than b!
# (1154, 5) a is still greater than b!
# (1155, 5) a is still greater than b!
# (1156, 5) a is still greater than b!
# (1157, 5) a is still greater than b!
# (1158, 5) a is still greater than b!
# (1159, 5) a is still greater than b!
# (1160, 5) a is still greater than b!
# (1161, 5) a is still greater than b!
# (1162, 5) a is still greater than b!
# (1163, 5) a is still greater than b!
# (1164, 5) a is still greater than b!
# (1165, 5) a is still greater than b!
# (1166, 5) a is still greater than b!
# (1167, 5) a is still greater than b!
# (1168, 5) a is still greater than b!
# (1169, 5) a is still greater than b!
# (1170, 5) a is still greater than b!
# (1171, 5) a is still greater than b!
# (1172, 5) a is still greater than b!
# (1173, 5) a is still greater than b!
# (1174, 5) a is still greater than b!
# (1175, 5) a is still greater than b!
# (1176, 5) a is still greater than b!
# (1177, 5) a is still greater than b!
# (1178, 5) a is still greater than b!
# (1179, 5) a is still greater than b!
# (1180, 5) a is still greater than b!
# (1181, 5) a is still greater than b!
# (1182, 5) a is still greater than b!
# (1183, 5) a is still greater than b!
# (1184, 5) a is still greater than b!
# (1185, 5) a is still greater than b!
# (1186, 5) a is still greater than b!
# (1187, 5) a is still greater than b!
# (1188, 5) a is still greater than b!
# (1189, 5) a is still greater than b!
# (1190, 5) a is still greater than b!
# (1191, 5) a is still greater than b!
# (1192, 5) a is still greater than b!
# (1193, 5) a is still greater than b!
# (1194, 5) a is still greater than b!
# (1195, 5) a is still greater than b!
# (1196, 5) a is still greater than b!
# (1197, 5) a is still greater than b!
# (1198, 5) a is still greater than b!
# (1199, 5) a is still greater than b!
# (1200, 5) a is still greater than b!
# (1201, 5) a is still greater than b!
# (1202, 5) a is still greater than b!
# (1203, 5) a is still greater than b!
# (1204, 5) a is still greater than b!
# (1205, 5) a is still greater than b!
# (1206, 5) a is still greater than b!
# (1207, 5) a is still greater than b!
# (1208, 5) a is still greater than b!
# (1209, 5) a is still greater than b!
# (1210, 5) a is still greater than b!
# (1211, 5) a is still greater than b!
# (1212, 5) a is still greater than b!
# (1213, 5) a is still greater than b!
# (1214, 5) a is still greater than b!
# (1215, 5) a is still greater than b!
# (1216, 5) a is still greater than b!
# (1217, 5) a is still greater than b!
# (1218, 5) a is still greater than b!
# (1219, 5) a is still greater than b!
# (1220, 5) a is still greater than b!
# (1221, 5) a is still greater than b!
# (1222, 5) a is still greater than b!
# (1223, 5) a is still greater than b!
# (1224, 5) a is still greater than b!
# (1225, 5) a is still greater than b!
# (1226, 5) a is still greater than b!
# (1227, 5) a is still greater than b!
# (1228, 5) a is still greater than b!
# (1229, 5) a is still greater than b!
# (1230, 5) a is still greater than b!
# (1231, 5) a is still greater than b!
# (1232, 5) a is still greater than b!
# (1233, 5) a is still greater than b!
# (1234, 5) a is still greater than b!
# (1235, 5) a is still greater than b!
# (1236, 5) a is still greater than b!
# (1237, 5) a is still greater than b!
# (1238, 5) a is still greater than b!
# (1239, 5) a is still greater than b!
# (1240, 5) a is still greater than b!
# (1241, 5) a is still greater than b!
# (1242, 5) a is still greater than b!
# (1243, 5) a is still greater than b!
# (1244, 5) a is still greater than b!
# (1245, 5) a is still greater than b!
# (1246, 5) a is still greater than b!
# (1247, 5) a is still greater than b!
# (1248, 5) a is still greater than b!
# (1249, 5) a is still greater than b!
# (1250, 5) a is still greater than b!
# (1251, 5) a is still greater than b!
# (1252, 5) a is still greater than b!
# (1253, 5) a is still greater than b!
# (1254, 5) a is still greater than b!
# (1255, 5) a is still greater than b!
# (1256, 5) a is still greater than b!
# (1257, 5) a is still greater than b!
# (1258, 5) a is still greater than b!
# (1259, 5) a is still greater than b!
# (1260, 5) a is still greater than b!
# (1261, 5) a is still greater than b!
# (1262, 5) a is still greater than b!
# (1263, 5) a is still greater than b!
# (1264, 5) a is still greater than b!
# (1265, 5) a is still greater than b!
# (1266, 5) a is still greater than b!
# (1267, 5) a is still greater than b!
# (1268, 5) a is still greater than b!
# (1269, 5) a is still greater than b!
# (1270, 5) a is still greater than b!
# (1271, 5) a is still greater than b!
# (1272, 5) a is still greater than b!
# (1273, 5) a is still greater than b!
# (1274, 5) a is still greater than b!
# (1275, 5) a is still greater than b!
# (1276, 5) a is still greater than b!
# (1277, 5) a is still greater than b!
# (1278, 5) a is still greater than b!
# (1279, 5) a is still greater than b!
# (1280, 5) a is still greater than b!
# (1281, 5) a is still greater than b!
# (1282, 5) a is still greater than b!
# (1283, 5) a is still greater than b!
# (1284, 5) a is still greater than b!
# (1285, 5) a is still greater than b!
# (1286, 5) a is still greater than b!
# (1287, 5) a is still greater than b!
# (1288, 5) a is still greater than b!
# (1289, 5) a is still greater than b!
# (1290, 5) a is still greater than b!
# (1291, 5) a is still greater than b!
# (1292, 5) a is still greater than b!
# (1293, 5) a is still greater than b!
# (1294, 5) a is still greater than b!
# (1295, 5) a is still greater than b!
# (1296, 5) a is still greater than b!
# (1297, 5) a is still greater than b!
# (1298, 5) a is still greater than b!
# (1299, 5) a is still greater than b!
# (1300, 5) a is still greater than b!
# (1301, 5) a is still greater than b!
# (1302, 5) a is still greater than b!
# (1303, 5) a is still greater than b!
# (1304, 5) a is still greater than b!
# (1305, 5) a is still greater than b!
# (1306, 5) a is still greater than b!
# (1307, 5) a is still greater than b!
# (1308, 5) a is still greater than b!
# (1309, 5) a is still greater than b!
# (1310, 5) a is still greater than b!
# (1311, 5) a is still greater than b!
# (1312, 5) a is still greater than b!
# (1313, 5) a is still greater than b!
# (1314, 5) a is still greater than b!
# (1315, 5) a is still greater than b!
# (1316, 5) a is still greater than b!
# (1317, 5) a is still greater than b!
# (1318, 5) a is still greater than b!
# (1319, 5) a is still greater than b!
# (1320, 5) a is still greater than b!
# (1321, 5) a is still greater than b!
# (1322, 5) a is still greater than b!
# (1323, 5) a is still greater than b!
# (1324, 5) a is still greater than b!
# (1325, 5) a is still greater than b!
# (1326, 5) a is still greater than b!
# (1327, 5) a is still greater than b!
# (1328, 5) a is still greater than b!
# (1329, 5) a is still greater than b!
# (1330, 5) a is still greater than b!
# (1331, 5) a is still greater than b!
# (1332, 5) a is still greater than b!
# (1333, 5) a is still greater than b!
# (1334, 5) a is still greater than b!
# (1335, 5) a is still greater than b!
# ...
# (40624, 5) a is still greater than b!
# (40625, 5) a is still greater than b!
# (40626, 5) a is still greater than b!
# (40627, 5) a is still greater than b!
# (40628, 5) a is still greater than b!
# (40629, 5) a is still greater than b!
# (40630, 5) a is still greater than b!
# (40631, 5) a is still greater than b!
# (40632, 5) a is still greater than b!
# (40633, 5) a is still greater than b!
# (40634, 5) a is still greater than b!
# (40635, 5) a is still greater than b!
# (40636, 5) a is still greater than b!
# (40637, 5) a is still greater than b!
# (40638, 5) a is still greater than b!
# (40639, 5) a is still greater than b!
# (40640, 5) a is still greater than b!
# (40641, 5) a is still greater than b!
# (40642, 5) a is still greater than b!
# (40643, 5) a is still greater than b!
# (40644, 5) a is still greater than b!
# (40645, 5) a is still greater than b!
# (40646, 5) a is still greater than b!
# (40647, 5) a is still greater than b!
# (40648, 5) a is still greater than b!
# (40649, 5) a is still greater than b!
# (40650, 5) a is still greater than b!
# (40651, 5) a is still greater than b!
# (40652, 5) a is still greater than b!
# (40653, 5) a is still greater than b!
# (40654, 5) a is still greater than b!
# (40655, 5) a is still greater than b!
# (40656, 5) a is still greater than b!
# (40657, 5) a is still greater than b!
# (40658, 5) a is still greater than b!
# (40659, 5) a is still greater than b!
# (40660, 5) a is still greater than b!
# (40661, 5) a is still greater than b!
# (40662, 5) a is still greater than b!
# (40663, 5) a is still greater than b!
# (40664, 5) a is still greater than b!
# (40665, 5) a is still greater than b!
# (40666, 5) a is still greater than b!
# (40667, 5) a is still greater than b!
# (40668, 5) a is still greater than b!
# (40669, 5) a is still greater than b!
# (40670, 5) a is still greater than b!
# (40671, 5) a is still greater than b!
# (40672, 5) a is still greater than b!
# (40673, 5) a is still greater than b!
# (40674, 5) a is still greater than b!
# (40675, 5) a is still greater than b!
# (40676, 5) a is still greater than b!
# (40677, 5) a is still greater than b!
# (40678, 5) a is still greater than b!
# (40679, 5) a is still greater than b!
# (40680, 5) a is still greater than b!
# (40681, 5) a is still greater than b!
# (40682, 5) a is still greater than b!
# (40683, 5) a is still greater than b!
# (40684, 5) a is still greater than b!
# (40685, 5) a is still greater than b!
# (40686, 5) a is still greater than b!
# (40687, 5) a is still greater than b!
# (40688, 5) a is still greater than b!
# (40689, 5) a is still greater than b!
# (40690, 5) a is still greater than b!
# (40691, 5) a is still greater than b!
# (40692, 5) a is still greater than b!
# (40693, 5) a is still greater than b!
# (40694, 5) a is still greater than b!
# (40695, 5) a is still greater than b!
# (40696, 5) a is still greater than b!
# (40697, 5) a is still greater than b!
# (40698, 5) a is still greater than b!
# (40699, 5) a is still greater than b!
# (40700, 5) a is still greater than b!
# (40701, 5) a is still greater than b!
# (40702, 5) a is still greater than b!
# (40703, 5) a is still greater than b!
# (40704, 5) a is still greater than b!
# (40705, 5) a is still greater than b!
# (40706, 5) a is still greater than b!
# (40707, 5) a is still greater than b!
# (40708, 5) a is still greater than b!
# (40709, 5) a is still greater than b!
# (40710, 5) a is still greater than b!
# (40711, 5) a is still greater than b!
# (40712, 5) a is still greater than b!
# (40713, 5) a is still greater than b!
# (40714, 5) a is still greater than b!
# (40715, 5) a is still greater than b!
# (40716, 5) a is still greater than b!
# (40717, 5) a is still greater than b!
# (40718, 5) a is still greater than b!
# (40719, 5) a is still greater than b!
# (40720, 5) a is still greater than b!
# (40721, 5) a is still greater than b!
# (40722, 5) a is still greater than b!
# (40723, 5) a is still greater than b!
# (40724, 5) a is still greater than b!
# (40725, 5) a is still greater than b!
# (40726, 5) a is still greater than b!
# (40727, 5) a is still greater than b!
# (40728, 5) a is still greater than b!
# (40729, 5) a is still greater than b!
# (40730, 5) a is still greater than b!
# (40731, 5) a is still greater than b!
# (40732, 5) a is still greater than b!
# (40733, 5) a is still greater than b!
# (40734, 5) a is still greater than b!
# (40735, 5) a is still greater than b!
# (40736, 5) a is still greater than b!
# (40737, 5) a is still greater than b!
# (40738, 5) a is still greater than b!
# (40739, 5) a is still greater than b!
# (40740, 5) a is still greater than b!
# (40741, 5) a is still greater than b!
# (40742, 5) a is still greater than b!
# (40743, 5) a is still greater than b!
# (40744, 5) a is still greater than b!
# (40745, 5) a is still greater than b!
# (40746, 5) a is still greater than b!
# (40747, 5) a is still greater than b!
# (40748, 5) a is still greater than b!
# (40749, 5) a is still greater than b!
# (40750, 5) a is still greater than b!
# (40751, 5) a is still greater than b!
# (40752, 5) a is still greater than b!
# (40753, 5) a is still greater than b!
# (40754, 5) a is still greater than b!
# (40755, 5) a is still greater than b!
# (40756, 5) a is still greater than b!
# (40757, 5) a is still greater than b!
# (40758, 5) a is still greater than b!
# (40759, 5) a is still greater than b!
# (40760, 5) a is still greater than b!
# (40761, 5) a is still greater than b!
# (40762, 5) a is still greater than b!
# (40763, 5) a is still greater than b!
# (40764, 5) a is still greater than b!
# (40765, 5) a is still greater than b!
# (40766, 5) a is still greater than b!
# (40767, 5) a is still greater than b!
# (40768, 5) a is still greater than b!
# (40769, 5) a is still greater than b!
# (40770, 5) a is still greater than b!
# (40771, 5) a is still greater than b!
# (40772, 5) a is still greater than b!
# (40773, 5) a is still greater than b!
# (40774, 5) a is still greater than b!
# (40775, 5) a is still greater than b!
# (40776, 5) a is still greater than b!
# (40777, 5) a is still greater than b!
# (40778, 5) a is still greater than b!
# (40779, 5) a is still greater than b!
# (40780, 5) a is still greater than b!
# (40781, 5) a is still greater than b!
# (40782, 5) a is still greater than b!
# (40783, 5) a is still greater than b!
# (40784, 5) a is still greater than b!
# (40785, 5) a is still greater than b!
# (40786, 5) a is still greater than b!
# (40787, 5) a is still greater than b!
# (40788, 5) a is still greater than b!
# (40789, 5) a is still greater than b!
# (40790, 5) a is still greater than b!
# (40791, 5) a is still greater than b!
# (40792, 5) a is still greater than b!
# (40793, 5) a is still greater than b!
# (40794, 5) a is still greater than b!
# (40795, 5) a is still greater than b!
# (40796, 5) a is still greater than b!
# (40797, 5) a is still greater than b!
# (40798, 5) a is still greater than b!
# (40799, 5) a is still greater than b!
# (40800, 5) a is still greater than b!
# (40801, 5) a is still greater than b!
# (40802, 5) a is still greater than b!
# (40803, 5) a is still greater than b!
# (40804, 5) a is still greater than b!
# (40805, 5) a is still greater than b!
# (40806, 5) a is still greater than b!
# (40807, 5) a is still greater than b!
# (40808, 5) a is still greater than b!
# (40809, 5) a is still greater than b!
# (40810, 5) a is still greater than b!
# (40811, 5) a is still greater than b!
# (40812, 5) a is still greater than b!
# (40813, 5) a is still greater than b!
# (40814, 5) a is still greater than b!
# (40815, 5) a is still greater than b!
# (40816, 5) a is still greater than b!
# (40817, 5) a is still greater than b!
# (40818, 5) a is still greater than b!
# (40819, 5) a is still greater than b!
# (40820, 5) a is still greater than b!
# (40821, 5) a is still greater than b!
# (40822, 5) a is still greater than b!
# (40823, 5) a is still greater than b!
# (40824, 5) a is still greater than b!
# (40825, 5) a is still greater than b!
# (40826, 5) a is still greater than b!
# (40827, 5) a is still greater than b!
# (40828, 5) a is still greater than b!
# (40829, 5) a is still greater than b!
# (40830, 5) a is still greater than b!
# (40831, 5) a is still greater than b!
# (40832, 5) a is still greater than b!
# (40833, 5) a is still greater than b!
# (40834, 5) a is still greater than b!
# (40835, 5) a is still greater than b!
# (40836, 5) a is still greater than b!
# (40837, 5) a is still greater than b!
# (40838, 5) a is still greater than b!
# (40839, 5) a is still greater than b!
# (40840, 5) a is still greater than b!
# (40841, 5) a is still greater than b!
# (40842, 5) a is still greater than b!
# (40843, 5) a is still greater than b!
# (40844, 5) a is still greater than b!
# (40845, 5) a is still greater than b!
# (40846, 5) a is still greater than b!
# (40847, 5) a is still greater than b!
# (40848, 5) a is still greater than b!
# (40849, 5) a is still greater than b!
# (40850, 5) a is still greater than b!
# (40851, 5) a is still greater than b!
# (40852, 5) a is still greater than b!
# (40853, 5) a is still greater than b!
# (40854, 5) a is still greater than b!
# (40855, 5) a is still greater than b!
# (40856, 5) a is still greater than b!
# (40857, 5) a is still greater than b!
# (40858, 5) a is still greater than b!
# (40859, 5) a is still greater than b!
# (40860, 5) a is still greater than b!
# (40861, 5) a is still greater than b!
# (40862, 5) a is still greater than b!
# (40863, 5) a is still greater than b!
# (40864, 5) a is still greater than b!
# (40865, 5) a is still greater than b!
# (40866, 5) a is still greater than b!
# (40867, 5) a is still greater than b!
# (40868, 5) a is still greater than b!
# (40869, 5) a is still greater than b!
# (40870, 5) a is still greater than b!
# (40871, 5) a is still greater than b!
# (40872, 5) a is still greater than b!
# (40873, 5) a is still greater than b!
# (40874, 5) a is still greater than b!
# (40875, 5) a is still greater than b!
# (40876, 5) a is still greater than b!
# (40877, 5) a is still greater than b!
# (40878, 5) a is still greater than b!
# (40879, 5) a is still greater than b!
# (40880, 5) a is still greater than b!
# (40881, 5) a is still greater than b!
# (40882, 5) a is still greater than b!
# (40883, 5) a is still greater than b!
# (40884, 5) a is still greater than b!
# (40885, 5) a is still greater than b!
# (40886, 5) a is still greater than b!
# (40887, 5) a is still greater than b!
# (40888, 5) a is still greater than b!
# (40889, 5) a is still greater than b!
# (40890, 5) a is still greater than b!
# (40891, 5) a is still greater than b!
# (40892, 5) a is still greater than b!
# (40893, 5) a is still greater than b!
# (40894, 5) a is still greater than b!
# (40895, 5) a is still greater than b!
# (40896, 5) a is still greater than b!
# (40897, 5) a is still greater than b!
# (40898, 5) a is still greater than b!
# (40899, 5) a is still greater than b!
# (40900, 5) a is still greater than b!
# (40901, 5) a is still greater than b!
# (40902, 5) a is still greater than b!
# (40903, 5) a is still greater than b!
# (40904, 5) a is still greater than b!
# (40905, 5) a is still greater than b!
# (40906, 5) a is still greater than b!
# (40907, 5) a is still greater than b!
# (40908, 5) a is still greater than b!
# (40909, 5) a is still greater than b!
# (40910, 5) a is still greater than b!
# (40911, 5) a is still greater than b!
# (40912, 5) a is still greater than b!
# (40913, 5) a is still greater than b!
# (40914, 5) a is still greater than b!
# (40915, 5) a is still greater than b!
# (40916, 5) a is still greater than b!
# (40917, 5) a is still greater than b!
# (40918, 5) a is still greater than b!
# (40919, 5) a is still greater than b!
# (40920, 5) a is still greater than b!
# (40921, 5) a is still greater than b!
# (40922, 5) a is still greater than b!
# (40923, 5) a is still greater than b!
# (40924, 5) a is still greater than b!
# (40925, 5) a is still greater than b!
# (40926, 5) a is still greater than b!
# (40927, 5) a is still greater than b!
# (40928, 5) a is still greater than b!
# (40929, 5) a is still greater than b!
# (40930, 5) a is still greater than b!
# (40931, 5) a is still greater than b!
# (40932, 5) a is still greater than b!
# (40933, 5) a is still greater than b!
# (40934, 5) a is still greater than b!
# (40935, 5) a is still greater than b!
# (40936, 5) a is still greater than b!
# (40937, 5) a is still greater than b!
# (40938, 5) a is still greater than b!
# (40939, 5) a is still greater than b!
# (40940, 5) a is still greater than b!
# (40941, 5) a is still greater than b!
# (40942, 5) a is still greater than b!
# (40943, 5) a is still greater than b!
# (40944, 5) a is still greater than b!
# (40945, 5) a is still greater than b!
# (40946, 5) a is still greater than b!
# (40947, 5) a is still greater than b!
# (40948, 5) a is still greater than b!
# (40949, 5) a is still greater than b!
# (40950, 5) a is still greater than b!
# (40951, 5) a is still greater than b!
# (40952, 5) a is still greater than b!
# (40953, 5) a is still greater than b!
# (40954, 5) a is still greater than b!
# (40955, 5) a is still greater than b!
# (40956, 5) a is still greater than b!
# (40957, 5) a is still greater than b!
# (40958, 5) a is still greater than b!
# (40959, 5) a is still greater than b!
# (40960, 5) a is still greater than b!
# (40961, 5) a is still greater than b!
# (40962, 5) a is still greater than b!
# (40963, 5) a is still greater than b!
# (40964, 5) a is still greater than b!
# (40965, 5) a is still greater than b!
# (40966, 5) a is still greater than b!
# (40967, 5) a is still greater than b!
# (40968, 5) a is still greater than b!
# (40969, 5) a is still greater than b!
# (40970, 5) a is still greater than b!
# (40971, 5) a is still greater than b!
# (40972, 5) a is still greater than b!
# (40973, 5) a is still greater than b!
# (40974, 5) a is still greater than b!
# (40975, 5) a is still greater than b!
# (40976, 5) a is still greater than b!
# (40977, 5) a is still greater than b!
# (40978, 5) a is still greater than b!
# (40979, 5) a is still greater than b!
# (40980, 5) a is still greater than b!
# (40981, 5) a is still greater than b!
# (40982, 5) a is still greater than b!
# (40983, 5) a is still greater than b!
# (40984, 5) a is still greater than b!
# (40985, 5) a is still greater than b!
# (40986, 5) a is still greater than b!
# (40987, 5) a is still greater than b!
# (40988, 5) a is still greater than b!
# (40989, 5) a is still greater than b!
# (40990, 5) a is still greater than b!
# (40991, 5) a is still greater than b!
# (40992, 5) a is still greater than b!
# (40993, 5) a is still greater than b!
# (40994, 5) a is still greater than b!
# (40995, 5) a is still greater than b!
# (40996, 5) a is still greater than b!
# (40997, 5) a is still greater than b!
# (40998, 5) a is still greater than b!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# X:\Temp/ipykernel_3472/3823003291.py in <module>
#       5 diff = 0
#       6 while a > b:
# ----> 7     print((a, b), "a is still greater than b!")
#       8     a += 1
#       9     diff += 1
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     527             is_child = (not self._is_master_process())
#     528             # only touch the buffer in the IO thread to avoid races
# --> 529             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     530             if is_child:
#     531                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# ~\anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     539                 )
#     540             data.group = group
# --> 541         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     542
#     543     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
