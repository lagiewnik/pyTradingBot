# %% [markdown]
# ## Trading with Python and Binance - API introduction

# %% [markdown]
# #### Testkey from: https://testnet.binance.vision/key/generate

# %%
api_key = '7BZCD18RNJcGUPYTWJJF1okfpajZZUdIXxq12JyC69neYuDkK3jzigOUhKLxujLb'
secret_key = 'IsrLOOSAfKPA7ktaF9m4lHQntbSqYoHxcICieILM4r2BqWp2e1zI6XBjuB52suja'
####Binance for Postman"
api_key = 'z2saYMAxK2iokZd8NeldiC23GA3ZJqGYn6QgI1ZeqZzLt7lnSR6IxYfO3VbKpOzh'
secret_key = 'Z1X9zKaR2IRBhwqV2xKtkhOHncXnNingJg5dzxBuekp4h6ZIDJn8AdTbq8Dmsxnt'

# %% [markdown]
# ## Creating connection

# %%
from binance.client import Client
import pandas as pd

# %%
client= Client(api_key=api_key, api_secret=secret_key, tld='com', testnet=False)

# %%
client.ping()
# Out:
# {}

# %%
client.get_system_status()
# Out:
# {'status': 0, 'msg': 'normal'}

# %%
account = client.get_account()

# %%
account
# Out:
# {'makerCommission': 10,
#  'takerCommission': 10,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'updateTime': 1643268431464,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '0.09184000', 'locked': '0.00000000'},
#   {'asset': 'NEO', 'free': '9.51242219', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '0.00000589', 'locked': '0.00000000'},
#   {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GAS', 'free': '1.38341219', 'locked': '0.00000000'},
#   {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HSR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MCO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OMG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YOYO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LRC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRX', 'free': '0.01000000', 'locked': '0.00000000'},
#   {'asset': 'SNGLS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STRAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BQX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KNC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XVG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINK', 'free': '4.23706267', 'locked': '0.00000000'},
#   {'asset': 'CVC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MTL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SALT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NULS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MTH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZEC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DGD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DASH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POWR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REQ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VEN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MOD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STORJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KMD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RCN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EDO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DATA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DLT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MANA', 'free': '264.08000000', 'locked': '0.00000000'},
#   {'asset': 'PPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RDN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AMB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GVT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XZC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QSP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LSK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TNB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LEND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CMT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAVES', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WABI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ELF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AION', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WINGS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BRD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEBL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NAV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRIG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'APPC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RLC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'INS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PIVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STEEM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NANO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BLZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SYS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RPX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NCASH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZIL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STORM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XEM', 'free': '2363.36602650', 'locked': '0.00000000'},
#   {'asset': 'WAN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WPR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QLC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GRS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CLOAK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LOOM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZEN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SKY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'THETA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOTX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QKC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NPXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KEY', 'free': '32753.19500000', 'locked': '0.00000000'},
#   {'asset': 'NAS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DENT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IQ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARDR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VET', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOCK', 'free': '50.11247730', 'locked': '0.00000000'},
#   {'asset': 'POLY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VTHO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RVN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DCR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MITH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHABC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHSV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FET', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TFUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CELR', 'free': '4860.90083010', 'locked': '0.00000000'},
#   {'asset': 'MATIC', 'free': '5.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATOM', 'free': '0.00000027', 'locked': '0.00000000'},
#   {'asset': 'PHB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FTM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDSB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHZ', 'free': '973.33540000', 'locked': '0.00000000'},
#   {'asset': 'COS', 'free': '12689.36051231', 'locked': '0.00000000'},
#   {'asset': 'ALGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ERD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOGE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BGBP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DUSK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANKR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WIN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TUSDB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COCOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PERL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TOMO', 'free': '201.49648644', 'locked': '0.00000000'},
#   {'asset': 'BUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAND', 'free': '17.46252000', 'locked': '0.00000000'},
#   {'asset': 'BEAM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HBAR', 'free': '1213.50000000', 'locked': '0.00000000'},
#   {'asset': 'XTZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NGN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DGB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NKN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GBP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EUR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LDBTC', 'free': '0.01178162', 'locked': '0.00000000'},
#   {'asset': 'KAVA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RUB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UAH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARPA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CTXC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AERGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TROY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BRL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VITE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FTT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OGN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DREP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TCT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MBL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COTI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BKRW', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HIVE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SOL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IDRT', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'CTSI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BIDR', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'STMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IRIS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MKR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DAI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADAUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADADOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINKUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINKDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RUNE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AVA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SRM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CRV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SAND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OCEAN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUNA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IDEX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RSR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PAXG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WNXM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KSM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFII', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UMA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRXUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRXDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOTUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOTDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NBS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WING', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SWRV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CREAM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNI', 'free': '21.42841000', 'locked': '0.00000000'},
#   {'asset': 'OXT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AVAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BURGER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SCRT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XVS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SPARTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALPHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ORN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UTK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'INJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FILDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FILUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CTK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EASY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUDIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AKRO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HARD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KP3R', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RENBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SLP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STRAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FOR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FRONT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ROSE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HEGIC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVEUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVEDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PROM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SKL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COVER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GHST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLMUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLMDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JUV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PSG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BVND', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'GRT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CELO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TWT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REEF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ASR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LD1INCH', 'free': '160.88134732', 'locked': '0.00000000'},
#   {'asset': 'RIF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRU', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DEXE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CKB', 'free': '13875.11700000', 'locked': '0.00000000'},
#   {'asset': 'FIRO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LIT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PROS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VAI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SFP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DODO', 'free': '65.71713808', 'locked': '0.00000000'},
#   {'asset': 'AUCTION', 'free': '9.03395820', 'locked': '0.00000000'},
#   {'asset': 'UFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TVK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BADGER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALICE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DEGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BIFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PERP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUPER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CFX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TKO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EPS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PUNDIX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MIR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FORTH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SHIB', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'GYEN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POLS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LDCOMP', 'free': '0.40026273', 'locked': '0.00000000'},
#   {'asset': 'LDDOCK', 'free': '5657.53424656', 'locked': '0.00000000'},
#   {'asset': 'MASK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGIX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NU', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KLAY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TORN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LDCOCOS', 'free': '0.19883374', 'locked': '0.00000000'},
#   {'asset': 'KEEP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ERN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BOND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MLN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'C98', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLOW', 'free': '10.82000000', 'locked': '0.00000000'},
#   {'asset': 'QUICK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MINA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CLV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XEC', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'ALPACA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FARM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VGX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MBOX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAXP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GNO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DYDX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GALA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ILV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YGG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BETA', 'free': '8.59949553', 'locked': '0.00000000'},
#   {'asset': 'RAD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RARE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SSV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LAZIO', 'free': '1.05252793', 'locked': '0.00000000'},
#   {'asset': 'MOVR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHESS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DAR', 'free': '2.74688571', 'locked': '0.00000000'},
#   {'asset': 'ACA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RGT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CITY', 'free': '0.27273870', 'locked': '0.00000000'},
#   {'asset': 'ENS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PORTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JASMY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PLA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PYR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SANTOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RNDR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALCX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MC', 'free': '0.00004272', 'locked': '0.00000000'},
#   {'asset': 'ANY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VOXEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BICO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLUX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HIGH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OOKI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PEOPLE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SPELL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JOE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GLMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LOKA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTTC', 'free': '0.0', 'locked': '0.0'},
#   {'asset': 'ANC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'API3', 'free': '0.00000000', 'locked': '0.00000000'}],
#  'permissions': ['SPOT']}

# %%
account["accountType"]
# Out:
# 'SPOT'

# %%
account["balances"]
# Out:
# [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETH', 'free': '0.09184000', 'locked': '0.00000000'},
#  {'asset': 'NEO', 'free': '9.51242219', 'locked': '0.00000000'},
#  {'asset': 'BNB', 'free': '0.00000589', 'locked': '0.00000000'},
#  {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GAS', 'free': '1.38341219', 'locked': '0.00000000'},
#  {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HSR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OAX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MCO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ICN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OMG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YOYO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LRC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRX', 'free': '0.01000000', 'locked': '0.00000000'},
#  {'asset': 'SNGLS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STRAT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BQX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FUN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KNC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CDT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XVG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IOTA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SNM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LINK', 'free': '4.23706267', 'locked': '0.00000000'},
#  {'asset': 'CVC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MDA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MTL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SALT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NULS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MTH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ADX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ENG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZEC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DGD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DASH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POWR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REQ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XMR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EVX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VIB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ENJ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VEN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MOD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STORJ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KMD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RCN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EDO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DATA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DLT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MANA', 'free': '264.08000000', 'locked': '0.00000000'},
#  {'asset': 'PPT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RDN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AMB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCPT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GVT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XZC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QSP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LSK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TNB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ADA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LEND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XLM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CMT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WAVES', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WABI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GTO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ICX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ELF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AION', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WINGS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BRD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NEBL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NAV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LUN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRIG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'APPC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CHAT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RLC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'INS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PIVX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IOST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STEEM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NANO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VIA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BLZ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SYS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RPX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NCASH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ONT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZIL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STORM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XEM', 'free': '2363.36602650', 'locked': '0.00000000'},
#  {'asset': 'WAN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WPR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QLC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GRS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CLOAK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LOOM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZEN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SKY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'THETA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IOTX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QKC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AGI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NPXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KEY', 'free': '32753.19500000', 'locked': '0.00000000'},
#  {'asset': 'NAS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MFT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DENT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IQ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARDR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HOT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VET', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOCK', 'free': '50.11247730', 'locked': '0.00000000'},
#  {'asset': 'POLY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VTHO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ONG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PHX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PAX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RVN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DCR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MITH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHABC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHSV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FET', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TFUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CELR', 'free': '4860.90083010', 'locked': '0.00000000'},
#  {'asset': 'MATIC', 'free': '5.00000000', 'locked': '0.00000000'},
#  {'asset': 'ATOM', 'free': '0.00000027', 'locked': '0.00000000'},
#  {'asset': 'PHB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ONE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FTM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTCB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDSB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CHZ', 'free': '973.33540000', 'locked': '0.00000000'},
#  {'asset': 'COS', 'free': '12689.36051231', 'locked': '0.00000000'},
#  {'asset': 'ALGO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ERD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOGE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BGBP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DUSK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ANKR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WIN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TUSDB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COCOS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PERL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TOMO', 'free': '201.49648644', 'locked': '0.00000000'},
#  {'asset': 'BUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAND', 'free': '17.46252000', 'locked': '0.00000000'},
#  {'asset': 'BEAM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HBAR', 'free': '1213.50000000', 'locked': '0.00000000'},
#  {'asset': 'XTZ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NGN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DGB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NKN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GBP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EUR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LDBTC', 'free': '0.01178162', 'locked': '0.00000000'},
#  {'asset': 'KAVA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RUB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UAH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARPA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CTXC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AERGO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TROY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BRL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VITE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FTT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AUD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OGN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DREP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETHBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETHBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRPBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRPBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOSBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOSBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TCT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WRX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MBL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COTI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BKRW', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNBBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNBBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HIVE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STPT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SOL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IDRT', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'CTSI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CHR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BIDR', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'STMX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MDT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COMP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IRIS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MKR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SXP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SNX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DAI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ADAUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ADADOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LINKUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LINKDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RUNE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNBUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNBDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XTZUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XTZDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AVA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YFI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SRM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ANT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CRV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SAND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OCEAN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NMR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LUNA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IDEX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RSR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PAXG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WNXM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KSM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUSHI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YFII', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DIA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BEL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UMA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOSUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRXUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOSDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRXDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOTUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOTDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NBS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WING', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SWRV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CREAM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UNI', 'free': '21.42841000', 'locked': '0.00000000'},
#  {'asset': 'OXT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AVAX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BURGER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FLM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SCRT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XVS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SPARTA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UNIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UNIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALPHA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ORN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UTK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VIDT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AAVE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SXPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SXPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'INJ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FILDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FILUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YFIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YFIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CTK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EASY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AUDIO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BOT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AKRO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HARD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KP3R', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RENBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SLP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STRAX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UNFI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CVP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FOR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FRONT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ROSE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MDX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HEGIC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AAVEUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AAVEDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PROM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BETH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SKL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GLM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COVER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GHST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUSHIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUSHIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XLMUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XLMDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JUV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PSG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BVND', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'GRT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CELO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TWT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REEF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ATM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ASR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': '1INCH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LD1INCH', 'free': '160.88134732', 'locked': '0.00000000'},
#  {'asset': 'RIF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTCST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRU', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DEXE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CKB', 'free': '13875.11700000', 'locked': '0.00000000'},
#  {'asset': 'FIRO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LIT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PROS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VAI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SFP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DODO', 'free': '65.71713808', 'locked': '0.00000000'},
#  {'asset': 'AUCTION', 'free': '9.03395820', 'locked': '0.00000000'},
#  {'asset': 'UFT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ACM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PHA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TVK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BADGER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALICE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DEGO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BIFI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LINA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PERP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RAMP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUPER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CFX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TKO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AUTO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EPS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PUNDIX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TLM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': '1INCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': '1INCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MIR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FORTH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EZ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ICP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SHIB', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'GYEN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POLS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LDCOMP', 'free': '0.40026273', 'locked': '0.00000000'},
#  {'asset': 'LDDOCK', 'free': '5657.53424656', 'locked': '0.00000000'},
#  {'asset': 'MASK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LPT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AGIX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ATA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NU', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KLAY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TORN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LDCOCOS', 'free': '0.19883374', 'locked': '0.00000000'},
#  {'asset': 'KEEP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ERN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BOND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MLN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'C98', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FLOW', 'free': '10.82000000', 'locked': '0.00000000'},
#  {'asset': 'QUICK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RAY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MINA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CLV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XEC', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'ALPACA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FARM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VGX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MBOX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WAXP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GNO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DYDX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GALA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ILV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YGG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIDA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BETA', 'free': '8.59949553', 'locked': '0.00000000'},
#  {'asset': 'RAD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RARE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SSV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LAZIO', 'free': '1.05252793', 'locked': '0.00000000'},
#  {'asset': 'MOVR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CHESS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DAR', 'free': '2.74688571', 'locked': '0.00000000'},
#  {'asset': 'ACA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RGT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CITY', 'free': '0.27273870', 'locked': '0.00000000'},
#  {'asset': 'ENS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PORTO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JASMY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AMP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PLA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PYR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SANTOS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RNDR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALCX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MC', 'free': '0.00004272', 'locked': '0.00000000'},
#  {'asset': 'ANY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VOXEL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BICO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FLUX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HIGH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OOKI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CVX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PEOPLE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SPELL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JOE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GLMR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ACH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IMX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LOKA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTTC', 'free': '0.0', 'locked': '0.0'},
#  {'asset': 'ANC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'API3', 'free': '0.00000000', 'locked': '0.00000000'}]

# %%
pd.to_datetime(account["updateTime"], unit="ms")
# Out:
# Timestamp('2022-01-27 07:27:11.464000')

# %%
df= pd.DataFrame(account["balances"])

# %%
df
# Out:
#     asset        free      locked
# 0     BTC  0.00000000  0.00000000
# 1     LTC  0.00000000  0.00000000
# 2     ETH  0.09184000  0.00000000
# 3     NEO  9.51242219  0.00000000
# 4     BNB  0.00000589  0.00000000
# ..    ...         ...         ...
# 494   IMX  0.00000000  0.00000000
# 495  LOKA  0.00000000  0.00000000
# 496  BTTC         0.0         0.0
# 497   ANC  0.00000000  0.00000000
# 498  API3  0.00000000  0.00000000
#
# [499 rows x 3 columns]

# %%
df.free = pd.to_numeric(df.free, errors="coerce")
df.locked = pd.to_numeric(df.locked, errors="coerce")

# %%
df.loc[df.free>0]
# Out:
#        asset          free  locked
# 2        ETH  9.184000e-02     0.0
# 3        NEO  9.512422e+00     0.0
# 4        BNB  5.890000e-06     0.0
# 9        GAS  1.383412e+00     0.0
# 22       TRX  1.000000e-02     0.0
# 32      LINK  4.237063e+00     0.0
# 69      MANA  2.640800e+02     0.0
# 122      XEM  2.363366e+03     0.0
# 140      KEY  3.275319e+04     0.0
# 148     DOCK  5.011248e+01     0.0
# 167     CELR  4.860901e+03     0.0
# 168    MATIC  5.000000e+00     0.0
# 169     ATOM  2.700000e-07     0.0
# 175      CHZ  9.733354e+02     0.0
# 176      COS  1.268936e+04     0.0
# 187     TOMO  2.014965e+02     0.0
# 189     BAND  1.746252e+01     0.0
# 191     HBAR  1.213500e+03     0.0
# 198    LDBTC  1.178162e-02     0.0
# 302      UNI  2.142841e+01     0.0
# 375  LD1INCH  1.608813e+02     0.0
# 380      CKB  1.387512e+04     0.0
# 387     DODO  6.571714e+01     0.0
# 388  AUCTION  9.033958e+00     0.0
# 422   LDCOMP  4.002627e-01     0.0
# 423   LDDOCK  5.657534e+03     0.0
# 432  LDCOCOS  1.988337e-01     0.0
# 438     FLOW  1.082000e+01     0.0
# 459     BETA  8.599496e+00     0.0
# 463    LAZIO  1.052528e+00     0.0
# 466      DAR  2.746886e+00     0.0
# 470     CITY  2.727387e-01     0.0
# 480       MC  4.272000e-05     0.0

# %%
df.loc[df.locked>0]
# Out:
# Empty DataFrame
# Columns: [asset, free, locked]
# Index: []

# %%
client.get_asset_balance(asset="MANA")
# Out:
# {'asset': 'MANA', 'free': '264.08000000', 'locked': '0.00000000'}

# %%
float(client.get_asset_balance(asset="MANA")["free"])
# Out:
# 264.08

# %%
snap = client.get_account_snapshot(type="SPOT")

# %%
snap
# Out:
# {'code': 200,
#  'msg': '',
#  'snapshotVos': [{'type': 'spot',
#    'updateTime': 1642723199000,
#    'data': {'totalAssetOfBtc': '0.09440739',
#     'balances': [{'asset': '1INCH', 'free': '0', 'locked': '0'},
#      {'asset': 'ADA', 'free': '0', 'locked': '0'},
#      {'asset': 'ADD', 'free': '0', 'locked': '0'},
#      {'asset': 'ADXOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ANTOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ATD', 'free': '0', 'locked': '0'},
#      {'asset': 'ATOM', 'free': '0.00000027', 'locked': '0'},
#      {'asset': 'AUCTION', 'free': '9.0339582', 'locked': '0'},
#      {'asset': 'BAND', 'free': '17.46252', 'locked': '0'},
#      {'asset': 'BCX', 'free': '0', 'locked': '0'},
#      {'asset': 'BETA', 'free': '8.59949553', 'locked': '0'},
#      {'asset': 'BGN', 'free': '0', 'locked': '0'},
#      {'asset': 'BLZ', 'free': '0', 'locked': '0'},
#      {'asset': 'BNB', 'free': '0.00000589', 'locked': '0'},
#      {'asset': 'BTC', 'free': '0', 'locked': '0'},
#      {'asset': 'BTM', 'free': '0', 'locked': '0'},
#      {'asset': 'BUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'CBK', 'free': '0', 'locked': '0'},
#      {'asset': 'CBM', 'free': '0', 'locked': '0'},
#      {'asset': 'CELR', 'free': '41.41901764', 'locked': '0'},
#      {'asset': 'CHZ', 'free': '973.3354', 'locked': '0'},
#      {'asset': 'CITY', 'free': '0.2727387', 'locked': '0'},
#      {'asset': 'CKB', 'free': '13875.117', 'locked': '0'},
#      {'asset': 'COCOS', 'free': '0', 'locked': '0'},
#      {'asset': 'COMP', 'free': '0', 'locked': '0'},
#      {'asset': 'COS', 'free': '12689.36051231', 'locked': '0'},
#      {'asset': 'COTI', 'free': '0', 'locked': '0'},
#      {'asset': 'CTR', 'free': '0', 'locked': '0'},
#      {'asset': 'DAR', 'free': '2.74688571', 'locked': '0'},
#      {'asset': 'DASH', 'free': '0', 'locked': '0'},
#      {'asset': 'DIA', 'free': '0', 'locked': '0'},
#      {'asset': 'DOCK', 'free': '50.10178459', 'locked': '0'},
#      {'asset': 'DODO', 'free': '1.05629916', 'locked': '0'},
#      {'asset': 'DOT', 'free': '0', 'locked': '0'},
#      {'asset': 'EGLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ENJ', 'free': '0', 'locked': '0'},
#      {'asset': 'EON', 'free': '0', 'locked': '0'},
#      {'asset': 'EOP', 'free': '0', 'locked': '0'},
#      {'asset': 'ETF', 'free': '0', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0.09184', 'locked': '0'},
#      {'asset': 'ETHBNT', 'free': '0', 'locked': '0'},
#      {'asset': 'EUR', 'free': '0', 'locked': '0'},
#      {'asset': 'FLOW', 'free': '10.82', 'locked': '0'},
#      {'asset': 'GAS', 'free': '1.38341219', 'locked': '0'},
#      {'asset': 'GRTDOWN', 'free': '0', 'locked': '0'},
#      {'asset': 'GRTUP', 'free': '0', 'locked': '0'},
#      {'asset': 'HBAR', 'free': '1213.5', 'locked': '0'},
#      {'asset': 'HCC', 'free': '0', 'locked': '0'},
#      {'asset': 'HKD', 'free': '0', 'locked': '0'},
#      {'asset': 'HRK', 'free': '0', 'locked': '0'},
#      {'asset': 'INR', 'free': '0', 'locked': '0'},
#      {'asset': 'IOTA', 'free': '0', 'locked': '0'},
#      {'asset': 'JEX', 'free': '0', 'locked': '0'},
#      {'asset': 'KES', 'free': '0', 'locked': '0'},
#      {'asset': 'KEY', 'free': '32753.195', 'locked': '0'},
#      {'asset': 'KNC', 'free': '0', 'locked': '0'},
#      {'asset': 'KZT', 'free': '0', 'locked': '0'},
#      {'asset': 'LAZIO', 'free': '1.05252793', 'locked': '0'},
#      {'asset': 'LD1INCH', 'free': '160.77965514', 'locked': '0'},
#      {'asset': 'LD789', 'free': '0', 'locked': '0'},
#      {'asset': 'LDADA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDALGO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDARK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDATOM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAKE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAKET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAND', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBANK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBCH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBNB', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBRL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBTC', 'free': '0.01177175', 'locked': '0'},
#      {'asset': 'LDBUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDCOCOS', 'free': '0.19879566', 'locked': '0'},
#      {'asset': 'LDCOMP', 'free': '0.40018601', 'locked': '0'},
#      {'asset': 'LDCOTI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDCVC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDAI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDASH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDOCK', 'free': '5657.53424656', 'locked': '0'},
#      {'asset': 'LDDOGE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDOT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDEOS', 'free': '0', 'locked': '0'},
#      {'asset': 'LDERD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDETC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDETH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDEUR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDFET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDFIL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDGBP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDIOST', 'free': '0', 'locked': '0'},
#      {'asset': 'LDIOTA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKAVA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKMD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKNC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLEND', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLINK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLOOM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLSK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLTC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDMATIC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDNEO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDNGN', 'free': '0', 'locked': '0'},
#      {'asset': 'LDONE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDONT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDQTUM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDRUB', 'free': '0', 'locked': '0'},
#      {'asset': 'LDSTRAT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDSXP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTHETA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTOMO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTROY', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTRX', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUNI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUSDC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUSDT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDVET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDWAVES', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXLM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXMR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXRP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXTZ', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZEC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZIL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZRX', 'free': '0', 'locked': '0'},
#      {'asset': 'LINK', 'free': '4.23706267', 'locked': '0'},
#      {'asset': 'LIT', 'free': '0', 'locked': '0'},
#      {'asset': 'LLT', 'free': '0', 'locked': '0'},
#      {'asset': 'LTC', 'free': '0', 'locked': '0'},
#      {'asset': 'LUNA', 'free': '0', 'locked': '0'},
#      {'asset': 'MANA', 'free': '264.08', 'locked': '0'},
#      {'asset': 'MATIC', 'free': '5', 'locked': '0'},
#      {'asset': 'MC', 'free': '0.00004272', 'locked': '0'},
#      {'asset': 'MEETONE', 'free': '0', 'locked': '0'},
#      {'asset': 'MXN', 'free': '0', 'locked': '0'},
#      {'asset': 'NANO', 'free': '0', 'locked': '0'},
#      {'asset': 'NEO', 'free': '9.51242219', 'locked': '0'},
#      {'asset': 'NOK', 'free': '0', 'locked': '0'},
#      {'asset': 'NVT', 'free': '0', 'locked': '0'},
#      {'asset': 'OCEAN', 'free': '0', 'locked': '0'},
#      {'asset': 'OMG', 'free': '0', 'locked': '0'},
#      {'asset': 'ONT', 'free': '0', 'locked': '0'},
#      {'asset': 'ONX', 'free': '0', 'locked': '0'},
#      {'asset': 'PEN', 'free': '0', 'locked': '0'},
#      {'asset': 'PERLOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'POLS', 'free': '0', 'locked': '0'},
#      {'asset': 'REEF', 'free': '0', 'locked': '0'},
#      {'asset': 'REN', 'free': '0', 'locked': '0'},
#      {'asset': 'REPV1', 'free': '0', 'locked': '0'},
#      {'asset': 'RLC', 'free': '0', 'locked': '0'},
#      {'asset': 'ROSE', 'free': '0', 'locked': '0'},
#      {'asset': 'SBTC', 'free': '0', 'locked': '0'},
#      {'asset': 'SFP', 'free': '0', 'locked': '0'},
#      {'asset': 'SGT', 'free': '0', 'locked': '0'},
#      {'asset': 'SRM', 'free': '0', 'locked': '0'},
#      {'asset': 'STMX', 'free': '0', 'locked': '0'},
#      {'asset': 'TLDBTC', 'free': '0', 'locked': '0'},
#      {'asset': 'TOMO', 'free': '201.49648644', 'locked': '0'},
#      {'asset': 'TRX', 'free': '0.01', 'locked': '0'},
#      {'asset': 'UGX', 'free': '0', 'locked': '0'},
#      {'asset': 'UNI', 'free': '21.42841', 'locked': '0'},
#      {'asset': 'USDT', 'free': '0', 'locked': '0'},
#      {'asset': 'VET', 'free': '0', 'locked': '0'},
#      {'asset': 'VITE', 'free': '0', 'locked': '0'},
#      {'asset': 'WAN', 'free': '0', 'locked': '0'},
#      {'asset': 'WAXP', 'free': '0', 'locked': '0'},
#      {'asset': 'WBNB', 'free': '0', 'locked': '0'},
#      {'asset': 'WING', 'free': '0', 'locked': '0'},
#      {'asset': 'XEM', 'free': '2363.3660265', 'locked': '0'},
#      {'asset': 'XPR', 'free': '0', 'locked': '0'},
#      {'asset': 'XRP', 'free': '0', 'locked': '0'},
#      {'asset': 'YFII', 'free': '0', 'locked': '0'},
#      {'asset': 'ZIL', 'free': '0', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1642809599000,
#    'data': {'totalAssetOfBtc': '0.09009837',
#     'balances': [{'asset': '1INCH', 'free': '0', 'locked': '0'},
#      {'asset': 'ADA', 'free': '0', 'locked': '0'},
#      {'asset': 'ADD', 'free': '0', 'locked': '0'},
#      {'asset': 'ADXOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ANTOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ATD', 'free': '0', 'locked': '0'},
#      {'asset': 'ATOM', 'free': '0.00000027', 'locked': '0'},
#      {'asset': 'AUCTION', 'free': '9.0339582', 'locked': '0'},
#      {'asset': 'BAND', 'free': '17.46252', 'locked': '0'},
#      {'asset': 'BCX', 'free': '0', 'locked': '0'},
#      {'asset': 'BETA', 'free': '8.59949553', 'locked': '0'},
#      {'asset': 'BGN', 'free': '0', 'locked': '0'},
#      {'asset': 'BLZ', 'free': '0', 'locked': '0'},
#      {'asset': 'BNB', 'free': '0.00000589', 'locked': '0'},
#      {'asset': 'BTC', 'free': '0', 'locked': '0'},
#      {'asset': 'BTM', 'free': '0', 'locked': '0'},
#      {'asset': 'BUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'CBK', 'free': '0', 'locked': '0'},
#      {'asset': 'CBM', 'free': '0', 'locked': '0'},
#      {'asset': 'CELR', 'free': '42.89826827', 'locked': '0'},
#      {'asset': 'CHZ', 'free': '973.3354', 'locked': '0'},
#      {'asset': 'CITY', 'free': '0.2727387', 'locked': '0'},
#      {'asset': 'CKB', 'free': '13875.117', 'locked': '0'},
#      {'asset': 'COCOS', 'free': '0', 'locked': '0'},
#      {'asset': 'COMP', 'free': '0', 'locked': '0'},
#      {'asset': 'COS', 'free': '12689.36051231', 'locked': '0'},
#      {'asset': 'COTI', 'free': '0', 'locked': '0'},
#      {'asset': 'CTR', 'free': '0', 'locked': '0'},
#      {'asset': 'DAR', 'free': '2.74688571', 'locked': '0'},
#      {'asset': 'DASH', 'free': '0', 'locked': '0'},
#      {'asset': 'DIA', 'free': '0', 'locked': '0'},
#      {'asset': 'DOCK', 'free': '50.10331212', 'locked': '0'},
#      {'asset': 'DODO', 'free': '1.09402413', 'locked': '0'},
#      {'asset': 'DOT', 'free': '0', 'locked': '0'},
#      {'asset': 'EGLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ENJ', 'free': '0', 'locked': '0'},
#      {'asset': 'EON', 'free': '0', 'locked': '0'},
#      {'asset': 'EOP', 'free': '0', 'locked': '0'},
#      {'asset': 'ETF', 'free': '0', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0.09184', 'locked': '0'},
#      {'asset': 'ETHBNT', 'free': '0', 'locked': '0'},
#      {'asset': 'EUR', 'free': '0', 'locked': '0'},
#      {'asset': 'FLOW', 'free': '10.82', 'locked': '0'},
#      {'asset': 'GAS', 'free': '1.38341219', 'locked': '0'},
#      {'asset': 'GRTDOWN', 'free': '0', 'locked': '0'},
#      {'asset': 'GRTUP', 'free': '0', 'locked': '0'},
#      {'asset': 'HBAR', 'free': '1213.5', 'locked': '0'},
#      {'asset': 'HCC', 'free': '0', 'locked': '0'},
#      {'asset': 'HKD', 'free': '0', 'locked': '0'},
#      {'asset': 'HRK', 'free': '0', 'locked': '0'},
#      {'asset': 'INR', 'free': '0', 'locked': '0'},
#      {'asset': 'IOTA', 'free': '0', 'locked': '0'},
#      {'asset': 'JEX', 'free': '0', 'locked': '0'},
#      {'asset': 'KES', 'free': '0', 'locked': '0'},
#      {'asset': 'KEY', 'free': '32753.195', 'locked': '0'},
#      {'asset': 'KNC', 'free': '0', 'locked': '0'},
#      {'asset': 'KZT', 'free': '0', 'locked': '0'},
#      {'asset': 'LAZIO', 'free': '1.05252793', 'locked': '0'},
#      {'asset': 'LD1INCH', 'free': '160.79417866', 'locked': '0'},
#      {'asset': 'LD789', 'free': '0', 'locked': '0'},
#      {'asset': 'LDADA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDALGO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDARK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDATOM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAKE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAKET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAND', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBANK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBCH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBNB', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBRL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBTC', 'free': '0.01177316', 'locked': '0'},
#      {'asset': 'LDBUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDCOCOS', 'free': '0.1988011', 'locked': '0'},
#      {'asset': 'LDCOMP', 'free': '0.40019697', 'locked': '0'},
#      {'asset': 'LDCOTI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDCVC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDAI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDASH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDOCK', 'free': '5657.53424656', 'locked': '0'},
#      {'asset': 'LDDOGE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDOT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDEOS', 'free': '0', 'locked': '0'},
#      {'asset': 'LDERD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDETC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDETH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDEUR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDFET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDFIL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDGBP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDIOST', 'free': '0', 'locked': '0'},
#      {'asset': 'LDIOTA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKAVA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKMD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKNC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLEND', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLINK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLOOM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLSK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLTC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDMATIC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDNEO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDNGN', 'free': '0', 'locked': '0'},
#      {'asset': 'LDONE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDONT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDQTUM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDRUB', 'free': '0', 'locked': '0'},
#      {'asset': 'LDSTRAT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDSXP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTHETA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTOMO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTROY', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTRX', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUNI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUSDC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUSDT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDVET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDWAVES', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXLM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXMR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXRP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXTZ', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZEC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZIL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZRX', 'free': '0', 'locked': '0'},
#      {'asset': 'LINK', 'free': '4.23706267', 'locked': '0'},
#      {'asset': 'LIT', 'free': '0', 'locked': '0'},
#      {'asset': 'LLT', 'free': '0', 'locked': '0'},
#      {'asset': 'LTC', 'free': '0', 'locked': '0'},
#      {'asset': 'LUNA', 'free': '0', 'locked': '0'},
#      {'asset': 'MANA', 'free': '264.08', 'locked': '0'},
#      {'asset': 'MATIC', 'free': '5', 'locked': '0'},
#      {'asset': 'MC', 'free': '0.00004272', 'locked': '0'},
#      {'asset': 'MEETONE', 'free': '0', 'locked': '0'},
#      {'asset': 'MXN', 'free': '0', 'locked': '0'},
#      {'asset': 'NANO', 'free': '0', 'locked': '0'},
#      {'asset': 'NEO', 'free': '9.51242219', 'locked': '0'},
#      {'asset': 'NOK', 'free': '0', 'locked': '0'},
#      {'asset': 'NVT', 'free': '0', 'locked': '0'},
#      {'asset': 'OCEAN', 'free': '0', 'locked': '0'},
#      {'asset': 'OMG', 'free': '0', 'locked': '0'},
#      {'asset': 'ONT', 'free': '0', 'locked': '0'},
#      {'asset': 'ONX', 'free': '0', 'locked': '0'},
#      {'asset': 'PEN', 'free': '0', 'locked': '0'},
#      {'asset': 'PERLOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'POLS', 'free': '0', 'locked': '0'},
#      {'asset': 'REEF', 'free': '0', 'locked': '0'},
#      {'asset': 'REN', 'free': '0', 'locked': '0'},
#      {'asset': 'REPV1', 'free': '0', 'locked': '0'},
#      {'asset': 'RLC', 'free': '0', 'locked': '0'},
#      {'asset': 'ROSE', 'free': '0', 'locked': '0'},
#      {'asset': 'SBTC', 'free': '0', 'locked': '0'},
#      {'asset': 'SFP', 'free': '0', 'locked': '0'},
#      {'asset': 'SGT', 'free': '0', 'locked': '0'},
#      {'asset': 'SRM', 'free': '0', 'locked': '0'},
#      {'asset': 'STMX', 'free': '0', 'locked': '0'},
#      {'asset': 'TLDBTC', 'free': '0', 'locked': '0'},
#      {'asset': 'TOMO', 'free': '201.49648644', 'locked': '0'},
#      {'asset': 'TRX', 'free': '0.01', 'locked': '0'},
#      {'asset': 'UGX', 'free': '0', 'locked': '0'},
#      {'asset': 'UNI', 'free': '21.42841', 'locked': '0'},
#      {'asset': 'USDT', 'free': '0', 'locked': '0'},
#      {'asset': 'VET', 'free': '0', 'locked': '0'},
#      {'asset': 'VITE', 'free': '0', 'locked': '0'},
#      {'asset': 'WAN', 'free': '0', 'locked': '0'},
#      {'asset': 'WAXP', 'free': '0', 'locked': '0'},
#      {'asset': 'WBNB', 'free': '0', 'locked': '0'},
#      {'asset': 'WING', 'free': '0', 'locked': '0'},
#      {'asset': 'XEM', 'free': '2363.3660265', 'locked': '0'},
#      {'asset': 'XPR', 'free': '0', 'locked': '0'},
#      {'asset': 'XRP', 'free': '0', 'locked': '0'},
#      {'asset': 'YFII', 'free': '0', 'locked': '0'},
#      {'asset': 'ZIL', 'free': '0', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1642895999000,
#    'data': {'totalAssetOfBtc': '0.08475044',
#     'balances': [{'asset': '1INCH', 'free': '0', 'locked': '0'},
#      {'asset': 'ADA', 'free': '0', 'locked': '0'},
#      {'asset': 'ADD', 'free': '0', 'locked': '0'},
#      {'asset': 'ADXOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ANTOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ATD', 'free': '0', 'locked': '0'},
#      {'asset': 'ATOM', 'free': '0.00000027', 'locked': '0'},
#      {'asset': 'AUCTION', 'free': '9.0339582', 'locked': '0'},
#      {'asset': 'BAND', 'free': '17.46252', 'locked': '0'},
#      {'asset': 'BCX', 'free': '0', 'locked': '0'},
#      {'asset': 'BETA', 'free': '8.59949553', 'locked': '0'},
#      {'asset': 'BGN', 'free': '0', 'locked': '0'},
#      {'asset': 'BLZ', 'free': '0', 'locked': '0'},
#      {'asset': 'BNB', 'free': '0.00000589', 'locked': '0'},
#      {'asset': 'BTC', 'free': '0', 'locked': '0'},
#      {'asset': 'BTM', 'free': '0', 'locked': '0'},
#      {'asset': 'BUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'CBK', 'free': '0', 'locked': '0'},
#      {'asset': 'CBM', 'free': '0', 'locked': '0'},
#      {'asset': 'CELR', 'free': '44.3775189', 'locked': '0'},
#      {'asset': 'CHZ', 'free': '973.3354', 'locked': '0'},
#      {'asset': 'CITY', 'free': '0.2727387', 'locked': '0'},
#      {'asset': 'CKB', 'free': '13875.117', 'locked': '0'},
#      {'asset': 'COCOS', 'free': '0', 'locked': '0'},
#      {'asset': 'COMP', 'free': '0', 'locked': '0'},
#      {'asset': 'COS', 'free': '12689.36051231', 'locked': '0'},
#      {'asset': 'COTI', 'free': '0', 'locked': '0'},
#      {'asset': 'CTR', 'free': '0', 'locked': '0'},
#      {'asset': 'DAR', 'free': '2.74688571', 'locked': '0'},
#      {'asset': 'DASH', 'free': '0', 'locked': '0'},
#      {'asset': 'DIA', 'free': '0', 'locked': '0'},
#      {'asset': 'DOCK', 'free': '50.10483965', 'locked': '0'},
#      {'asset': 'DODO', 'free': '1.1317491', 'locked': '0'},
#      {'asset': 'DOT', 'free': '0', 'locked': '0'},
#      {'asset': 'EGLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ENJ', 'free': '0', 'locked': '0'},
#      {'asset': 'EON', 'free': '0', 'locked': '0'},
#      {'asset': 'EOP', 'free': '0', 'locked': '0'},
#      {'asset': 'ETF', 'free': '0', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0.09184', 'locked': '0'},
#      {'asset': 'ETHBNT', 'free': '0', 'locked': '0'},
#      {'asset': 'EUR', 'free': '0', 'locked': '0'},
#      {'asset': 'FLOW', 'free': '10.82', 'locked': '0'},
#      {'asset': 'GAS', 'free': '1.38341219', 'locked': '0'},
#      {'asset': 'GRTDOWN', 'free': '0', 'locked': '0'},
#      {'asset': 'GRTUP', 'free': '0', 'locked': '0'},
#      {'asset': 'HBAR', 'free': '1213.5', 'locked': '0'},
#      {'asset': 'HCC', 'free': '0', 'locked': '0'},
#      {'asset': 'HKD', 'free': '0', 'locked': '0'},
#      {'asset': 'HRK', 'free': '0', 'locked': '0'},
#      {'asset': 'INR', 'free': '0', 'locked': '0'},
#      {'asset': 'IOTA', 'free': '0', 'locked': '0'},
#      {'asset': 'JEX', 'free': '0', 'locked': '0'},
#      {'asset': 'KES', 'free': '0', 'locked': '0'},
#      {'asset': 'KEY', 'free': '32753.195', 'locked': '0'},
#      {'asset': 'KNC', 'free': '0', 'locked': '0'},
#      {'asset': 'KZT', 'free': '0', 'locked': '0'},
#      {'asset': 'LAZIO', 'free': '1.05252793', 'locked': '0'},
#      {'asset': 'LD1INCH', 'free': '160.80870349', 'locked': '0'},
#      {'asset': 'LD789', 'free': '0', 'locked': '0'},
#      {'asset': 'LDADA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDALGO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDARK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDATOM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAKE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAKET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAND', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBANK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBCH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBNB', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBRL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBTC', 'free': '0.01177457', 'locked': '0'},
#      {'asset': 'LDBUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDCOCOS', 'free': '0.19880654', 'locked': '0'},
#      {'asset': 'LDCOMP', 'free': '0.40020793', 'locked': '0'},
#      {'asset': 'LDCOTI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDCVC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDAI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDASH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDOCK', 'free': '5657.53424656', 'locked': '0'},
#      {'asset': 'LDDOGE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDOT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDEOS', 'free': '0', 'locked': '0'},
#      {'asset': 'LDERD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDETC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDETH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDEUR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDFET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDFIL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDGBP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDIOST', 'free': '0', 'locked': '0'},
#      {'asset': 'LDIOTA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKAVA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKMD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKNC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLEND', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLINK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLOOM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLSK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLTC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDMATIC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDNEO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDNGN', 'free': '0', 'locked': '0'},
#      {'asset': 'LDONE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDONT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDQTUM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDRUB', 'free': '0', 'locked': '0'},
#      {'asset': 'LDSTRAT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDSXP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTHETA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTOMO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTROY', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTRX', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUNI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUSDC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUSDT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDVET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDWAVES', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXLM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXMR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXRP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXTZ', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZEC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZIL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZRX', 'free': '0', 'locked': '0'},
#      {'asset': 'LINK', 'free': '4.23706267', 'locked': '0'},
#      {'asset': 'LIT', 'free': '0', 'locked': '0'},
#      {'asset': 'LLT', 'free': '0', 'locked': '0'},
#      {'asset': 'LTC', 'free': '0', 'locked': '0'},
#      {'asset': 'LUNA', 'free': '0', 'locked': '0'},
#      {'asset': 'MANA', 'free': '264.08', 'locked': '0'},
#      {'asset': 'MATIC', 'free': '5', 'locked': '0'},
#      {'asset': 'MC', 'free': '0.00004272', 'locked': '0'},
#      {'asset': 'MEETONE', 'free': '0', 'locked': '0'},
#      {'asset': 'MXN', 'free': '0', 'locked': '0'},
#      {'asset': 'NANO', 'free': '0', 'locked': '0'},
#      {'asset': 'NEO', 'free': '9.51242219', 'locked': '0'},
#      {'asset': 'NOK', 'free': '0', 'locked': '0'},
#      {'asset': 'NVT', 'free': '0', 'locked': '0'},
#      {'asset': 'OCEAN', 'free': '0', 'locked': '0'},
#      {'asset': 'OMG', 'free': '0', 'locked': '0'},
#      {'asset': 'ONT', 'free': '0', 'locked': '0'},
#      {'asset': 'ONX', 'free': '0', 'locked': '0'},
#      {'asset': 'PEN', 'free': '0', 'locked': '0'},
#      {'asset': 'PERLOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'POLS', 'free': '0', 'locked': '0'},
#      {'asset': 'REEF', 'free': '0', 'locked': '0'},
#      {'asset': 'REN', 'free': '0', 'locked': '0'},
#      {'asset': 'REPV1', 'free': '0', 'locked': '0'},
#      {'asset': 'RLC', 'free': '0', 'locked': '0'},
#      {'asset': 'ROSE', 'free': '0', 'locked': '0'},
#      {'asset': 'SBTC', 'free': '0', 'locked': '0'},
#      {'asset': 'SFP', 'free': '0', 'locked': '0'},
#      {'asset': 'SGT', 'free': '0', 'locked': '0'},
#      {'asset': 'SRM', 'free': '0', 'locked': '0'},
#      {'asset': 'STMX', 'free': '0', 'locked': '0'},
#      {'asset': 'TLDBTC', 'free': '0', 'locked': '0'},
#      {'asset': 'TOMO', 'free': '201.49648644', 'locked': '0'},
#      {'asset': 'TRX', 'free': '0.01', 'locked': '0'},
#      {'asset': 'UGX', 'free': '0', 'locked': '0'},
#      {'asset': 'UNI', 'free': '21.42841', 'locked': '0'},
#      {'asset': 'USDT', 'free': '0', 'locked': '0'},
#      {'asset': 'VET', 'free': '0', 'locked': '0'},
#      {'asset': 'VITE', 'free': '0', 'locked': '0'},
#      {'asset': 'WAN', 'free': '0', 'locked': '0'},
#      {'asset': 'WAXP', 'free': '0', 'locked': '0'},
#      {'asset': 'WBNB', 'free': '0', 'locked': '0'},
#      {'asset': 'WING', 'free': '0', 'locked': '0'},
#      {'asset': 'XEM', 'free': '2363.3660265', 'locked': '0'},
#      {'asset': 'XPR', 'free': '0', 'locked': '0'},
#      {'asset': 'XRP', 'free': '0', 'locked': '0'},
#      {'asset': 'YFII', 'free': '0', 'locked': '0'},
#      {'asset': 'ZIL', 'free': '0', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1642982399000,
#    'data': {'totalAssetOfBtc': '0.09293817',
#     'balances': [{'asset': '1INCH', 'free': '0', 'locked': '0'},
#      {'asset': 'ADA', 'free': '0', 'locked': '0'},
#      {'asset': 'ADD', 'free': '0', 'locked': '0'},
#      {'asset': 'ADXOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ANTOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ATD', 'free': '0', 'locked': '0'},
#      {'asset': 'ATOM', 'free': '0.00000027', 'locked': '0'},
#      {'asset': 'AUCTION', 'free': '9.0339582', 'locked': '0'},
#      {'asset': 'BAND', 'free': '17.46252', 'locked': '0'},
#      {'asset': 'BCX', 'free': '0', 'locked': '0'},
#      {'asset': 'BETA', 'free': '8.59949553', 'locked': '0'},
#      {'asset': 'BGN', 'free': '0', 'locked': '0'},
#      {'asset': 'BLZ', 'free': '0', 'locked': '0'},
#      {'asset': 'BNB', 'free': '0.00000589', 'locked': '0'},
#      {'asset': 'BTC', 'free': '0', 'locked': '0'},
#      {'asset': 'BTM', 'free': '0', 'locked': '0'},
#      {'asset': 'BUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'CBK', 'free': '0', 'locked': '0'},
#      {'asset': 'CBM', 'free': '0', 'locked': '0'},
#      {'asset': 'CELR', 'free': '4860.9008301', 'locked': '0'},
#      {'asset': 'CHZ', 'free': '973.3354', 'locked': '0'},
#      {'asset': 'CITY', 'free': '0.2727387', 'locked': '0'},
#      {'asset': 'CKB', 'free': '13875.117', 'locked': '0'},
#      {'asset': 'COCOS', 'free': '0', 'locked': '0'},
#      {'asset': 'COMP', 'free': '0', 'locked': '0'},
#      {'asset': 'COS', 'free': '12689.36051231', 'locked': '0'},
#      {'asset': 'COTI', 'free': '0', 'locked': '0'},
#      {'asset': 'CTR', 'free': '0', 'locked': '0'},
#      {'asset': 'DAR', 'free': '2.74688571', 'locked': '0'},
#      {'asset': 'DASH', 'free': '0', 'locked': '0'},
#      {'asset': 'DIA', 'free': '0', 'locked': '0'},
#      {'asset': 'DOCK', 'free': '50.10636718', 'locked': '0'},
#      {'asset': 'DODO', 'free': '65.71713808', 'locked': '0'},
#      {'asset': 'DOT', 'free': '0', 'locked': '0'},
#      {'asset': 'EGLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ENJ', 'free': '0', 'locked': '0'},
#      {'asset': 'EON', 'free': '0', 'locked': '0'},
#      {'asset': 'EOP', 'free': '0', 'locked': '0'},
#      {'asset': 'ETF', 'free': '0', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0.09184', 'locked': '0'},
#      {'asset': 'ETHBNT', 'free': '0', 'locked': '0'},
#      {'asset': 'EUR', 'free': '0', 'locked': '0'},
#      {'asset': 'FLOW', 'free': '10.82', 'locked': '0'},
#      {'asset': 'GAS', 'free': '1.38341219', 'locked': '0'},
#      {'asset': 'GRTDOWN', 'free': '0', 'locked': '0'},
#      {'asset': 'GRTUP', 'free': '0', 'locked': '0'},
#      {'asset': 'HBAR', 'free': '1213.5', 'locked': '0'},
#      {'asset': 'HCC', 'free': '0', 'locked': '0'},
#      {'asset': 'HKD', 'free': '0', 'locked': '0'},
#      {'asset': 'HRK', 'free': '0', 'locked': '0'},
#      {'asset': 'INR', 'free': '0', 'locked': '0'},
#      {'asset': 'IOTA', 'free': '0', 'locked': '0'},
#      {'asset': 'JEX', 'free': '0', 'locked': '0'},
#      {'asset': 'KES', 'free': '0', 'locked': '0'},
#      {'asset': 'KEY', 'free': '32753.195', 'locked': '0'},
#      {'asset': 'KNC', 'free': '0', 'locked': '0'},
#      {'asset': 'KZT', 'free': '0', 'locked': '0'},
#      {'asset': 'LAZIO', 'free': '1.05252793', 'locked': '0'},
#      {'asset': 'LD1INCH', 'free': '160.82322963', 'locked': '0'},
#      {'asset': 'LD789', 'free': '0', 'locked': '0'},
#      {'asset': 'LDADA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDALGO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDARK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDATOM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAKE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAKET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAND', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBANK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBCH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBNB', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBRL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBTC', 'free': '0.01177598', 'locked': '0'},
#      {'asset': 'LDBUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDCOCOS', 'free': '0.19881198', 'locked': '0'},
#      {'asset': 'LDCOMP', 'free': '0.40021889', 'locked': '0'},
#      {'asset': 'LDCOTI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDCVC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDAI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDASH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDOCK', 'free': '5657.53424656', 'locked': '0'},
#      {'asset': 'LDDOGE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDOT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDEOS', 'free': '0', 'locked': '0'},
#      {'asset': 'LDERD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDETC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDETH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDEUR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDFET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDFIL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDGBP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDIOST', 'free': '0', 'locked': '0'},
#      {'asset': 'LDIOTA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKAVA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKMD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKNC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLEND', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLINK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLOOM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLSK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLTC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDMATIC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDNEO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDNGN', 'free': '0', 'locked': '0'},
#      {'asset': 'LDONE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDONT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDQTUM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDRUB', 'free': '0', 'locked': '0'},
#      {'asset': 'LDSTRAT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDSXP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTHETA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTOMO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTROY', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTRX', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUNI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUSDC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUSDT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDVET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDWAVES', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXLM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXMR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXRP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXTZ', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZEC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZIL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZRX', 'free': '0', 'locked': '0'},
#      {'asset': 'LINK', 'free': '4.23706267', 'locked': '0'},
#      {'asset': 'LIT', 'free': '0', 'locked': '0'},
#      {'asset': 'LLT', 'free': '0', 'locked': '0'},
#      {'asset': 'LTC', 'free': '0', 'locked': '0'},
#      {'asset': 'LUNA', 'free': '0', 'locked': '0'},
#      {'asset': 'MANA', 'free': '264.08', 'locked': '0'},
#      {'asset': 'MATIC', 'free': '5', 'locked': '0'},
#      {'asset': 'MC', 'free': '0.00004272', 'locked': '0'},
#      {'asset': 'MEETONE', 'free': '0', 'locked': '0'},
#      {'asset': 'MXN', 'free': '0', 'locked': '0'},
#      {'asset': 'NANO', 'free': '0', 'locked': '0'},
#      {'asset': 'NEO', 'free': '9.51242219', 'locked': '0'},
#      {'asset': 'NOK', 'free': '0', 'locked': '0'},
#      {'asset': 'NVT', 'free': '0', 'locked': '0'},
#      {'asset': 'OCEAN', 'free': '0', 'locked': '0'},
#      {'asset': 'OMG', 'free': '0', 'locked': '0'},
#      {'asset': 'ONT', 'free': '0', 'locked': '0'},
#      {'asset': 'ONX', 'free': '0', 'locked': '0'},
#      {'asset': 'PEN', 'free': '0', 'locked': '0'},
#      {'asset': 'PERLOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'POLS', 'free': '0', 'locked': '0'},
#      {'asset': 'REEF', 'free': '0', 'locked': '0'},
#      {'asset': 'REN', 'free': '0', 'locked': '0'},
#      {'asset': 'REPV1', 'free': '0', 'locked': '0'},
#      {'asset': 'RLC', 'free': '0', 'locked': '0'},
#      {'asset': 'ROSE', 'free': '0', 'locked': '0'},
#      {'asset': 'SBTC', 'free': '0', 'locked': '0'},
#      {'asset': 'SFP', 'free': '0', 'locked': '0'},
#      {'asset': 'SGT', 'free': '0', 'locked': '0'},
#      {'asset': 'SRM', 'free': '0', 'locked': '0'},
#      {'asset': 'STMX', 'free': '0', 'locked': '0'},
#      {'asset': 'TLDBTC', 'free': '0', 'locked': '0'},
#      {'asset': 'TOMO', 'free': '201.49648644', 'locked': '0'},
#      {'asset': 'TRX', 'free': '0.01', 'locked': '0'},
#      {'asset': 'UGX', 'free': '0', 'locked': '0'},
#      {'asset': 'UNI', 'free': '21.42841', 'locked': '0'},
#      {'asset': 'USDT', 'free': '0', 'locked': '0'},
#      {'asset': 'VET', 'free': '0', 'locked': '0'},
#      {'asset': 'VITE', 'free': '0', 'locked': '0'},
#      {'asset': 'WAN', 'free': '0', 'locked': '0'},
#      {'asset': 'WAXP', 'free': '0', 'locked': '0'},
#      {'asset': 'WBNB', 'free': '0', 'locked': '0'},
#      {'asset': 'WING', 'free': '0', 'locked': '0'},
#      {'asset': 'XEM', 'free': '2363.3660265', 'locked': '0'},
#      {'asset': 'XPR', 'free': '0', 'locked': '0'},
#      {'asset': 'XRP', 'free': '0', 'locked': '0'},
#      {'asset': 'YFII', 'free': '0', 'locked': '0'},
#      {'asset': 'ZIL', 'free': '0', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1643068799000,
#    'data': {'totalAssetOfBtc': '0.08783307',
#     'balances': [{'asset': '1INCH', 'free': '0', 'locked': '0'},
#      {'asset': 'ADA', 'free': '0', 'locked': '0'},
#      {'asset': 'ADD', 'free': '0', 'locked': '0'},
#      {'asset': 'ADXOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ANTOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ATD', 'free': '0', 'locked': '0'},
#      {'asset': 'ATOM', 'free': '0.00000027', 'locked': '0'},
#      {'asset': 'AUCTION', 'free': '9.0339582', 'locked': '0'},
#      {'asset': 'BAND', 'free': '17.46252', 'locked': '0'},
#      {'asset': 'BCX', 'free': '0', 'locked': '0'},
#      {'asset': 'BETA', 'free': '8.59949553', 'locked': '0'},
#      {'asset': 'BGN', 'free': '0', 'locked': '0'},
#      {'asset': 'BLZ', 'free': '0', 'locked': '0'},
#      {'asset': 'BNB', 'free': '0.00000589', 'locked': '0'},
#      {'asset': 'BTC', 'free': '0', 'locked': '0'},
#      {'asset': 'BTM', 'free': '0', 'locked': '0'},
#      {'asset': 'BUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'CBK', 'free': '0', 'locked': '0'},
#      {'asset': 'CBM', 'free': '0', 'locked': '0'},
#      {'asset': 'CELR', 'free': '4860.9008301', 'locked': '0'},
#      {'asset': 'CHZ', 'free': '973.3354', 'locked': '0'},
#      {'asset': 'CITY', 'free': '0.2727387', 'locked': '0'},
#      {'asset': 'CKB', 'free': '13875.117', 'locked': '0'},
#      {'asset': 'COCOS', 'free': '0', 'locked': '0'},
#      {'asset': 'COMP', 'free': '0', 'locked': '0'},
#      {'asset': 'COS', 'free': '12689.36051231', 'locked': '0'},
#      {'asset': 'COTI', 'free': '0', 'locked': '0'},
#      {'asset': 'CTR', 'free': '0', 'locked': '0'},
#      {'asset': 'DAR', 'free': '2.74688571', 'locked': '0'},
#      {'asset': 'DASH', 'free': '0', 'locked': '0'},
#      {'asset': 'DIA', 'free': '0', 'locked': '0'},
#      {'asset': 'DOCK', 'free': '50.10789471', 'locked': '0'},
#      {'asset': 'DODO', 'free': '65.71713808', 'locked': '0'},
#      {'asset': 'DOT', 'free': '0', 'locked': '0'},
#      {'asset': 'EGLD', 'free': '0', 'locked': '0'},
#      {'asset': 'ENJ', 'free': '0', 'locked': '0'},
#      {'asset': 'EON', 'free': '0', 'locked': '0'},
#      {'asset': 'EOP', 'free': '0', 'locked': '0'},
#      {'asset': 'ETF', 'free': '0', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0.09184', 'locked': '0'},
#      {'asset': 'ETHBNT', 'free': '0', 'locked': '0'},
#      {'asset': 'EUR', 'free': '0', 'locked': '0'},
#      {'asset': 'FLOW', 'free': '10.82', 'locked': '0'},
#      {'asset': 'GAS', 'free': '1.38341219', 'locked': '0'},
#      {'asset': 'GRTDOWN', 'free': '0', 'locked': '0'},
#      {'asset': 'GRTUP', 'free': '0', 'locked': '0'},
#      {'asset': 'HBAR', 'free': '1213.5', 'locked': '0'},
#      {'asset': 'HCC', 'free': '0', 'locked': '0'},
#      {'asset': 'HKD', 'free': '0', 'locked': '0'},
#      {'asset': 'HRK', 'free': '0', 'locked': '0'},
#      {'asset': 'INR', 'free': '0', 'locked': '0'},
#      {'asset': 'IOTA', 'free': '0', 'locked': '0'},
#      {'asset': 'JEX', 'free': '0', 'locked': '0'},
#      {'asset': 'KES', 'free': '0', 'locked': '0'},
#      {'asset': 'KEY', 'free': '32753.195', 'locked': '0'},
#      {'asset': 'KNC', 'free': '0', 'locked': '0'},
#      {'asset': 'KZT', 'free': '0', 'locked': '0'},
#      {'asset': 'LAZIO', 'free': '1.05252793', 'locked': '0'},
#      {'asset': 'LD1INCH', 'free': '160.83775708', 'locked': '0'},
#      {'asset': 'LD789', 'free': '0', 'locked': '0'},
#      {'asset': 'LDADA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDALGO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDARK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDATOM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAKE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAKET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAND', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBANK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBAT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBCH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBNB', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBRL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDBTC', 'free': '0.01177739', 'locked': '0'},
#      {'asset': 'LDBUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDCOCOS', 'free': '0.19881742', 'locked': '0'},
#      {'asset': 'LDCOMP', 'free': '0.40022985', 'locked': '0'},
#      {'asset': 'LDCOTI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDCVC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDAI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDASH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDOCK', 'free': '5657.53424656', 'locked': '0'},
#      {'asset': 'LDDOGE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDDOT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDEOS', 'free': '0', 'locked': '0'},
#      {'asset': 'LDERD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDETC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDETH', 'free': '0', 'locked': '0'},
#      {'asset': 'LDEUR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDFET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDFIL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDGBP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDIOST', 'free': '0', 'locked': '0'},
#      {'asset': 'LDIOTA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKAVA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKMD', 'free': '0', 'locked': '0'},
#      {'asset': 'LDKNC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLEND', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLINK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLOOM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLSK', 'free': '0', 'locked': '0'},
#      {'asset': 'LDLTC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDMATIC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDNEO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDNGN', 'free': '0', 'locked': '0'},
#      {'asset': 'LDONE', 'free': '0', 'locked': '0'},
#      {'asset': 'LDONT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDQTUM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDRUB', 'free': '0', 'locked': '0'},
#      {'asset': 'LDSTRAT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDSXP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTHETA', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTOMO', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTROY', 'free': '0', 'locked': '0'},
#      {'asset': 'LDTRX', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUNI', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUSDC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDUSDT', 'free': '0', 'locked': '0'},
#      {'asset': 'LDVET', 'free': '0', 'locked': '0'},
#      {'asset': 'LDWAVES', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXLM', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXMR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXRP', 'free': '0', 'locked': '0'},
#      {'asset': 'LDXTZ', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZEC', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZIL', 'free': '0', 'locked': '0'},
#      {'asset': 'LDZRX', 'free': '0', 'locked': '0'},
#      {'asset': 'LINK', 'free': '4.23706267', 'locked': '0'},
#      {'asset': 'LIT', 'free': '0', 'locked': '0'},
#      {'asset': 'LLT', 'free': '0', 'locked': '0'},
#      {'asset': 'LTC', 'free': '0', 'locked': '0'},
#      {'asset': 'LUNA', 'free': '0', 'locked': '0'},
#      {'asset': 'MANA', 'free': '264.08', 'locked': '0'},
#      {'asset': 'MATIC', 'free': '5', 'locked': '0'},
#      {'asset': 'MC', 'free': '0.00004272', 'locked': '0'},
#      {'asset': 'MEETONE', 'free': '0', 'locked': '0'},
#      {'asset': 'MXN', 'free': '0', 'locked': '0'},
#      {'asset': 'NANO', 'free': '0', 'locked': '0'},
#      {'asset': 'NEO', 'free': '9.51242219', 'locked': '0'},
#      {'asset': 'NOK', 'free': '0', 'locked': '0'},
#      {'asset': 'NVT', 'free': '0', 'locked': '0'},
#      {'asset': 'OCEAN', 'free': '0', 'locked': '0'},
#      {'asset': 'OMG', 'free': '0', 'locked': '0'},
#      {'asset': 'ONT', 'free': '0', 'locked': '0'},
#      {'asset': 'ONX', 'free': '0', 'locked': '0'},
#      {'asset': 'PEN', 'free': '0', 'locked': '0'},
#      {'asset': 'PERLOLD', 'free': '0', 'locked': '0'},
#      {'asset': 'POLS', 'free': '0', 'locked': '0'},
#      {'asset': 'REEF', 'free': '0', 'locked': '0'},
#      {'asset': 'REN', 'free': '0', 'locked': '0'},
#      {'asset': 'REPV1', 'free': '0', 'locked': '0'},
#      {'asset': 'RLC', 'free': '0', 'locked': '0'},
#      {'asset': 'ROSE', 'free': '0', 'locked': '0'},
#      {'asset': 'SBTC', 'free': '0', 'locked': '0'},
#      {'asset': 'SFP', 'free': '0', 'locked': '0'},
#      {'asset': 'SGT', 'free': '0', 'locked': '0'},
#      {'asset': 'SRM', 'free': '0', 'locked': '0'},
#      {'asset': 'STMX', 'free': '0', 'locked': '0'},
#      {'asset': 'TLDBTC', 'free': '0', 'locked': '0'},
#      {'asset': 'TOMO', 'free': '201.49648644', 'locked': '0'},
#      {'asset': 'TRX', 'free': '0.01', 'locked': '0'},
#      {'asset': 'UGX', 'free': '0', 'locked': '0'},
#      {'asset': 'UNI', 'free': '21.42841', 'locked': '0'},
#      {'asset': 'USDT', 'free': '0', 'locked': '0'},
#      {'asset': 'VET', 'free': '0', 'locked': '0'},
#      {'asset': 'VITE', 'free': '0', 'locked': '0'},
#      {'asset': 'WAN', 'free': '0', 'locked': '0'},
#      {'asset': 'WAXP', 'free': '0', 'locked': '0'},
#      {'asset': 'WBNB', 'free': '0', 'locked': '0'},
#      {'asset': 'WING', 'free': '0', 'locked': '0'},
#      {'asset': 'XEM', 'free': '2363.3660265', 'locked': '0'},
#      {'asset': 'XPR', 'free': '0', 'locked': '0'},
#      {'asset': 'XRP', 'free': '0', 'locked': '0'},
#      {'asset': 'YFII', 'free': '0', 'locked': '0'},
#      {'asset': 'ZIL', 'free': '0', 'locked': '0'}]}}]}

# %%
snap=pd.json_normalize(snap["snapshotVos"])
snap
# Out:
#    type     updateTime data.totalAssetOfBtc  \
# 0  spot  1642723199000           0.09440739
# 1  spot  1642809599000           0.09009837
# 2  spot  1642895999000           0.08475044
# 3  spot  1642982399000           0.09293817
# 4  spot  1643068799000           0.08783307
#
#                                        data.balances
# 0  [{'asset': '1INCH', 'free': '0', 'locked': '0'...
# 1  [{'asset': '1INCH', 'free': '0', 'locked': '0'...
# 2  [{'asset': '1INCH', 'free': '0', 'locked': '0'...
# 3  [{'asset': '1INCH', 'free': '0', 'locked': '0'...
# 4  [{'asset': '1INCH', 'free': '0', 'locked': '0'...

# %%
snap.updateTime=pd.to_datetime(snap["updateTime"],unit="ms")

# %%
snap
# Out:
#    type          updateTime data.totalAssetOfBtc  \
# 0  spot 2022-01-20 23:59:59           0.09440739
# 1  spot 2022-01-21 23:59:59           0.09009837
# 2  spot 2022-01-22 23:59:59           0.08475044
# 3  spot 2022-01-23 23:59:59           0.09293817
# 4  spot 2022-01-24 23:59:59           0.08783307
#
#                                        data.balances
# 0  [{'asset': '1INCH', 'free': '0', 'locked': '0'...
# 1  [{'asset': '1INCH', 'free': '0', 'locked': '0'...
# 2  [{'asset': '1INCH', 'free': '0', 'locked': '0'...
# 3  [{'asset': '1INCH', 'free': '0', 'locked': '0'...
# 4  [{'asset': '1INCH', 'free': '0', 'locked': '0'...

# %%
snap["data.balances"][0]
# Out:
# [{'asset': '1INCH', 'free': '0', 'locked': '0'},
#  {'asset': 'ADA', 'free': '0', 'locked': '0'},
#  {'asset': 'ADD', 'free': '0', 'locked': '0'},
#  {'asset': 'ADXOLD', 'free': '0', 'locked': '0'},
#  {'asset': 'ANTOLD', 'free': '0', 'locked': '0'},
#  {'asset': 'ATD', 'free': '0', 'locked': '0'},
#  {'asset': 'ATOM', 'free': '0.00000027', 'locked': '0'},
#  {'asset': 'AUCTION', 'free': '9.0339582', 'locked': '0'},
#  {'asset': 'BAND', 'free': '17.46252', 'locked': '0'},
#  {'asset': 'BCX', 'free': '0', 'locked': '0'},
#  {'asset': 'BETA', 'free': '8.59949553', 'locked': '0'},
#  {'asset': 'BGN', 'free': '0', 'locked': '0'},
#  {'asset': 'BLZ', 'free': '0', 'locked': '0'},
#  {'asset': 'BNB', 'free': '0.00000589', 'locked': '0'},
#  {'asset': 'BTC', 'free': '0', 'locked': '0'},
#  {'asset': 'BTM', 'free': '0', 'locked': '0'},
#  {'asset': 'BUSD', 'free': '0', 'locked': '0'},
#  {'asset': 'CBK', 'free': '0', 'locked': '0'},
#  {'asset': 'CBM', 'free': '0', 'locked': '0'},
#  {'asset': 'CELR', 'free': '41.41901764', 'locked': '0'},
#  {'asset': 'CHZ', 'free': '973.3354', 'locked': '0'},
#  {'asset': 'CITY', 'free': '0.2727387', 'locked': '0'},
#  {'asset': 'CKB', 'free': '13875.117', 'locked': '0'},
#  {'asset': 'COCOS', 'free': '0', 'locked': '0'},
#  {'asset': 'COMP', 'free': '0', 'locked': '0'},
#  {'asset': 'COS', 'free': '12689.36051231', 'locked': '0'},
#  {'asset': 'COTI', 'free': '0', 'locked': '0'},
#  {'asset': 'CTR', 'free': '0', 'locked': '0'},
#  {'asset': 'DAR', 'free': '2.74688571', 'locked': '0'},
#  {'asset': 'DASH', 'free': '0', 'locked': '0'},
#  {'asset': 'DIA', 'free': '0', 'locked': '0'},
#  {'asset': 'DOCK', 'free': '50.10178459', 'locked': '0'},
#  {'asset': 'DODO', 'free': '1.05629916', 'locked': '0'},
#  {'asset': 'DOT', 'free': '0', 'locked': '0'},
#  {'asset': 'EGLD', 'free': '0', 'locked': '0'},
#  {'asset': 'ENJ', 'free': '0', 'locked': '0'},
#  {'asset': 'EON', 'free': '0', 'locked': '0'},
#  {'asset': 'EOP', 'free': '0', 'locked': '0'},
#  {'asset': 'ETF', 'free': '0', 'locked': '0'},
#  {'asset': 'ETH', 'free': '0.09184', 'locked': '0'},
#  {'asset': 'ETHBNT', 'free': '0', 'locked': '0'},
#  {'asset': 'EUR', 'free': '0', 'locked': '0'},
#  {'asset': 'FLOW', 'free': '10.82', 'locked': '0'},
#  {'asset': 'GAS', 'free': '1.38341219', 'locked': '0'},
#  {'asset': 'GRTDOWN', 'free': '0', 'locked': '0'},
#  {'asset': 'GRTUP', 'free': '0', 'locked': '0'},
#  {'asset': 'HBAR', 'free': '1213.5', 'locked': '0'},
#  {'asset': 'HCC', 'free': '0', 'locked': '0'},
#  {'asset': 'HKD', 'free': '0', 'locked': '0'},
#  {'asset': 'HRK', 'free': '0', 'locked': '0'},
#  {'asset': 'INR', 'free': '0', 'locked': '0'},
#  {'asset': 'IOTA', 'free': '0', 'locked': '0'},
#  {'asset': 'JEX', 'free': '0', 'locked': '0'},
#  {'asset': 'KES', 'free': '0', 'locked': '0'},
#  {'asset': 'KEY', 'free': '32753.195', 'locked': '0'},
#  {'asset': 'KNC', 'free': '0', 'locked': '0'},
#  {'asset': 'KZT', 'free': '0', 'locked': '0'},
#  {'asset': 'LAZIO', 'free': '1.05252793', 'locked': '0'},
#  {'asset': 'LD1INCH', 'free': '160.77965514', 'locked': '0'},
#  {'asset': 'LD789', 'free': '0', 'locked': '0'},
#  {'asset': 'LDADA', 'free': '0', 'locked': '0'},
#  {'asset': 'LDALGO', 'free': '0', 'locked': '0'},
#  {'asset': 'LDARK', 'free': '0', 'locked': '0'},
#  {'asset': 'LDATOM', 'free': '0', 'locked': '0'},
#  {'asset': 'LDBAKE', 'free': '0', 'locked': '0'},
#  {'asset': 'LDBAKET', 'free': '0', 'locked': '0'},
#  {'asset': 'LDBAL', 'free': '0', 'locked': '0'},
#  {'asset': 'LDBAND', 'free': '0', 'locked': '0'},
#  {'asset': 'LDBANK', 'free': '0', 'locked': '0'},
#  {'asset': 'LDBAT', 'free': '0', 'locked': '0'},
#  {'asset': 'LDBCH', 'free': '0', 'locked': '0'},
#  {'asset': 'LDBNB', 'free': '0', 'locked': '0'},
#  {'asset': 'LDBRL', 'free': '0', 'locked': '0'},
#  {'asset': 'LDBTC', 'free': '0.01177175', 'locked': '0'},
#  {'asset': 'LDBUSD', 'free': '0', 'locked': '0'},
#  {'asset': 'LDCOCOS', 'free': '0.19879566', 'locked': '0'},
#  {'asset': 'LDCOMP', 'free': '0.40018601', 'locked': '0'},
#  {'asset': 'LDCOTI', 'free': '0', 'locked': '0'},
#  {'asset': 'LDCVC', 'free': '0', 'locked': '0'},
#  {'asset': 'LDDAI', 'free': '0', 'locked': '0'},
#  {'asset': 'LDDASH', 'free': '0', 'locked': '0'},
#  {'asset': 'LDDOCK', 'free': '5657.53424656', 'locked': '0'},
#  {'asset': 'LDDOGE', 'free': '0', 'locked': '0'},
#  {'asset': 'LDDOT', 'free': '0', 'locked': '0'},
#  {'asset': 'LDEOS', 'free': '0', 'locked': '0'},
#  {'asset': 'LDERD', 'free': '0', 'locked': '0'},
#  {'asset': 'LDETC', 'free': '0', 'locked': '0'},
#  {'asset': 'LDETH', 'free': '0', 'locked': '0'},
#  {'asset': 'LDEUR', 'free': '0', 'locked': '0'},
#  {'asset': 'LDFET', 'free': '0', 'locked': '0'},
#  {'asset': 'LDFIL', 'free': '0', 'locked': '0'},
#  {'asset': 'LDGBP', 'free': '0', 'locked': '0'},
#  {'asset': 'LDIOST', 'free': '0', 'locked': '0'},
#  {'asset': 'LDIOTA', 'free': '0', 'locked': '0'},
#  {'asset': 'LDKAVA', 'free': '0', 'locked': '0'},
#  {'asset': 'LDKMD', 'free': '0', 'locked': '0'},
#  {'asset': 'LDKNC', 'free': '0', 'locked': '0'},
#  {'asset': 'LDLEND', 'free': '0', 'locked': '0'},
#  {'asset': 'LDLINK', 'free': '0', 'locked': '0'},
#  {'asset': 'LDLOOM', 'free': '0', 'locked': '0'},
#  {'asset': 'LDLSK', 'free': '0', 'locked': '0'},
#  {'asset': 'LDLTC', 'free': '0', 'locked': '0'},
#  {'asset': 'LDMATIC', 'free': '0', 'locked': '0'},
#  {'asset': 'LDNEO', 'free': '0', 'locked': '0'},
#  {'asset': 'LDNGN', 'free': '0', 'locked': '0'},
#  {'asset': 'LDONE', 'free': '0', 'locked': '0'},
#  {'asset': 'LDONT', 'free': '0', 'locked': '0'},
#  {'asset': 'LDQTUM', 'free': '0', 'locked': '0'},
#  {'asset': 'LDRUB', 'free': '0', 'locked': '0'},
#  {'asset': 'LDSTRAT', 'free': '0', 'locked': '0'},
#  {'asset': 'LDSXP', 'free': '0', 'locked': '0'},
#  {'asset': 'LDTHETA', 'free': '0', 'locked': '0'},
#  {'asset': 'LDTOMO', 'free': '0', 'locked': '0'},
#  {'asset': 'LDTROY', 'free': '0', 'locked': '0'},
#  {'asset': 'LDTRX', 'free': '0', 'locked': '0'},
#  {'asset': 'LDUNI', 'free': '0', 'locked': '0'},
#  {'asset': 'LDUSDC', 'free': '0', 'locked': '0'},
#  {'asset': 'LDUSDT', 'free': '0', 'locked': '0'},
#  {'asset': 'LDVET', 'free': '0', 'locked': '0'},
#  {'asset': 'LDWAVES', 'free': '0', 'locked': '0'},
#  {'asset': 'LDXLM', 'free': '0', 'locked': '0'},
#  {'asset': 'LDXMR', 'free': '0', 'locked': '0'},
#  {'asset': 'LDXRP', 'free': '0', 'locked': '0'},
#  {'asset': 'LDXTZ', 'free': '0', 'locked': '0'},
#  {'asset': 'LDZEC', 'free': '0', 'locked': '0'},
#  {'asset': 'LDZIL', 'free': '0', 'locked': '0'},
#  {'asset': 'LDZRX', 'free': '0', 'locked': '0'},
#  {'asset': 'LINK', 'free': '4.23706267', 'locked': '0'},
#  {'asset': 'LIT', 'free': '0', 'locked': '0'},
#  {'asset': 'LLT', 'free': '0', 'locked': '0'},
#  {'asset': 'LTC', 'free': '0', 'locked': '0'},
#  {'asset': 'LUNA', 'free': '0', 'locked': '0'},
#  {'asset': 'MANA', 'free': '264.08', 'locked': '0'},
#  {'asset': 'MATIC', 'free': '5', 'locked': '0'},
#  {'asset': 'MC', 'free': '0.00004272', 'locked': '0'},
#  {'asset': 'MEETONE', 'free': '0', 'locked': '0'},
#  {'asset': 'MXN', 'free': '0', 'locked': '0'},
#  {'asset': 'NANO', 'free': '0', 'locked': '0'},
#  {'asset': 'NEO', 'free': '9.51242219', 'locked': '0'},
#  {'asset': 'NOK', 'free': '0', 'locked': '0'},
#  {'asset': 'NVT', 'free': '0', 'locked': '0'},
#  {'asset': 'OCEAN', 'free': '0', 'locked': '0'},
#  {'asset': 'OMG', 'free': '0', 'locked': '0'},
#  {'asset': 'ONT', 'free': '0', 'locked': '0'},
#  {'asset': 'ONX', 'free': '0', 'locked': '0'},
#  {'asset': 'PEN', 'free': '0', 'locked': '0'},
#  {'asset': 'PERLOLD', 'free': '0', 'locked': '0'},
#  {'asset': 'POLS', 'free': '0', 'locked': '0'},
#  {'asset': 'REEF', 'free': '0', 'locked': '0'},
#  {'asset': 'REN', 'free': '0', 'locked': '0'},
#  {'asset': 'REPV1', 'free': '0', 'locked': '0'},
#  {'asset': 'RLC', 'free': '0', 'locked': '0'},
#  {'asset': 'ROSE', 'free': '0', 'locked': '0'},
#  {'asset': 'SBTC', 'free': '0', 'locked': '0'},
#  {'asset': 'SFP', 'free': '0', 'locked': '0'},
#  {'asset': 'SGT', 'free': '0', 'locked': '0'},
#  {'asset': 'SRM', 'free': '0', 'locked': '0'},
#  {'asset': 'STMX', 'free': '0', 'locked': '0'},
#  {'asset': 'TLDBTC', 'free': '0', 'locked': '0'},
#  {'asset': 'TOMO', 'free': '201.49648644', 'locked': '0'},
#  {'asset': 'TRX', 'free': '0.01', 'locked': '0'},
#  {'asset': 'UGX', 'free': '0', 'locked': '0'},
#  {'asset': 'UNI', 'free': '21.42841', 'locked': '0'},
#  {'asset': 'USDT', 'free': '0', 'locked': '0'},
#  {'asset': 'VET', 'free': '0', 'locked': '0'},
#  {'asset': 'VITE', 'free': '0', 'locked': '0'},
#  {'asset': 'WAN', 'free': '0', 'locked': '0'},
#  {'asset': 'WAXP', 'free': '0', 'locked': '0'},
#  {'asset': 'WBNB', 'free': '0', 'locked': '0'},
#  {'asset': 'WING', 'free': '0', 'locked': '0'},
#  {'asset': 'XEM', 'free': '2363.3660265', 'locked': '0'},
#  {'asset': 'XPR', 'free': '0', 'locked': '0'},
#  {'asset': 'XRP', 'free': '0', 'locked': '0'},
#  {'asset': 'YFII', 'free': '0', 'locked': '0'},
#  {'asset': 'ZIL', 'free': '0', 'locked': '0'}]

# %%
client.get_exchange_info()
# Out:
# {'timezone': 'UTC',
#  'serverTime': 1643316827868,
#  'rateLimits': [{'rateLimitType': 'REQUEST_WEIGHT',
#    'interval': 'MINUTE',
#    'intervalNum': 1,
#    'limit': 1200},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'SECOND',
#    'intervalNum': 10,
#    'limit': 50},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'DAY',
#    'intervalNum': 1,
#    'limit': 160000},
#   {'rateLimitType': 'RAW_REQUESTS',
#    'interval': 'MINUTE',
#    'intervalNum': 5,
#    'limit': 6100}],
#  'exchangeFilters': [],
#  'symbols': [{'symbol': 'ETHBTC',
#    'status': 'TRADING',
#    'baseAsset': 'ETH',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '922327.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '908.01751076',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'LTCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'LTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '9320.67712500',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'BNBBTC',
#    'status': 'TRADING',
#    'baseAsset': 'BNB',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '10654.47654375',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'NEOBTC',
#    'status': 'TRADING',
#    'baseAsset': 'NEO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '7800.85531250',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'QTUMETH',
#    'status': 'TRADING',
#    'baseAsset': 'QTUM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '7334.04275694',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'EOSETH',
#    'status': 'TRADING',
#    'baseAsset': 'EOS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '38224.05986111',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'SNTETH',
#    'status': 'TRADING',
#    'baseAsset': 'SNT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '620498.04722222',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BNTETH',
#    'status': 'TRADING',
#    'baseAsset': 'BNT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '13227.95298611',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BCCBTC',
#    'status': 'BREAK',
#    'baseAsset': 'BCC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'GASBTC',
#    'status': 'TRADING',
#    'baseAsset': 'GAS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '10235.08134027',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BNBETH',
#    'status': 'TRADING',
#    'baseAsset': 'BNB',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '9000000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '7056.11784861',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'BTCUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'BTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00001000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00001000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '224.45090907',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'ETHUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'ETH',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '2192.54719958',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'HSRBTC',
#    'status': 'BREAK',
#    'baseAsset': 'HSR',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'OAXETH',
#    'status': 'BREAK',
#    'baseAsset': 'OAX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '579591.88919668',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'DNTETH',
#    'status': 'BREAK',
#    'baseAsset': 'DNT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '4194220.05124836',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'MCOETH',
#    'status': 'BREAK',
#    'baseAsset': 'MCO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '6660.95529820',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'ICNETH',
#    'status': 'BREAK',
#    'baseAsset': 'ICN',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'MCOBTC',
#    'status': 'BREAK',
#    'baseAsset': 'MCO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '27097.31944518',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'WTCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'WTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '9000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '62169.35050000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'WTCETH',
#    'status': 'BREAK',
#    'baseAsset': 'WTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '28248.67398611',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'LRCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'LRC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '289463.81250000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'LRCETH',
#    'status': 'TRADING',
#    'baseAsset': 'LRC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '74266.02847222',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'QTUMBTC',
#    'status': 'TRADING',
#    'baseAsset': 'QTUM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '14487.89717361',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'YOYOBTC',
#    'status': 'TRADING',
#    'baseAsset': 'YOYO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '12134615.49097222',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'OMGBTC',
#    'status': 'TRADING',
#    'baseAsset': 'OMG',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '28404.70968055',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'OMGETH',
#    'status': 'TRADING',
#    'baseAsset': 'OMG',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '15457.28798611',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'ZRXBTC',
#    'status': 'TRADING',
#    'baseAsset': 'ZRX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '92079.77569444',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'ZRXETH',
#    'status': 'TRADING',
#    'baseAsset': 'ZRX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '27567.25069444',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'STRATBTC',
#    'status': 'BREAK',
#    'baseAsset': 'STRAT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '222217.01315789',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'STRATETH',
#    'status': 'BREAK',
#    'baseAsset': 'STRAT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '75043.65373961',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'SNGLSBTC',
#    'status': 'BREAK',
#    'baseAsset': 'SNGLS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '69235100.97256515',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'SNGLSETH',
#    'status': 'BREAK',
#    'baseAsset': 'SNGLS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '6821000.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BQXBTC',
#    'status': 'BREAK',
#    'baseAsset': 'BQX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '106190.15178571',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'BQXETH',
#    'status': 'BREAK',
#    'baseAsset': 'BQX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '10.00000000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '10.00000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '10.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '10.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '24348.24047619',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'KNCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'KNC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
# ...
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '43006.85131944',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'SUSHIBUSD',
#    'status': 'TRADING',
#    'baseAsset': 'SUSHI',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BUSD',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00100000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00100000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '32120.94715277',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'SUSHIUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'SUSHI',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00100000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00100000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '95063.70569444',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'YFIIBNB',
#    'status': 'TRADING',
#    'baseAsset': 'YFII',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BNB',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '90000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.05000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '11.34107062',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'YFIIBTC',
#    'status': 'TRADING',
#    'baseAsset': 'YFII',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '33.08588298',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'YFIIBUSD',
#    'status': 'TRADING',
#    'baseAsset': 'YFII',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BUSD',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '1.00000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '1.00000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '19.81340715',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'YFIIUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'YFII',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '1.00000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '1.00000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '71.70175493',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'KSMBNB',
#    'status': 'TRADING',
#    'baseAsset': 'KSM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BNB',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '900000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.05000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '117.31574652',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   {'symbol': 'KSMBTC',
#    'status': 'TRADING',
#    'baseAsset': 'KSM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '10000000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '727.60728125',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'KSMBUSD',
#    'status': 'TRADING',
#    'baseAsset': 'KSM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BUSD',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.10000000',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.10000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '900000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '514.19122076',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'KSMUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'KSM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.10000000',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.10000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '900000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '1633.04435173',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT', 'MARGIN']},
#   {'symbol': 'EGLDBNB',
#    'status': 'TRADING',
#    'baseAsset': 'EGLD',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BNB',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '900000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.05000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '406.59319444',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#    'permissions': ['SPOT']},
#   ...]}

# %%
client.get_all_coins_info()
# Out:
# [{'coin': 'AGLD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Adventure Gold',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'AGLD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '31',
#     'withdrawMin': '62',
#     'withdrawMax': '9999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'STPT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Standard Tokenization Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'STPT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '360',
#     'withdrawMin': '720',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'MXN',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Mexican Peso',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'MXN',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'UGX',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Uganda Shilling',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'UGX',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'RENBTC',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'renBTC',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'RENBTC',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.0000051',
#     'withdrawMin': '0.00001',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'RENBTC',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.00067',
#     'withdrawMin': '0.0013',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'GLM',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Golem',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'GLM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '76',
#     'withdrawMin': '152',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'RAY',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Raydium',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'SOL',
#     'coin': 'RAY',
#     'withdrawIntegerMultiple': '0.000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The Solana blockchain will retain 0.00203928 SOL for your first token deposit. The following deposits will not be charge for any fee.',
#     'specialWithdrawTips': 'The Solana (SOL) network is recently experiencing congestion issues. Withdrawals may be paused from time to time to clear the backlog. We’re actively working with the project to provide a stable, long-term solution. Apologies for any inconvenience caused. For more information: https://status.solana.com/incidents/6tp7jy94r4r9',
#     'name': 'Solana',
#     'resetAddressStatus': False,
#     'addressRegex': '^[1-9A-HJ-NP-Za-km-z]{32,44}$',
#     'addressRule': 'ADDRESS',
#     'memoRegex': '',
#     'withdrawFee': '0.26',
#     'withdrawMin': '0.52',
#     'withdrawMax': '9999999',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'NEAR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'NEAR Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BNB',
#     'coin': 'NEAR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Both a MEMO and an Address are required to successfully deposit your BEP2 tokens to Binance.',
#     'name': 'Binance Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'addressRule': '',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.017',
#     'withdrawMin': '0.034',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True},
#    {'network': 'BSC',
#     'coin': 'NEAR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.017',
#     'withdrawMin': '0.034',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'NEAR',
#     'coin': 'NEAR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'NEAR Protocol',
#     'resetAddressStatus': False,
#     'addressRegex': '^[a-z0-9_-]{1}[a-z0-9_.-]{0,62}[a-z0-9_-]{1}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.01',
#     'withdrawMin': '0.2',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 5,
#     'sameAddress': False}]},
#  {'coin': 'AUDIO',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Audius',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'AUDIO',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '28',
#     'withdrawMin': '56',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'HNT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': False,
#   'name': 'Helium',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'HNT',
#     'coin': 'HNT',
#     'withdrawIntegerMultiple': '0.01',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': '',
#     'name': 'Helium',
#     'resetAddressStatus': False,
#     'addressRegex': '^(1)[0-9A-za-z]{50}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.05',
#     'withdrawMin': '1',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'ADADOWN',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'ADADOWN',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETF',
#     'coin': 'ADADOWN',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'ETF',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'CDT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': False,
#   'name': 'Blox',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'CDT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '226',
#     'withdrawMin': '452',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'SPARTA',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Spartan Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'SPARTA',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will potentially lose your assets if the chosen platform does not support refund of wrongfully deposited assets. Please note that you are withdrawing SPARTAv2 which is subject to a fee burn. For more information, please refer to: ##https://spartanprotocol.medium.com/spartav2-token-fee-burn-97e5441da98e##',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '2',
#     'withdrawMin': '4',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'SUSD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'sUSD',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'SUSD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '15',
#     'withdrawMin': '30',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'FARM',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Harvest Finance',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'FARM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.0017',
#     'withdrawMin': '0.0034',
#     'withdrawMax': '9999999',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'FARM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.23',
#     'withdrawMin': '0.46',
#     'withdrawMax': '9999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'AION',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'AION',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'AION',
#     'coin': 'AION',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Aion',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{64}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.1',
#     'withdrawMin': '0.2',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 60,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'AION',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'Network swapped, ERC20 withdrawal closed.',
#     'specialTips': 'This deposit address supports ERC20 tokens. We will automatically convert your tokens to the Mainnet.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '286',
#     'withdrawMin': '572',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'NPXS',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'Old Pundi X',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'NPXS',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'We have disabled deposits as our systems are currently undergoing maintenance.',
#     'withdrawDesc': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '5603',
#     'withdrawMin': '11206',
#     'withdrawMax': '9900000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'DGB',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'DigiByte',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'DGB',
#     'coin': 'DGB',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'DigiByte',
#     'resetAddressStatus': False,
#     'addressRegex': '^[DS][a-km-zA-HJ-NP-Z1-9]{25,34}$|^(dgb1)[0-9A-Za-z]{39,59}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.2',
#     'withdrawMin': '0.4',
#     'withdrawMax': '10000000000',
#     'minConfirm': 10,
#     'unLockConfirm': 50,
#     'sameAddress': False}]},
#  {'coin': 'ZRX',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': '0x',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'ZRX',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '46',
#     'withdrawMin': '92',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'BCD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Bitcoin Diamond',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BCD',
#     'coin': 'BCD',
#     'withdrawIntegerMultiple': '0.000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Bitcoin Diamond',
#     'resetAddressStatus': False,
#     'addressRegex': '^[13][a-km-zA-HJ-NP-Z1-9]{25,34}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.01',
#     'withdrawMin': '0.02',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 6,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'EASY',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'EasyFi',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BSC',
#     'coin': 'EASY',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'Sorry, we do not support deposits for this asset.',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.017',
#     'withdrawMin': '0.034',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'EASY',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'Sorry, we do not support deposits for this asset.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '2.28',
#     'withdrawMin': '4.56',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'SANTOS',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Santos FC Fan Token',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'SANTOS',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.074',
#     'withdrawMin': '0.15',
#     'withdrawMax': '9999999',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'WING',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Wing Token',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ONT',
#     'coin': 'WING',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ontology',
#     'resetAddressStatus': False,
#     'addressRegex': '^(A)[A-Za-z0-9]{33}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.0026',
#     'withdrawMin': '0.0052',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 5,
#     'sameAddress': False}]},
#  {'coin': 'WNXM',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Wrapped NXM',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'WNXM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.72',
#     'withdrawMin': '1.44',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'BCH',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Bitcoin Cash',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BCH',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Bitcoin Cash',
#     'resetAddressStatus': False,
#     'addressRegex': '^[13][a-km-zA-HJ-NP-Z1-9]{25,34}$|^[0-9A-Za-z]{42,42}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.001',
#     'withdrawMin': '0.002',
#     'withdrawMax': '10000000000',
#     'minConfirm': 2,
#     'unLockConfirm': 6,
#     'sameAddress': False},
#    {'network': 'BNB',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please enter both MEMO and Address data, which are required to deposit BCH BEP2 tokens to your Binance account.',
#     'name': 'Binance Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'addressRule': '',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.00065',
#     'withdrawMin': '0.0013',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True},
#    {'network': 'BSC',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.00065',
#     'withdrawMin': '0.0013',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': 'This deposit address supports ERC20 BBCH tokens. Please ensure your destination address supports BBCH tokens under the contract address ending in 65f1b.',
#     'specialWithdrawTips': 'The network you have selected is ERC20-BBCH. Please ensure that the withdrawal address supports the ERC20-BBCH. You will potentially lose your assets if the chosen platform does not support refund of wrongfully deposited assets.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.085',
#     'withdrawMin': '0.17',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'JST',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'JUST',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'JST',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '4.73',
#     'withdrawMin': '9.46',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'TRX',
#     'coin': 'JST',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Tron (TRC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^T[1-9A-HJ-NP-Za-km-z]{33}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '50',
#     'withdrawMin': '100',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'ADAUP',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'ADAUP',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETF',
#     'coin': 'ADAUP',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'ETF',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'HOT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Holo',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'HOT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Holo (ticker: HOT). Please ensure you are depositing Holo (HOT) tokens under the contract address ending in 526e2.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '5537',
#     'withdrawMin': '11074',
#     'withdrawMax': '9900000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'AR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Arweave',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'AR',
#     'coin': 'AR',
#     'withdrawIntegerMultiple': '0.00001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Arweave',
#     'resetAddressStatus': False,
#     'addressRegex': '^[0-9a-z-A-Z\\-\\_]{43}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.03',
#     'withdrawMin': '0.1',
#     'withdrawMax': '9999999',
#     'minConfirm': 20,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'IRIS',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'IRISnet',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'IRIS',
#     'coin': 'IRIS',
#     'withdrawIntegerMultiple': '0.000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Both a MEMO and an Address are required to successfully deposit your IRIS to Binance',
#     'name': 'IRISnet',
#     'resetAddressStatus': False,
#     'addressRegex': '^(iaa1)[0-9a-z]{38}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '1',
#     'withdrawMin': '2',
#     'withdrawMax': '10000000000',
#     'minConfirm': 10,
#     'unLockConfirm': 15,
#     'sameAddress': True}]},
#  {'coin': 'RAMP',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'RAMP',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'RAMP',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '1.83',
#     'withdrawMin': '3.66',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'RAMP',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '240',
#     'withdrawMin': '480',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'BCX',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'BitcoinX',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BCX',
#     'coin': 'BCX',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'Sorry, we do not support deposits for this asset.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'BitcoinX',
#     'resetAddressStatus': False,
#     'addressRegex': '^(X)[0-9A-za-z]{33}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.5',
#     'withdrawMin': '0.5',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 2,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'SEK',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'Swedish Kroner ',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'SEK',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'We have disabled deposits as our systems are currently undergoing maintenance.',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'TRIG',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'Triggers',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'TRIG',
#     'coin': 'TRIG',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'Sorry, but this asset has been delisted. We cannot process deposits for this asset.',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': '',
#     'name': 'Triggers',
#     'resetAddressStatus': False,
#     'addressRegex': '^[13][a-km-zA-HJ-NP-Z1-9]{25,34}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '50',
#     'withdrawMin': '51',
#     'withdrawMax': '10000000000',
#     'minConfirm': 2,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'RCN',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'Ripio Credit Network',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'RCN',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'We have disabled deposits as our systems are currently undergoing maintenance.',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Ripio Credit Network. Please ensure you are depositing Ripio Credit Network (RCN) tokens under the contract address ending in 375a6.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '539',
#     'withdrawMin': '1078',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'COVER',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'COVER Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'COVER',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'We have disabled deposits as our systems are currently undergoing maintenance.',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': 'Please ensure you are depositing ERC20 COVER tokens under the contract address ending in Bd8713',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.005',
#     'withdrawMin': '0.01',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'FLM',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Flamingo',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'NEO',
#     'coin': 'FLM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Neo Legacy',
#     'resetAddressStatus': False,
#     'addressRegex': '^(A)[A-Za-z0-9]{33}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.5',
#     'withdrawMin': '2',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 5,
#     'sameAddress': False}]},
#  {'coin': 'GNO',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Gnosis',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'GNO',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.091',
#     'withdrawMin': '0.18',
#     'withdrawMax': '9999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'VITE',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'VITE',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'VITE',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '3.79',
#     'withdrawMin': '7.58',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'VITE',
#     'coin': 'VITE',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Both a MEMO and an Address are required to successfully deposit your VITE to Binance.',
#     'name': 'VITE',
#     'resetAddressStatus': False,
#     'addressRegex': '^(vite_)[a-z0-9]{50}$',
#     'addressRule': '',
#     'memoRegex': '\\w{0,120}',
#     'withdrawFee': '1',
#     'withdrawMin': '2',
#     'withdrawMax': '10000000000',
#     'minConfirm': 150,
#     'unLockConfirm': 0,
#     'sameAddress': True}]},
#  {'coin': 'GNT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': False,
#   'name': 'Golem',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'GNT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'Smart contract swap in progress. Withdrawals are temporarily suspended.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '20',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'BKRW',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'Binance KRW',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BNB',
#     'coin': 'BKRW',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'Sorry, but this asset has been delisted. We cannot process deposits for this asset.',
#     'withdrawDesc': '',
#     'specialTips': 'Please enter both MEMO and Address data, which are required to deposit BEP2-BKRW tokens to your Binance account.',
#     'name': 'Binance Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'addressRule': '',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0',
#     'withdrawMin': '20',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True}]},
#  {'coin': 'CFX',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Conflux Network',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'CFX',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '1.78',
#     'withdrawMin': '3.56',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'XPR',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
# ...
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'VIB',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '1001',
#     'withdrawMin': '2002',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'VIA',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'Viacoin',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'VIA',
#     'coin': 'VIA',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'We have disabled deposits as our systems are currently undergoing maintenance.',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'name': 'Viacoin',
#     'resetAddressStatus': False,
#     'addressRegex': '((V|E)[A-Za-z0-9]{33})|(via1[qpzry9x8gf2tvdw0s3jn54khce6mua7l]{39})',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.01',
#     'withdrawMin': '0.02',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 50,
#     'sameAddress': False}]},
#  {'coin': 'FIS',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Stafi',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'FIS',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.26',
#     'withdrawMin': '0.52',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'FIS',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '34',
#     'withdrawMin': '68',
#     'withdrawMax': '9900000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'BAR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'FC Barcelona Fan Token BAR',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'CHZ',
#     'coin': 'BAR',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'Only CHZ network withdrawals supported. Withdrawing to an address that is not a CHZ network address will result the LOSS of your funds.',
#     'name': 'Chiliz Chain (CHZ)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '1',
#     'withdrawMax': '9999999',
#     'minConfirm': 15,
#     'unLockConfirm': 30,
#     'sameAddress': False}]},
#  {'coin': 'RAD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Radicle',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'RAD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '4.96',
#     'withdrawMin': '9.92',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'BAT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Basic Attention Token',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BNB',
#     'coin': 'BAT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Basic Attention Token (BAT). Both a MEMO and an Address are required to successfully deposit your BEP2 tokens to Binance.',
#     'name': 'Binance Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'addressRule': '',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.23',
#     'withdrawMin': '0.46',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True},
#    {'network': 'BSC',
#     'coin': 'BAT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Basic Attention Token. Please ensure you are depositing Basic Attention Token (BAT) tokens under the contract address ending in 9766e.',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.23',
#     'withdrawMin': '0.46',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'BAT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Basic Attention Token. Please ensure you are depositing Basic Attention Token (BAT) tokens under the contract address ending in 887ef.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '30',
#     'withdrawMin': '60',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'VRAB',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Verasity',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BNB',
#     'coin': 'VRAB',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please enter both MEMO and Address data, which are required to deposit VRAB BEP2 tokens to your Binance account.',
#     'name': 'Binance Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'addressRule': '',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '100',
#     'withdrawMin': '200',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True},
#    {'network': 'ETH',
#     'coin': 'VRAB',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'Sorry, we do not support deposits for this asset.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '300',
#     'withdrawMin': '600',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'AKRO',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Akropolis',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'AKRO',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '1972',
#     'withdrawMin': '3944',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'NZD',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'New Zealand Dollar',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'NZD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'We have disabled deposits as our systems are currently undergoing maintenance.',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'MOVR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Moonriver',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'MOVR',
#     'coin': 'MOVR',
#     'withdrawIntegerMultiple': '0.00001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Moonriver',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.003',
#     'withdrawMin': '0.006',
#     'withdrawMax': '9999999',
#     'minConfirm': 30,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'XMR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Monero',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'XMR',
#     'coin': 'XMR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Monero',
#     'resetAddressStatus': False,
#     'addressRegex': '^[48][a-zA-Z|\\d]{94}([a-zA-Z|\\d]{11})?$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.0001',
#     'withdrawMin': '0.0002',
#     'withdrawMax': '10000000000',
#     'minConfirm': 3,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': '1INCHDOWN',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': '1INCHDOWN',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETF',
#     'coin': '1INCHDOWN',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'Not support deposit',
#     'withdrawDesc': 'Not support withdrawal',
#     'specialTips': '',
#     'name': 'ETF',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False}]},
#  {'coin': 'COTI',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'COTI',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BNB',
#     'coin': 'COTI',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please enter both MEMO and Address data, which are required to deposit COTI BEP2 tokens to your Binance account.',
#     'name': 'Binance Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'addressRule': '',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.73',
#     'withdrawMin': '1.46',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True},
#    {'network': 'BSC',
#     'coin': 'COTI',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'Binance Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.73',
#     'withdrawMin': '1.46',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False},
#    {'network': 'ETH',
#     'coin': 'COTI',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '95',
#     'withdrawMin': '190',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False}]}]

# %%
coins= pd.DataFrame(client.get_all_coins_info())

# %%
coins
# Out:
#           coin  depositAllEnable  withdrawAllEnable  \
# 0         AGLD              True               True
# 1         STPT              True               True
# 2          MXN              True               True
# 3          UGX              True               True
# 4       RENBTC              True               True
# ..         ...               ...                ...
# 547        NZD             False              False
# 548       MOVR              True               True
# 549        XMR              True               True
# 550  1INCHDOWN             False              False
# 551       COTI              True               True
#
#                                name free locked freeze withdrawing ipoing  \
# 0                    Adventure Gold    0      0      0           0      0
# 1    Standard Tokenization Protocol    0      0      0           0      0
# 2                      Mexican Peso    0      0      0           0      0
# 3                   Uganda Shilling    0      0      0           0      0
# 4                            renBTC    0      0      0           0      0
# ..                              ...  ...    ...    ...         ...    ...
# 547              New Zealand Dollar    0      0      0           0      0
# 548                       Moonriver    0      0      0           0      0
# 549                          Monero    0      0      0           0      0
# 550                       1INCHDOWN    0      0      0           0      0
# 551                            COTI    0      0      0           0      0
#
#     ipoable storage  isLegalMoney  trading  \
# 0         0       0         False     True
# 1         0       0         False     True
# 2         0       0          True    False
# 3         0       0          True    False
# 4         0       0         False     True
# ..      ...     ...           ...      ...
# 547       0       0          True    False
# 548       0       0         False     True
# 549       0       0         False     True
# 550       0       0         False    False
# 551       0       0         False     True
#
#                                            networkList
# 0    [{'network': 'ETH', 'coin': 'AGLD', 'withdrawI...
# 1    [{'network': 'ETH', 'coin': 'STPT', 'withdrawI...
# 2    [{'network': 'FIAT_MONEY', 'coin': 'MXN', 'wit...
# 3    [{'network': 'FIAT_MONEY', 'coin': 'UGX', 'wit...
# 4    [{'network': 'BSC', 'coin': 'RENBTC', 'withdra...
# ..                                                 ...
# 547  [{'network': 'FIAT_MONEY', 'coin': 'NZD', 'wit...
# 548  [{'network': 'MOVR', 'coin': 'MOVR', 'withdraw...
# 549  [{'network': 'XMR', 'coin': 'XMR', 'withdrawIn...
# 550  [{'network': 'ETF', 'coin': '1INCHDOWN', 'with...
# 551  [{'network': 'BNB', 'coin': 'COTI', 'withdrawI...
#
# [552 rows x 14 columns]

# %%
coins.loc[coins.coin=='BTC']
# Out:
#     coin  depositAllEnable  withdrawAllEnable     name free locked freeze  \
# 323  BTC              True               True  Bitcoin    0      0      0
#
#     withdrawing ipoing ipoable storage  isLegalMoney  trading  \
# 323           0      0       0       0         False     True
#
#                                            networkList
# 323  [{'network': 'BNB', 'coin': 'BTC', 'withdrawIn...

# %%
coins.loc[coins.coin=='EUR']
# Out:
#     coin  depositAllEnable  withdrawAllEnable  name free locked freeze  \
# 253  EUR              True               True  Euro    0      0      0
#
#     withdrawing ipoing ipoable storage  isLegalMoney  trading  \
# 253           0      0       0       0          True     True
#
#                                            networkList
# 253  [{'network': 'FIAT_MONEY', 'coin': 'EUR', 'wit...

# %%
client.get_trade_fee(symbol="BTCUSDT")
# Out:
# [{'symbol': 'BTCUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'}]

# %%
client.get_trade_fee(symbol="BTCEUR")
# Out:
# [{'symbol': 'BTCEUR', 'makerCommission': '0.001', 'takerCommission': '0.001'}]

# %%
client.get_trade_fee(symbol="BTCBUSD")
# Out:
# [{'symbol': 'BTCBUSD', 'makerCommission': '0', 'takerCommission': '0.001'}]

# %% [markdown]
# ## GEtting current Market data

# %%
from binance.client import Client
import pandas as pd

# %%
client= Client(api_key=api_key, api_secret=secret_key, tld='com', testnet=False)

# %% [markdown]
# ### Current price

# %%
client.get_symbol_ticker(symbol="BTCUSDT")
# Out:
# {'symbol': 'BTCUSDT', 'price': '35678.01000000'}

# %%
float(client.get_symbol_ticker(symbol="ETHUSDT")["price"])
# Out:
# 2339.49

# %%
prices = client.get_all_tickers()
prices
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.06541900'},
#  {'symbol': 'LTCBTC', 'price': '0.00290100'},
#  {'symbol': 'BNBBTC', 'price': '0.01013000'},
#  {'symbol': 'NEOBTC', 'price': '0.00048800'},
#  {'symbol': 'QTUMETH', 'price': '0.00233600'},
#  {'symbol': 'EOSETH', 'price': '0.00091600'},
#  {'symbol': 'SNTETH', 'price': '0.00001960'},
#  {'symbol': 'BNTETH', 'price': '0.00095700'},
#  {'symbol': 'BCCBTC', 'price': '0.07908100'},
#  {'symbol': 'GASBTC', 'price': '0.00011170'},
#  {'symbol': 'BNBETH', 'price': '0.15470000'},
#  {'symbol': 'BTCUSDT', 'price': '35676.53000000'},
#  {'symbol': 'ETHUSDT', 'price': '2333.45000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00041400'},
#  {'symbol': 'OAXETH', 'price': '0.00017780'},
#  {'symbol': 'DNTETH', 'price': '0.00002801'},
#  {'symbol': 'MCOETH', 'price': '0.00577200'},
#  {'symbol': 'ICNETH', 'price': '0.00166300'},
#  {'symbol': 'MCOBTC', 'price': '0.00021140'},
#  {'symbol': 'WTCBTC', 'price': '0.00001337'},
#  {'symbol': 'WTCETH', 'price': '0.00023700'},
#  {'symbol': 'LRCBTC', 'price': '0.00002658'},
#  {'symbol': 'LRCETH', 'price': '0.00040598'},
#  {'symbol': 'QTUMBTC', 'price': '0.00015230'},
#  {'symbol': 'YOYOBTC', 'price': '0.00000031'},
#  {'symbol': 'OMGBTC', 'price': '0.00011470'},
#  {'symbol': 'OMGETH', 'price': '0.00175500'},
#  {'symbol': 'ZRXBTC', 'price': '0.00001423'},
#  {'symbol': 'ZRXETH', 'price': '0.00021750'},
#  {'symbol': 'STRATBTC', 'price': '0.00003085'},
#  {'symbol': 'STRATETH', 'price': '0.00105300'},
#  {'symbol': 'SNGLSBTC', 'price': '0.00000013'},
#  {'symbol': 'SNGLSETH', 'price': '0.00005306'},
#  {'symbol': 'BQXBTC', 'price': '0.00008703'},
#  {'symbol': 'BQXETH', 'price': '0.00126350'},
#  {'symbol': 'KNCBTC', 'price': '0.00004970'},
#  {'symbol': 'KNCETH', 'price': '0.00075660'},
#  {'symbol': 'FUNBTC', 'price': '0.00000029'},
#  {'symbol': 'FUNETH', 'price': '0.00000405'},
#  {'symbol': 'SNMBTC', 'price': '0.00000524'},
#  {'symbol': 'SNMETH', 'price': '0.00004986'},
#  {'symbol': 'NEOETH', 'price': '0.00747000'},
#  {'symbol': 'IOTABTC', 'price': '0.00002172'},
#  {'symbol': 'IOTAETH', 'price': '0.00033230'},
#  {'symbol': 'LINKBTC', 'price': '0.00040700'},
#  {'symbol': 'LINKETH', 'price': '0.00622400'},
#  {'symbol': 'XVGBTC', 'price': '0.00000027'},
#  {'symbol': 'XVGETH', 'price': '0.00000397'},
#  {'symbol': 'SALTBTC', 'price': '0.00004250'},
#  {'symbol': 'SALTETH', 'price': '0.00113800'},
#  {'symbol': 'MDABTC', 'price': '0.00001004'},
#  {'symbol': 'MDAETH', 'price': '0.00181150'},
#  {'symbol': 'MTLBTC', 'price': '0.00003799'},
#  {'symbol': 'MTLETH', 'price': '0.00058030'},
#  {'symbol': 'SUBBTC', 'price': '0.00000457'},
#  {'symbol': 'SUBETH', 'price': '0.00012334'},
#  {'symbol': 'EOSBTC', 'price': '0.00006000'},
#  {'symbol': 'SNTBTC', 'price': '0.00000128'},
#  {'symbol': 'ETCETH', 'price': '0.01009000'},
#  {'symbol': 'ETCBTC', 'price': '0.00066100'},
#  {'symbol': 'MTHBTC', 'price': '0.00000052'},
#  {'symbol': 'MTHETH', 'price': '0.00004135'},
#  {'symbol': 'ENGBTC', 'price': '0.00006200'},
#  {'symbol': 'ENGETH', 'price': '0.00186480'},
#  {'symbol': 'DNTBTC', 'price': '0.00000215'},
#  {'symbol': 'ZECBTC', 'price': '0.00239300'},
#  {'symbol': 'ZECETH', 'price': '0.03658000'},
#  {'symbol': 'BNTBTC', 'price': '0.00006266'},
#  {'symbol': 'ASTBTC', 'price': '0.00000440'},
#  {'symbol': 'ASTETH', 'price': '0.00006960'},
#  {'symbol': 'DASHBTC', 'price': '0.00248900'},
#  {'symbol': 'DASHETH', 'price': '0.03804000'},
#  {'symbol': 'OAXBTC', 'price': '0.00000319'},
#  {'symbol': 'ICNBTC', 'price': '0.00005742'},
#  {'symbol': 'BTGBTC', 'price': '0.00077800'},
#  {'symbol': 'BTGETH', 'price': '0.05274500'},
#  {'symbol': 'EVXBTC', 'price': '0.00000274'},
#  {'symbol': 'EVXETH', 'price': '0.00062490'},
#  {'symbol': 'REQBTC', 'price': '0.00000586'},
#  {'symbol': 'REQETH', 'price': '0.00004995'},
#  {'symbol': 'VIBBTC', 'price': '0.00000065'},
#  {'symbol': 'VIBETH', 'price': '0.00000990'},
#  {'symbol': 'HSRETH', 'price': '0.01247400'},
#  {'symbol': 'TRXBTC', 'price': '0.00000155'},
#  {'symbol': 'TRXETH', 'price': '0.00002365'},
#  {'symbol': 'POWRBTC', 'price': '0.00001433'},
#  {'symbol': 'POWRETH', 'price': '0.00021900'},
#  {'symbol': 'ARKBTC', 'price': '0.00002267'},
#  {'symbol': 'ARKETH', 'price': '0.00104600'},
#  {'symbol': 'YOYOETH', 'price': '0.00005828'},
#  {'symbol': 'XRPBTC', 'price': '0.00001659'},
#  {'symbol': 'XRPETH', 'price': '0.00025370'},
#  {'symbol': 'MODBTC', 'price': '0.00004280'},
#  {'symbol': 'MODETH', 'price': '0.00116700'},
#  {'symbol': 'ENJBTC', 'price': '0.00004248'},
#  {'symbol': 'ENJETH', 'price': '0.00065050'},
#  {'symbol': 'STORJBTC', 'price': '0.00002887'},
#  {'symbol': 'STORJETH', 'price': '0.00029910'},
#  {'symbol': 'BNBUSDT', 'price': '361.40000000'},
#  {'symbol': 'VENBNB', 'price': '0.14920000'},
#  {'symbol': 'YOYOBNB', 'price': '0.00059800'},
#  {'symbol': 'POWRBNB', 'price': '0.00385000'},
#  {'symbol': 'VENBTC', 'price': '0.00013928'},
#  {'symbol': 'VENETH', 'price': '0.00325194'},
#  {'symbol': 'KMDBTC', 'price': '0.00001332'},
#  {'symbol': 'KMDETH', 'price': '0.00020370'},
#  {'symbol': 'NULSBNB', 'price': '0.01257000'},
#  {'symbol': 'RCNBTC', 'price': '0.00000074'},
#  {'symbol': 'RCNETH', 'price': '0.00037604'},
#  {'symbol': 'RCNBNB', 'price': '0.00347300'},
#  {'symbol': 'NULSBTC', 'price': '0.00001029'},
#  {'symbol': 'NULSETH', 'price': '0.00051926'},
#  {'symbol': 'RDNBTC', 'price': '0.00000447'},
#  {'symbol': 'RDNETH', 'price': '0.00071530'},
#  {'symbol': 'RDNBNB', 'price': '0.00623000'},
#  {'symbol': 'XMRBTC', 'price': '0.00393000'},
#  {'symbol': 'XMRETH', 'price': '0.06011000'},
#  {'symbol': 'DLTBNB', 'price': '0.00240000'},
#  {'symbol': 'WTCBNB', 'price': '0.00180500'},
#  {'symbol': 'DLTBTC', 'price': '0.00000071'},
#  {'symbol': 'DLTETH', 'price': '0.00016807'},
#  {'symbol': 'AMBBTC', 'price': '0.00000045'},
#  {'symbol': 'AMBETH', 'price': '0.00004100'},
#  {'symbol': 'AMBBNB', 'price': '0.00068500'},
#  {'symbol': 'BCCETH', 'price': '2.47246000'},
#  {'symbol': 'BCCUSDT', 'price': '448.70000000'},
#  {'symbol': 'BCCBNB', 'price': '54.29000000'},
#  {'symbol': 'BATBTC', 'price': '0.00002264'},
#  {'symbol': 'BATETH', 'price': '0.00034630'},
#  {'symbol': 'BATBNB', 'price': '0.00183100'},
#  {'symbol': 'BCPTBTC', 'price': '0.00000048'},
#  {'symbol': 'BCPTETH', 'price': '0.00008181'},
#  {'symbol': 'BCPTBNB', 'price': '0.00116200'},
#  {'symbol': 'ARNBTC', 'price': '0.00000761'},
#  {'symbol': 'ARNETH', 'price': '0.00029362'},
#  {'symbol': 'GVTBTC', 'price': '0.00001792'},
#  {'symbol': 'GVTETH', 'price': '0.00384600'},
#  {'symbol': 'CDTBTC', 'price': '0.00000317'},
#  {'symbol': 'CDTETH', 'price': '0.00005119'},
#  {'symbol': 'GXSBTC', 'price': '0.00003756'},
#  {'symbol': 'GXSETH', 'price': '0.00057330'},
#  {'symbol': 'NEOUSDT', 'price': '17.42000000'},
#  {'symbol': 'NEOBNB', 'price': '0.04820000'},
#  {'symbol': 'POEBTC', 'price': '0.00000005'},
#  {'symbol': 'POEETH', 'price': '0.00000664'},
#  {'symbol': 'QSPBTC', 'price': '0.00000100'},
#  {'symbol': 'QSPETH', 'price': '0.00001549'},
#  {'symbol': 'QSPBNB', 'price': '0.00052350'},
#  {'symbol': 'BTSBTC', 'price': '0.00000064'},
#  {'symbol': 'BTSETH', 'price': '0.00009498'},
#  {'symbol': 'BTSBNB', 'price': '0.00144800'},
#  {'symbol': 'XZCBTC', 'price': '0.00013550'},
#  {'symbol': 'XZCETH', 'price': '0.00310000'},
#  {'symbol': 'XZCBNB', 'price': '0.26750000'},
#  {'symbol': 'LSKBTC', 'price': '0.00004264'},
#  {'symbol': 'LSKETH', 'price': '0.00065100'},
#  {'symbol': 'LSKBNB', 'price': '0.06494000'},
#  {'symbol': 'TNTBTC', 'price': '0.00000261'},
#  {'symbol': 'TNTETH', 'price': '0.00000920'},
#  {'symbol': 'FUELBTC', 'price': '0.00000026'},
#  {'symbol': 'FUELETH', 'price': '0.00002221'},
#  {'symbol': 'MANABTC', 'price': '0.00005962'},
#  {'symbol': 'MANAETH', 'price': '0.00091380'},
#  {'symbol': 'BCDBTC', 'price': '0.00002395'},
#  {'symbol': 'BCDETH', 'price': '0.00251000'},
#  {'symbol': 'DGDBTC', 'price': '0.00393100'},
#  {'symbol': 'DGDETH', 'price': '0.19260000'},
#  {'symbol': 'IOTABNB', 'price': '0.00214600'},
#  {'symbol': 'ADXBTC', 'price': '0.00001102'},
#  {'symbol': 'ADXETH', 'price': '0.00016840'},
#  {'symbol': 'ADXBNB', 'price': '0.00492900'},
#  {'symbol': 'ADABTC', 'price': '0.00002834'},
#  {'symbol': 'ADAETH', 'price': '0.00043320'},
#  {'symbol': 'PPTBTC', 'price': '0.00001855'},
#  {'symbol': 'PPTETH', 'price': '0.00141000'},
#  {'symbol': 'CMTBTC', 'price': '0.00000028'},
#  {'symbol': 'CMTETH', 'price': '0.00000625'},
#  {'symbol': 'CMTBNB', 'price': '0.00057700'},
#  {'symbol': 'XLMBTC', 'price': '0.00000529'},
#  {'symbol': 'XLMETH', 'price': '0.00008080'},
#  {'symbol': 'XLMBNB', 'price': '0.00052200'},
#  {'symbol': 'CNDBTC', 'price': '0.00000015'},
#  {'symbol': 'CNDETH', 'price': '0.00002599'},
#  {'symbol': 'CNDBNB', 'price': '0.00033990'},
#  {'symbol': 'LENDBTC', 'price': '0.00004512'},
#  {'symbol': 'LENDETH', 'price': '0.00137174'},
#  {'symbol': 'WABIBTC', 'price': '0.00000322'},
#  {'symbol': 'WABIETH', 'price': '0.00040308'},
#  {'symbol': 'WABIBNB', 'price': '0.00031720'},
#  {'symbol': 'LTCETH', 'price': '0.04433000'},
#  {'symbol': 'LTCUSDT', 'price': '103.40000000'},
#  {'symbol': 'LTCBNB', 'price': '0.28600000'},
#  {'symbol': 'TNBBTC', 'price': '0.00000007'},
#  {'symbol': 'TNBETH', 'price': '0.00000752'},
#  {'symbol': 'WAVESBTC', 'price': '0.00026210'},
#  {'symbol': 'WAVESETH', 'price': '0.00401000'},
#  {'symbol': 'WAVESBNB', 'price': '0.02602000'},
#  {'symbol': 'GTOBTC', 'price': '0.00000081'},
#  {'symbol': 'GTOETH', 'price': '0.00003197'},
#  {'symbol': 'GTOBNB', 'price': '0.00035200'},
#  {'symbol': 'ICXBTC', 'price': '0.00001860'},
#  {'symbol': 'ICXETH', 'price': '0.00028410'},
#  {'symbol': 'ICXBNB', 'price': '0.00465400'},
#  {'symbol': 'OSTBTC', 'price': '0.00000032'},
#  {'symbol': 'OSTETH', 'price': '0.00000225'},
#  {'symbol': 'OSTBNB', 'price': '0.00052500'},
#  {'symbol': 'ELFBTC', 'price': '0.00000872'},
#  {'symbol': 'ELFETH', 'price': '0.00013340'},
#  {'symbol': 'AIONBTC', 'price': '0.00000228'},
#  {'symbol': 'AIONETH', 'price': '0.00003500'},
#  {'symbol': 'AIONBNB', 'price': '0.00261300'},
#  {'symbol': 'NEBLBTC', 'price': '0.00001462'},
#  {'symbol': 'NEBLBNB', 'price': '0.01356000'},
#  {'symbol': 'BRDBTC', 'price': '0.00000664'},
#  {'symbol': 'BRDETH', 'price': '0.00010095'},
#  {'symbol': 'BRDBNB', 'price': '0.00247000'},
#  {'symbol': 'MCOBNB', 'price': '0.26837000'},
#  {'symbol': 'EDOBTC', 'price': '0.00005609'},
#  {'symbol': 'EDOETH', 'price': '0.00226600'},
#  {'symbol': 'WINGSBTC', 'price': '0.00001193'},
#  {'symbol': 'WINGSETH', 'price': '0.00033460'},
#  {'symbol': 'NAVBTC', 'price': '0.00000394'},
#  {'symbol': 'NAVETH', 'price': '0.00011870'},
#  {'symbol': 'NAVBNB', 'price': '0.00423700'},
#  {'symbol': 'LUNBTC', 'price': '0.00008510'},
#  {'symbol': 'LUNETH', 'price': '0.00489100'},
#  {'symbol': 'TRIGBTC', 'price': '0.00001980'},
#  {'symbol': 'TRIGETH', 'price': '0.00059400'},
#  {'symbol': 'TRIGBNB', 'price': '0.01218000'},
#  {'symbol': 'APPCBTC', 'price': '0.00000055'},
#  {'symbol': 'APPCETH', 'price': '0.00014600'},
#  {'symbol': 'APPCBNB', 'price': '0.00189100'},
#  {'symbol': 'VIBEBTC', 'price': '0.00000042'},
#  {'symbol': 'VIBEETH', 'price': '0.00005720'},
#  {'symbol': 'RLCBTC', 'price': '0.00004959'},
#  {'symbol': 'RLCETH', 'price': '0.00075800'},
#  {'symbol': 'RLCBNB', 'price': '0.03344000'},
#  {'symbol': 'INSBTC', 'price': '0.00000618'},
#  {'symbol': 'INSETH', 'price': '0.00050100'},
#  {'symbol': 'PIVXBTC', 'price': '0.00000882'},
#  {'symbol': 'PIVXBNB', 'price': '0.01660000'},
#  {'symbol': 'IOSTBTC', 'price': '0.00000064'},
#  {'symbol': 'IOSTETH', 'price': '0.00000982'},
#  {'symbol': 'CHATBTC', 'price': '0.00000195'},
#  {'symbol': 'CHATETH', 'price': '0.00006585'},
#  {'symbol': 'STEEMBTC', 'price': '0.00000815'},
#  {'symbol': 'STEEMETH', 'price': '0.00012410'},
#  {'symbol': 'STEEMBNB', 'price': '0.00448000'},
#  {'symbol': 'NANOBTC', 'price': '0.00006280'},
#  {'symbol': 'NANOETH', 'price': '0.00090500'},
#  {'symbol': 'NANOBNB', 'price': '0.05589000'},
#  {'symbol': 'VIABTC', 'price': '0.00000681'},
#  {'symbol': 'VIAETH', 'price': '0.00085600'},
#  {'symbol': 'VIABNB', 'price': '0.00958000'},
#  {'symbol': 'BLZBTC', 'price': '0.00000328'},
#  {'symbol': 'BLZETH', 'price': '0.00005013'},
#  {'symbol': 'BLZBNB', 'price': '0.00062190'},
#  {'symbol': 'AEBTC', 'price': '0.00000292'},
#  {'symbol': 'AEETH', 'price': '0.00021900'},
#  {'symbol': 'AEBNB', 'price': '0.00777000'},
#  {'symbol': 'RPXBTC', 'price': '0.00000224'},
#  {'symbol': 'RPXETH', 'price': '0.00005449'},
#  {'symbol': 'RPXBNB', 'price': '0.00145700'},
#  {'symbol': 'NCASHBTC', 'price': '0.00000005'},
#  {'symbol': 'NCASHETH', 'price': '0.00000044'},
#  {'symbol': 'NCASHBNB', 'price': '0.00006790'},
#  {'symbol': 'POABTC', 'price': '0.00000041'},
#  {'symbol': 'POAETH', 'price': '0.00004891'},
#  {'symbol': 'POABNB', 'price': '0.00092100'},
#  {'symbol': 'ZILBTC', 'price': '0.00000119'},
#  {'symbol': 'ZILETH', 'price': '0.00001820'},
#  {'symbol': 'ZILBNB', 'price': '0.00011820'},
#  {'symbol': 'ONTBTC', 'price': '0.00001252'},
#  {'symbol': 'ONTETH', 'price': '0.00019120'},
#  {'symbol': 'ONTBNB', 'price': '0.00246200'},
#  {'symbol': 'STORMBTC', 'price': '0.00000035'},
#  {'symbol': 'STORMETH', 'price': '0.00001398'},
#  {'symbol': 'STORMBNB', 'price': '0.00006550'},
#  {'symbol': 'QTUMBNB', 'price': '0.09597000'},
#  {'symbol': 'QTUMUSDT', 'price': '5.42900000'},
#  {'symbol': 'XEMBTC', 'price': '0.00000268'},
#  {'symbol': 'XEMETH', 'price': '0.00004072'},
#  {'symbol': 'XEMBNB', 'price': '0.00244100'},
#  {'symbol': 'WANBTC', 'price': '0.00001128'},
#  {'symbol': 'WANETH', 'price': '0.00017180'},
#  {'symbol': 'WANBNB', 'price': '0.00181000'},
#  {'symbol': 'WPRBTC', 'price': '0.00000027'},
#  {'symbol': 'WPRETH', 'price': '0.00004020'},
#  {'symbol': 'QLCBTC', 'price': '0.00000053'},
#  {'symbol': 'QLCETH', 'price': '0.00000800'},
#  {'symbol': 'SYSBTC', 'price': '0.00002160'},
#  {'symbol': 'SYSETH', 'price': '0.00011047'},
#  {'symbol': 'SYSBNB', 'price': '0.00163500'},
#  {'symbol': 'QLCBNB', 'price': '0.00092200'},
#  {'symbol': 'GRSBTC', 'price': '0.00001461'},
#  {'symbol': 'GRSETH', 'price': '0.00076455'},
#  {'symbol': 'ADAUSDT', 'price': '1.01000000'},
#  {'symbol': 'ADABNB', 'price': '0.00279700'},
#  {'symbol': 'CLOAKBTC', 'price': '0.00015550'},
#  {'symbol': 'CLOAKETH', 'price': '0.00414200'},
#  {'symbol': 'GNTBTC', 'price': '0.00000678'},
#  {'symbol': 'GNTETH', 'price': '0.00022071'},
#  {'symbol': 'GNTBNB', 'price': '0.00243900'},
#  {'symbol': 'LOOMBTC', 'price': '0.00000164'},
#  {'symbol': 'LOOMETH', 'price': '0.00002507'},
#  {'symbol': 'LOOMBNB', 'price': '0.00088500'},
#  {'symbol': 'XRPUSDT', 'price': '0.59170000'},
#  {'symbol': 'BCNBTC', 'price': '0.00000022'},
#  {'symbol': 'BCNETH', 'price': '0.00000707'},
#  {'symbol': 'BCNBNB', 'price': '0.00002000'},
#  {'symbol': 'REPBTC', 'price': '0.00034150'},
#  {'symbol': 'REPBNB', 'price': '0.44670000'},
#  {'symbol': 'BTCTUSD', 'price': '35751.96000000'},
#  {'symbol': 'TUSDBTC', 'price': '0.00025971'},
#  {'symbol': 'ETHTUSD', 'price': '2341.41000000'},
#  {'symbol': 'TUSDETH', 'price': '0.00762097'},
#  {'symbol': 'TUSDBNB', 'price': '0.06777000'},
#  {'symbol': 'ZENBTC', 'price': '0.00099400'},
#  {'symbol': 'ZENETH', 'price': '0.01519000'},
#  {'symbol': 'ZENBNB', 'price': '0.09810000'},
#  {'symbol': 'SKYBTC', 'price': '0.00000829'},
#  {'symbol': 'SKYETH', 'price': '0.00222000'},
#  {'symbol': 'SKYBNB', 'price': '0.03022000'},
#  {'symbol': 'EOSUSDT', 'price': '2.13800000'},
#  {'symbol': 'EOSBNB', 'price': '0.00592000'},
#  {'symbol': 'CVCBTC', 'price': '0.00000653'},
#  {'symbol': 'CVCETH', 'price': '0.00009960'},
#  {'symbol': 'CVCBNB', 'price': '0.00211200'},
#  {'symbol': 'THETABTC', 'price': '0.00008220'},
#  {'symbol': 'THETAETH', 'price': '0.00125600'},
#  {'symbol': 'THETABNB', 'price': '0.00811000'},
#  {'symbol': 'XRPBNB', 'price': '0.00163600'},
#  {'symbol': 'TUSDUSDT', 'price': '0.99970000'},
#  {'symbol': 'IOTAUSDT', 'price': '0.77490000'},
#  {'symbol': 'XLMUSDT', 'price': '0.18870000'},
#  {'symbol': 'IOTXBTC', 'price': '0.00000200'},
#  {'symbol': 'IOTXETH', 'price': '0.00003062'},
#  {'symbol': 'QKCBTC', 'price': '0.00000040'},
#  {'symbol': 'QKCETH', 'price': '0.00000599'},
#  {'symbol': 'AGIBTC', 'price': '0.00000668'},
#  {'symbol': 'AGIETH', 'price': '0.00007363'},
#  {'symbol': 'AGIBNB', 'price': '0.00077200'},
#  {'symbol': 'NXSBTC', 'price': '0.00000799'},
#  {'symbol': 'NXSETH', 'price': '0.00077300'},
#  {'symbol': 'NXSBNB', 'price': '0.01087000'},
#  {'symbol': 'ENJBNB', 'price': '0.00418300'},
#  {'symbol': 'DATABTC', 'price': '0.00000199'},
#  {'symbol': 'DATAETH', 'price': '0.00003030'},
#  {'symbol': 'ONTUSDT', 'price': '0.44660000'},
#  {'symbol': 'TRXBNB', 'price': '0.00015270'},
#  {'symbol': 'TRXUSDT', 'price': '0.05520000'},
#  {'symbol': 'ETCUSDT', 'price': '23.55000000'},
#  {'symbol': 'ETCBNB', 'price': '0.06530000'},
#  {'symbol': 'ICXUSDT', 'price': '0.66200000'},
#  {'symbol': 'SCBTC', 'price': '0.00000026'},
#  {'symbol': 'SCETH', 'price': '0.00000397'},
#  {'symbol': 'NPXSBTC', 'price': '0.00000003'},
#  {'symbol': 'NPXSETH', 'price': '0.00000345'},
#  {'symbol': 'VENUSDT', 'price': '0.00010000'},
#  {'symbol': 'KEYBTC', 'price': '0.00000013'},
#  {'symbol': 'KEYETH', 'price': '0.00000255'},
#  {'symbol': 'NASBTC', 'price': '0.00000610'},
#  {'symbol': 'NASETH', 'price': '0.00009180'},
#  {'symbol': 'NASBNB', 'price': '0.02337000'},
#  {'symbol': 'MFTBTC', 'price': '0.00000008'},
#  {'symbol': 'MFTETH', 'price': '0.00000244'},
#  {'symbol': 'MFTBNB', 'price': '0.00001580'},
#  {'symbol': 'DENTBTC', 'price': '0.00000004'},
#  {'symbol': 'DENTETH', 'price': '0.00000102'},
#  {'symbol': 'ARDRBTC', 'price': '0.00000463'},
#  {'symbol': 'ARDRETH', 'price': '0.00018870'},
#  {'symbol': 'ARDRBNB', 'price': '0.00316800'},
#  {'symbol': 'NULSUSDT', 'price': '0.36800000'},
#  {'symbol': 'HOTBTC', 'price': '0.00000002'},
#  {'symbol': 'HOTETH', 'price': '0.00000181'},
#  {'symbol': 'VETBTC', 'price': '0.00000142'},
#  {'symbol': 'VETETH', 'price': '0.00002160'},
#  {'symbol': 'VETUSDT', 'price': '0.05040000'},
#  {'symbol': 'VETBNB', 'price': '0.00013950'},
#  {'symbol': 'DOCKBTC', 'price': '0.00000117'},
#  {'symbol': 'DOCKETH', 'price': '0.00003283'},
#  {'symbol': 'POLYBTC', 'price': '0.00001002'},
#  {'symbol': 'POLYBNB', 'price': '0.00145900'},
#  {'symbol': 'PHXBTC', 'price': '0.00000180'},
#  {'symbol': 'PHXETH', 'price': '0.00005617'},
#  {'symbol': 'PHXBNB', 'price': '0.00045600'},
#  {'symbol': 'HCBTC', 'price': '0.00002000'},
#  {'symbol': 'HCETH', 'price': '0.00513400'},
#  {'symbol': 'GOBTC', 'price': '0.00000054'},
#  {'symbol': 'GOBNB', 'price': '0.00069230'},
#  {'symbol': 'PAXBTC', 'price': '0.00025175'},
#  {'symbol': 'PAXBNB', 'price': '0.20121000'},
#  {'symbol': 'PAXUSDT', 'price': '0.99960000'},
#  {'symbol': 'PAXETH', 'price': '0.00888047'},
#  {'symbol': 'RVNBTC', 'price': '0.00000177'},
#  {'symbol': 'DCRBTC', 'price': '0.00163800'},
#  {'symbol': 'DCRBNB', 'price': '0.78100000'},
#  {'symbol': 'USDCBNB', 'price': '0.21755000'},
#  {'symbol': 'MITHBTC', 'price': '0.00000089'},
#  {'symbol': 'MITHBNB', 'price': '0.00008800'},
#  {'symbol': 'BCHABCBTC', 'price': '0.02933000'},
#  {'symbol': 'BCHSVBTC', 'price': '0.01117900'},
#  {'symbol': 'BCHABCUSDT', 'price': '220.08000000'},
#  {'symbol': 'BCHSVUSDT', 'price': '58.90000000'},
#  {'symbol': 'BNBPAX', 'price': '495.10000000'},
#  {'symbol': 'BTCPAX', 'price': '51529.15000000'},
#  {'symbol': 'ETHPAX', 'price': '3904.41000000'},
#  {'symbol': 'XRPPAX', 'price': '0.88960000'},
#  {'symbol': 'EOSPAX', 'price': '2.58450000'},
#  {'symbol': 'XLMPAX', 'price': '0.04221000'},
#  {'symbol': 'RENBTC', 'price': '0.00000836'},
#  {'symbol': 'RENBNB', 'price': '0.00458500'},
#  {'symbol': 'BNBTUSD', 'price': '362.00000000'},
#  {'symbol': 'XRPTUSD', 'price': '0.59200000'},
#  {'symbol': 'EOSTUSD', 'price': '4.11590000'},
#  {'symbol': 'XLMTUSD', 'price': '0.06833000'},
#  {'symbol': 'BNBUSDC', 'price': '362.40000000'},
#  {'symbol': 'BTCUSDC', 'price': '35687.18000000'},
#  {'symbol': 'ETHUSDC', 'price': '2334.68000000'},
#  {'symbol': 'XRPUSDC', 'price': '0.59180000'},
#  {'symbol': 'EOSUSDC', 'price': '2.14600000'},
#  {'symbol': 'XLMUSDC', 'price': '0.04970000'},
#  {'symbol': 'USDCUSDT', 'price': '0.99980000'},
#  {'symbol': 'ADATUSD', 'price': '1.01000000'},
#  {'symbol': 'TRXTUSD', 'price': '0.05522000'},
#  {'symbol': 'NEOTUSD', 'price': '11.81800000'},
#  {'symbol': 'TRXXRP', 'price': '0.09321000'},
#  {'symbol': 'XZCXRP', 'price': '20.79200000'},
#  {'symbol': 'PAXTUSD', 'price': '0.99950000'},
#  {'symbol': 'USDCTUSD', 'price': '1.00000000'},
#  {'symbol': 'USDCPAX', 'price': '1.00020000'},
#  {'symbol': 'LINKUSDT', 'price': '14.51000000'},
#  {'symbol': 'LINKTUSD', 'price': '28.87000000'},
#  {'symbol': 'LINKPAX', 'price': '3.98340000'},
#  {'symbol': 'LINKUSDC', 'price': '14.54000000'},
#  {'symbol': 'WAVESUSDT', 'price': '9.35000000'},
#  {'symbol': 'WAVESTUSD', 'price': '1.07200000'},
#  {'symbol': 'WAVESPAX', 'price': '0.80290000'},
#  {'symbol': 'WAVESUSDC', 'price': '1.20360000'},
#  {'symbol': 'BCHABCTUSD', 'price': '220.20000000'},
#  {'symbol': 'BCHABCPAX', 'price': '221.20000000'},
#  {'symbol': 'BCHABCUSDC', 'price': '220.30000000'},
#  {'symbol': 'BCHSVTUSD', 'price': '59.17000000'},
#  {'symbol': 'BCHSVPAX', 'price': '58.18000000'},
#  {'symbol': 'BCHSVUSDC', 'price': '57.50000000'},
#  {'symbol': 'LTCTUSD', 'price': '150.10000000'},
#  {'symbol': 'LTCPAX', 'price': '171.13000000'},
#  {'symbol': 'LTCUSDC', 'price': '103.80000000'},
#  {'symbol': 'TRXPAX', 'price': '0.07661000'},
#  {'symbol': 'TRXUSDC', 'price': '0.05522000'},
#  {'symbol': 'BTTBTC', 'price': '0.00000005'},
#  {'symbol': 'BTTBNB', 'price': '0.00000573'},
#  {'symbol': 'BTTUSDT', 'price': '0.00277700'},
#  {'symbol': 'BNBUSDS', 'price': '22.27880000'},
#  {'symbol': 'BTCUSDS', 'price': '9604.59000000'},
#  {'symbol': 'USDSUSDT', 'price': '0.99680000'},
#  {'symbol': 'USDSPAX', 'price': '1.00020000'},
#  {'symbol': 'USDSTUSD', 'price': '1.00000000'},
#  {'symbol': 'USDSUSDC', 'price': '1.00000000'},
#  {'symbol': 'BTTPAX', 'price': '0.00038660'},
#  {'symbol': 'BTTTUSD', 'price': '0.00277000'},
#  {'symbol': 'BTTUSDC', 'price': '0.00277600'},
#  {'symbol': 'ONGBNB', 'price': '0.00545000'},
#  {'symbol': 'ONGBTC', 'price': '0.00001648'},
#  {'symbol': 'ONGUSDT', 'price': '0.58810000'},
#  {'symbol': 'HOTBNB', 'price': '0.00001173'},
#  {'symbol': 'HOTUSDT', 'price': '0.00424200'},
#  {'symbol': 'ZILUSDT', 'price': '0.04257000'},
#  {'symbol': 'ZRXBNB', 'price': '0.01045000'},
#  {'symbol': 'ZRXUSDT', 'price': '0.50760000'},
#  {'symbol': 'FETBNB', 'price': '0.00082700'},
#  {'symbol': 'FETBTC', 'price': '0.00000839'},
#  {'symbol': 'FETUSDT', 'price': '0.29960000'},
#  {'symbol': 'BATUSDT', 'price': '0.80790000'},
#  {'symbol': 'XMRBNB', 'price': '0.38850000'},
#  {'symbol': 'XMRUSDT', 'price': '140.30000000'},
#  {'symbol': 'ZECBNB', 'price': '0.23650000'},
#  {'symbol': 'ZECUSDT', 'price': '85.30000000'},
#  {'symbol': 'ZECPAX', 'price': '42.10000000'},
#  {'symbol': 'ZECTUSD', 'price': '51.48000000'},
#  {'symbol': 'ZECUSDC', 'price': '85.30000000'},
#  {'symbol': 'IOSTUSDT', 'price': '0.02296000'},
#  {'symbol': 'CELRBNB', 'price': '0.00013217'},
#  {'symbol': 'CELRBTC', 'price': '0.00000134'},
#  {'symbol': 'CELRUSDT', 'price': '0.04776000'},
#  {'symbol': 'ADAPAX', 'price': '0.03257000'},
#  {'symbol': 'ADAUSDC', 'price': '1.01300000'},
#  {'symbol': 'NEOPAX', 'price': '11.12200000'},
#  {'symbol': 'NEOUSDC', 'price': '28.27000000'},
#  {'symbol': 'DASHBNB', 'price': '0.24650000'},
#  {'symbol': 'DASHUSDT', 'price': '88.80000000'},
#  {'symbol': 'NANOUSDT', 'price': '2.22400000'},
#  {'symbol': 'OMGBNB', 'price': '0.03938000'},
#  {'symbol': 'OMGUSDT', 'price': '4.08900000'},
#  {'symbol': 'THETAUSDT', 'price': '2.93100000'},
#  {'symbol': 'ENJUSDT', 'price': '1.51500000'},
#  {'symbol': 'MITHUSDT', 'price': '0.03195000'},
#  {'symbol': 'MATICBNB', 'price': '0.00421700'},
#  {'symbol': 'MATICBTC', 'price': '0.00004272'},
#  {'symbol': 'MATICUSDT', 'price': '1.52500000'},
#  {'symbol': 'ATOMBNB', 'price': '0.08081000'},
#  {'symbol': 'ATOMBTC', 'price': '0.00081910'},
#  {'symbol': 'ATOMUSDT', 'price': '29.22000000'},
#  {'symbol': 'ATOMUSDC', 'price': '29.18000000'},
#  {'symbol': 'ATOMPAX', 'price': '3.17800000'},
#  {'symbol': 'ATOMTUSD', 'price': '2.59800000'},
#  {'symbol': 'ETCUSDC', 'price': '4.71000000'},
#  {'symbol': 'ETCPAX', 'price': '4.83800000'},
#  {'symbol': 'ETCTUSD', 'price': '3.79500000'},
#  {'symbol': 'BATUSDC', 'price': '0.63130000'},
#  {'symbol': 'BATPAX', 'price': '0.25560000'},
#  {'symbol': 'BATTUSD', 'price': '0.22220000'},
#  {'symbol': 'PHBBNB', 'price': '0.00013700'},
#  {'symbol': 'PHBBTC', 'price': '0.00000780'},
#  {'symbol': 'PHBUSDC', 'price': '0.00587000'},
#  {'symbol': 'PHBTUSD', 'price': '0.27800000'},
#  {'symbol': 'PHBPAX', 'price': '0.00639000'},
#  {'symbol': 'TFUELBNB', 'price': '0.00012590'},
#  {'symbol': 'TFUELBTC', 'price': '0.00000496'},
#  {'symbol': 'TFUELUSDT', 'price': '0.17670000'},
#  {'symbol': 'TFUELUSDC', 'price': '0.00356500'},
#  {'symbol': 'TFUELTUSD', 'price': '0.00307700'},
#  {'symbol': 'TFUELPAX', 'price': '0.00348700'},
#  {'symbol': 'ONEBNB', 'price': '0.00047890'},
#  {'symbol': 'ONEBTC', 'price': '0.00000486'},
#  {'symbol': 'ONEUSDT', 'price': '0.17319000'},
#  {'symbol': 'ONETUSD', 'price': '0.00472000'},
#  {'symbol': 'ONEPAX', 'price': '0.00496000'},
#  {'symbol': 'ONEUSDC', 'price': '0.00520000'},
#  {'symbol': 'FTMBNB', 'price': '0.00557700'},
#  {'symbol': 'FTMBTC', 'price': '0.00005642'},
#  {'symbol': 'FTMUSDT', 'price': '2.01350000'},
#  {'symbol': 'FTMTUSD', 'price': '0.01095000'},
#  {'symbol': 'FTMPAX', 'price': '0.01028000'},
#  {'symbol': 'FTMUSDC', 'price': '0.01107000'},
#  {'symbol': 'BTCBBTC', 'price': '1.00000000'},
#  {'symbol': 'BCPTTUSD', 'price': '0.02606000'},
#  {'symbol': 'BCPTPAX', 'price': '0.02761000'},
#  {'symbol': 'BCPTUSDC', 'price': '0.02728000'},
#  {'symbol': 'ALGOBNB', 'price': '0.00245200'},
#  {'symbol': 'ALGOBTC', 'price': '0.00002485'},
#  {'symbol': 'ALGOUSDT', 'price': '0.88610000'},
#  {'symbol': 'ALGOTUSD', 'price': '1.01700000'},
#  {'symbol': 'ALGOPAX', 'price': '0.20390000'},
#  {'symbol': 'ALGOUSDC', 'price': '0.23800000'},
#  {'symbol': 'USDSBUSDT', 'price': '0.99970000'},
#  {'symbol': 'USDSBUSDS', 'price': '0.99990000'},
#  {'symbol': 'GTOUSDT', 'price': '0.02918000'},
#  {'symbol': 'GTOPAX', 'price': '0.01361000'},
#  {'symbol': 'GTOTUSD', 'price': '0.01236000'},
#  {'symbol': 'GTOUSDC', 'price': '0.01196000'},
#  {'symbol': 'ERDBNB', 'price': '0.00083273'},
#  {'symbol': 'ERDBTC', 'price': '0.00000168'},
#  {'symbol': 'ERDUSDT', 'price': '0.01971000'},
#  {'symbol': 'ERDPAX', 'price': '0.00125270'},
#  {'symbol': 'ERDUSDC', 'price': '0.00135730'},
#  {'symbol': 'DOGEBNB', 'price': '0.00015270'},
#  {'symbol': 'DOGEBTC', 'price': '0.00000384'},
#  {'symbol': 'DOGEUSDT', 'price': '0.13720000'},
#  {'symbol': 'DOGEPAX', 'price': '0.00216820'},
#  {'symbol': 'DOGEUSDC', 'price': '0.00212770'},
#  {'symbol': 'DUSKBNB', 'price': '0.00118000'},
#  {'symbol': 'DUSKBTC', 'price': '0.00001774'},
#  {'symbol': 'DUSKUSDT', 'price': '0.63170000'},
#  {'symbol': 'DUSKUSDC', 'price': '0.01790000'},
#  {'symbol': 'DUSKPAX', 'price': '0.01890000'},
#  {'symbol': 'BGBPUSDC', 'price': '1.39000000'},
#  {'symbol': 'ANKRBNB', 'price': '0.00019870'},
#  {'symbol': 'ANKRBTC', 'price': '0.00000200'},
#  {'symbol': 'ANKRUSDT', 'price': '0.07120000'},
#  {'symbol': 'ANKRTUSD', 'price': '0.00212800'},
#  {'symbol': 'ANKRPAX', 'price': '0.00209300'},
#  {'symbol': 'ANKRUSDC', 'price': '0.00209700'},
#  {'symbol': 'ONTPAX', 'price': '0.84510000'},
#  {'symbol': 'ONTUSDC', 'price': '0.57080000'},
#  {'symbol': 'WINBNB', 'price': '0.00000080'},
#  {'symbol': 'WINBTC', 'price': '0.00000001'},
#  {'symbol': 'WINUSDT', 'price': '0.00028900'},
#  {'symbol': 'WINUSDC', 'price': '0.00028910'},
#  {'symbol': 'COSBNB', 'price': '0.00003822'},
#  {'symbol': 'COSBTC', 'price': '0.00000038'},
#  {'symbol': 'COSUSDT', 'price': '0.01381000'},
#  {'symbol': 'TUSDBTUSD', 'price': '0.99750000'},
#  {'symbol': 'NPXSUSDT', 'price': '0.00703010'},
#  {'symbol': 'NPXSUSDC', 'price': '0.00017020'},
#  {'symbol': 'COCOSBNB', 'price': '0.00283400'},
#  {'symbol': 'COCOSBTC', 'price': '0.00000003'},
#  {'symbol': 'COCOSUSDT', 'price': '1.02620000'},
#  {'symbol': 'MTLUSDT', 'price': '1.35600000'},
#  {'symbol': 'TOMOBNB', 'price': '0.03255000'},
#  {'symbol': 'TOMOBTC', 'price': '0.00003069'},
#  {'symbol': 'TOMOUSDT', 'price': '1.09300000'},
#  {'symbol': 'TOMOUSDC', 'price': '0.36700000'},
#  {'symbol': 'PERLBNB', 'price': '0.00012720'},
#  {'symbol': 'PERLBTC', 'price': '0.00000128'},
#  {'symbol': 'PERLUSDC', 'price': '0.02447000'},
#  {'symbol': 'PERLUSDT', 'price': '0.04566000'},
#  {'symbol': 'DENTUSDT', 'price': '0.00238500'},
#  {'symbol': 'MFTUSDT', 'price': '0.00569900'},
#  {'symbol': 'KEYUSDT', 'price': '0.00598700'},
#  {'symbol': 'STORMUSDT', 'price': '0.00339700'},
#  {'symbol': 'DOCKUSDT', 'price': '0.04182000'},
#  {'symbol': 'WANUSDT', 'price': '0.40260000'},
#  {'symbol': 'FUNUSDT', 'price': '0.00946000'},
#  {'symbol': 'CVCUSDT', 'price': '0.23330000'},
#  {'symbol': 'BTTTRX', 'price': '0.03945000'},
#  {'symbol': 'WINTRX', 'price': '0.00523400'},
#  {'symbol': 'CHZBNB', 'price': '0.00046730'},
#  {'symbol': 'CHZBTC', 'price': '0.00000474'},
#  {'symbol': 'CHZUSDT', 'price': '0.16900000'},
#  {'symbol': 'BANDBNB', 'price': '0.02248000'},
#  {'symbol': 'BANDBTC', 'price': '0.00009280'},
#  {'symbol': 'BANDUSDT', 'price': '3.32100000'},
#  {'symbol': 'BNBBUSD', 'price': '361.50000000'},
#  {'symbol': 'BTCBUSD', 'price': '35685.21000000'},
#  {'symbol': 'BUSDUSDT', 'price': '0.99980000'},
#  {'symbol': 'BEAMBNB', 'price': '0.02177000'},
#  {'symbol': 'BEAMBTC', 'price': '0.00000831'},
#  {'symbol': 'BEAMUSDT', 'price': '0.29690000'},
#  {'symbol': 'XTZBNB', 'price': '0.00770000'},
#  {'symbol': 'XTZBTC', 'price': '0.00007792'},
#  {'symbol': 'XTZUSDT', 'price': '2.78000000'},
#  {'symbol': 'RENUSDT', 'price': '0.29810000'},
#  {'symbol': 'RVNUSDT', 'price': '0.06315000'},
#  {'symbol': 'HCUSDT', 'price': '0.84230000'},
#  {'symbol': 'HBARBNB', 'price': '0.00056870'},
#  {'symbol': 'HBARBTC', 'price': '0.00000575'},
#  {'symbol': 'HBARUSDT', 'price': '0.20510000'},
#  {'symbol': 'NKNBNB', 'price': '0.00074700'},
#  {'symbol': 'NKNBTC', 'price': '0.00000537'},
#  {'symbol': 'NKNUSDT', 'price': '0.19120000'},
#  {'symbol': 'XRPBUSD', 'price': '0.59180000'},
#  {'symbol': 'ETHBUSD', 'price': '2333.40000000'},
#  {'symbol': 'BCHABCBUSD', 'price': '220.16000000'},
#  {'symbol': 'LTCBUSD', 'price': '103.50000000'},
#  {'symbol': 'LINKBUSD', 'price': '14.52000000'},
#  {'symbol': 'ETCBUSD', 'price': '23.55000000'},
#  {'symbol': 'STXBNB', 'price': '0.00372400'},
#  {'symbol': 'STXBTC', 'price': '0.00003764'},
#  {'symbol': 'STXUSDT', 'price': '1.34000000'},
#  {'symbol': 'KAVABNB', 'price': '0.00852000'},
#  {'symbol': 'KAVABTC', 'price': '0.00008620'},
#  {'symbol': 'KAVAUSDT', 'price': '3.07500000'},
#  {'symbol': 'BUSDNGN', 'price': '462.64000000'},
#  {'symbol': 'BNBNGN', 'price': '43608.00000000'},
#  {'symbol': 'BTCNGN', 'price': '20989988.00000000'},
#  {'symbol': 'ARPABNB', 'price': '0.00018300'},
#  {'symbol': 'ARPABTC', 'price': '0.00000186'},
#  {'symbol': 'ARPAUSDT', 'price': '0.06614000'},
#  {'symbol': 'TRXBUSD', 'price': '0.05521000'},
#  {'symbol': 'EOSBUSD', 'price': '2.13900000'},
#  {'symbol': 'IOTXUSDT', 'price': '0.07135000'},
#  {'symbol': 'RLCUSDT', 'price': '1.76800000'},
#  {'symbol': 'MCOUSDT', 'price': '2.74400000'},
#  {'symbol': 'XLMBUSD', 'price': '0.18880000'},
#  {'symbol': 'ADABUSD', 'price': '1.01100000'},
#  {'symbol': 'CTXCBNB', 'price': '0.00412200'},
#  {'symbol': 'CTXCBTC', 'price': '0.00000766'},
#  {'symbol': 'CTXCUSDT', 'price': '0.27410000'},
#  {'symbol': 'BCHBNB', 'price': '0.77600000'},
#  {'symbol': 'BCHBTC', 'price': '0.00787000'},
#  {'symbol': 'BCHUSDT', 'price': '280.60000000'},
#  {'symbol': 'BCHUSDC', 'price': '280.70000000'},
#  {'symbol': 'BCHTUSD', 'price': '630.00000000'},
#  {'symbol': 'BCHPAX', 'price': '617.72000000'},
#  {'symbol': 'BCHBUSD', 'price': '280.60000000'},
#  {'symbol': 'BTCRUB', 'price': '2795269.00000000'},
#  {'symbol': 'ETHRUB', 'price': '182966.10000000'},
#  {'symbol': 'XRPRUB', 'price': '46.44000000'},
#  {'symbol': 'BNBRUB', 'price': '28365.40000000'},
#  {'symbol': 'TROYBNB', 'price': '0.00001622'},
#  {'symbol': 'TROYBTC', 'price': '0.00000018'},
#  {'symbol': 'TROYUSDT', 'price': '0.00586100'},
#  {'symbol': 'BUSDRUB', 'price': '78.28000000'},
#  {'symbol': 'QTUMBUSD', 'price': '5.43900000'},
#  {'symbol': 'VETBUSD', 'price': '0.05040000'},
#  {'symbol': 'VITEBNB', 'price': '0.00070700'},
#  {'symbol': 'VITEBTC', 'price': '0.00000136'},
#  {'symbol': 'VITEUSDT', 'price': '0.04854000'},
#  {'symbol': 'FTTBNB', 'price': '0.10180000'},
#  {'symbol': 'FTTBTC', 'price': '0.00103000'},
#  {'symbol': 'FTTUSDT', 'price': '36.75000000'},
#  {'symbol': 'BTCTRY', 'price': '494330.00000000'},
#  {'symbol': 'BNBTRY', 'price': '5009.00000000'},
#  {'symbol': 'BUSDTRY', 'price': '13.84500000'},
#  {'symbol': 'ETHTRY', 'price': '32341.00000000'},
#  {'symbol': 'XRPTRY', 'price': '8.21400000'},
#  {'symbol': 'USDTTRY', 'price': '13.85000000'},
#  {'symbol': 'USDTRUB', 'price': '78.30000000'},
#  {'symbol': 'BTCEUR', 'price': '32050.95000000'},
#  {'symbol': 'ETHEUR', 'price': '2096.21000000'},
#  {'symbol': 'BNBEUR', 'price': '324.80000000'},
#  {'symbol': 'XRPEUR', 'price': '0.53170000'},
#  {'symbol': 'EURBUSD', 'price': '1.11300000'},
#  {'symbol': 'EURUSDT', 'price': '1.11300000'},
#  {'symbol': 'OGNBNB', 'price': '0.00084100'},
#  {'symbol': 'OGNBTC', 'price': '0.00000852'},
#  {'symbol': 'OGNUSDT', 'price': '0.30390000'},
#  {'symbol': 'DREPBNB', 'price': '0.00009380'},
#  {'symbol': 'DREPBTC', 'price': '0.00001950'},
#  {'symbol': 'DREPUSDT', 'price': '0.69550000'},
#  {'symbol': 'BULLUSDT', 'price': '1370.28000000'},
#  {'symbol': 'BULLBUSD', 'price': '1368.56000000'},
#  {'symbol': 'BEARUSDT', 'price': '11.16000000'},
#  {'symbol': 'BEARBUSD', 'price': '11.14000000'},
#  {'symbol': 'ETHBULLUSDT', 'price': '79.18000000'},
#  {'symbol': 'ETHBULLBUSD', 'price': '78.46000000'},
#  {'symbol': 'ETHBEARUSDT', 'price': '12.20000000'},
#  {'symbol': 'ETHBEARBUSD', 'price': '12.24000000'},
#  {'symbol': 'TCTBNB', 'price': '0.00041860'},
#  {'symbol': 'TCTBTC', 'price': '0.00000052'},
#  {'symbol': 'TCTUSDT', 'price': '0.01866000'},
#  {'symbol': 'WRXBNB', 'price': '0.00213900'},
#  {'symbol': 'WRXBTC', 'price': '0.00002161'},
#  {'symbol': 'WRXUSDT', 'price': '0.77200000'},
#  {'symbol': 'ICXBUSD', 'price': '0.66500000'},
#  {'symbol': 'BTSUSDT', 'price': '0.02310000'},
#  {'symbol': 'BTSBUSD', 'price': '0.01930000'},
#  {'symbol': 'LSKUSDT', 'price': '1.52800000'},
#  {'symbol': 'BNTUSDT', 'price': '2.23500000'},
#  {'symbol': 'BNTBUSD', 'price': '2.22500000'},
#  {'symbol': 'LTOBNB', 'price': '0.00248000'},
#  {'symbol': 'LTOBTC', 'price': '0.00000533'},
#  {'symbol': 'LTOUSDT', 'price': '0.19030000'},
#  {'symbol': 'ATOMBUSD', 'price': '29.23000000'},
#  {'symbol': 'DASHBUSD', 'price': '88.80000000'},
#  {'symbol': 'NEOBUSD', 'price': '17.43000000'},
#  {'symbol': 'WAVESBUSD', 'price': '9.38000000'},
#  {'symbol': 'XTZBUSD', 'price': '2.78300000'},
#  {'symbol': 'EOSBULLUSDT', 'price': '3.85000000'},
#  {'symbol': 'EOSBULLBUSD', 'price': '3.90000000'},
#  {'symbol': 'EOSBEARUSDT', 'price': '30.21000000'},
#  {'symbol': 'EOSBEARBUSD', 'price': '29.81000000'},
#  {'symbol': 'XRPBULLUSDT', 'price': '8.74000000'},
#  {'symbol': 'XRPBULLBUSD', 'price': '8.78000000'},
#  {'symbol': 'XRPBEARUSDT', 'price': '548.55000000'},
#  {'symbol': 'XRPBEARBUSD', 'price': '547.33000000'},
#  {'symbol': 'BATBUSD', 'price': '0.80800000'},
#  {'symbol': 'ENJBUSD', 'price': '1.51600000'},
#  {'symbol': 'NANOBUSD', 'price': '2.22500000'},
#  {'symbol': 'ONTBUSD', 'price': '0.44670000'},
#  {'symbol': 'RVNBUSD', 'price': '0.06329000'},
#  {'symbol': 'STRATBUSD', 'price': '0.49150000'},
#  {'symbol': 'STRATBNB', 'price': '0.01900000'},
#  {'symbol': 'STRATUSDT', 'price': '0.49040000'},
#  {'symbol': 'AIONBUSD', 'price': '0.07210000'},
#  {'symbol': 'AIONUSDT', 'price': '0.08190000'},
#  {'symbol': 'MBLBNB', 'price': '0.00001457'},
#  {'symbol': 'MBLBTC', 'price': '0.00000005'},
#  {'symbol': 'MBLUSDT', 'price': '0.00526700'},
#  {'symbol': 'COTIBNB', 'price': '0.00072760'},
#  {'symbol': 'COTIBTC', 'price': '0.00000737'},
#  {'symbol': 'COTIUSDT', 'price': '0.26280000'},
#  {'symbol': 'ALGOBUSD', 'price': '0.88630000'},
#  {'symbol': 'BTTBUSD', 'price': '0.00277800'},
#  {'symbol': 'TOMOBUSD', 'price': '1.09300000'},
#  {'symbol': 'XMRBUSD', 'price': '140.30000000'},
#  {'symbol': 'ZECBUSD', 'price': '85.20000000'},
#  {'symbol': 'BNBBULLUSDT', 'price': '57.21000000'},
#  {'symbol': 'BNBBULLBUSD', 'price': '58.37000000'},
#  {'symbol': 'BNBBEARUSDT', 'price': '58.61000000'},
#  {'symbol': 'BNBBEARBUSD', 'price': '57.21000000'},
#  {'symbol': 'STPTBNB', 'price': '0.00067000'},
#  {'symbol': 'STPTBTC', 'price': '0.00000186'},
#  {'symbol': 'STPTUSDT', 'price': '0.06617000'},
#  {'symbol': 'BTCZAR', 'price': '857014.00000000'},
#  {'symbol': 'ETHZAR', 'price': '27850.40000000'},
#  {'symbol': 'BNBZAR', 'price': '5000.00000000'},
#  {'symbol': 'USDTZAR', 'price': '14.02300000'},
#  {'symbol': 'BUSDZAR', 'price': '13.88800000'},
#  {'symbol': 'BTCBKRW', 'price': '42029197.00000000'},
#  {'symbol': 'ETHBKRW', 'price': '1277799.00000000'},
#  {'symbol': 'BNBBKRW', 'price': '44687.00000000'},
#  {'symbol': 'WTCUSDT', 'price': '0.47850000'},
#  {'symbol': 'DATABUSD', 'price': '0.07089000'},
#  {'symbol': 'DATAUSDT', 'price': '0.07085000'},
#  {'symbol': 'XZCUSDT', 'price': '4.44600000'},
#  {'symbol': 'SOLBNB', 'price': '0.24010000'},
#  {'symbol': 'SOLBTC', 'price': '0.00243140'},
#  {'symbol': 'SOLUSDT', 'price': '86.72000000'},
#  {'symbol': 'SOLBUSD', 'price': '86.74000000'},
#  {'symbol': 'BTCIDRT', 'price': '693891182.00'},
#  {'symbol': 'BNBIDRT', 'price': '5150801.00'},
#  {'symbol': 'USDTIDRT', 'price': '14242.00'},
#  {'symbol': 'BUSDIDRT', 'price': '14389.00'},
#  {'symbol': 'CTSIBTC', 'price': '0.00001214'},
#  {'symbol': 'CTSIUSDT', 'price': '0.43270000'},
#  {'symbol': 'CTSIBNB', 'price': '0.00119800'},
#  {'symbol': 'CTSIBUSD', 'price': '0.43340000'},
#  {'symbol': 'HIVEBNB', 'price': '0.00429000'},
#  {'symbol': 'HIVEBTC', 'price': '0.00002350'},
#  {'symbol': 'HIVEUSDT', 'price': '0.83860000'},
#  {'symbol': 'CHRBNB', 'price': '0.00135390'},
#  {'symbol': 'CHRBTC', 'price': '0.00001370'},
#  {'symbol': 'CHRUSDT', 'price': '0.48860000'},
#  {'symbol': 'BTCUPUSDT', 'price': '29.29000000'},
#  {'symbol': 'BTCDOWNUSDT', 'price': '0.01980000'},
#  {'symbol': 'GXSUSDT', 'price': '1.33820000'},
#  {'symbol': 'ARDRUSDT', 'price': '0.16520000'},
#  {'symbol': 'ERDBUSD', 'price': '0.01966100'},
#  {'symbol': 'LENDUSDT', 'price': '0.51431000'},
#  {'symbol': 'HBARBUSD', 'price': '0.20540000'},
#  {'symbol': 'MATICBUSD', 'price': '1.52500000'},
#  {'symbol': 'WRXBUSD', 'price': '0.77300000'},
#  {'symbol': 'ZILBUSD', 'price': '0.04258000'},
#  {'symbol': 'MDTBNB', 'price': '0.00073720'},
#  {'symbol': 'MDTBTC', 'price': '0.00000154'},
#  {'symbol': 'MDTUSDT', 'price': '0.05490000'},
#  {'symbol': 'STMXBTC', 'price': '0.00000038'},
#  {'symbol': 'STMXETH', 'price': '0.00000565'},
#  {'symbol': 'STMXUSDT', 'price': '0.01321000'},
#  {'symbol': 'KNCBUSD', 'price': '1.77400000'},
#  {'symbol': 'KNCUSDT', 'price': '1.77100000'},
#  {'symbol': 'REPBUSD', 'price': '13.67300000'},
#  {'symbol': 'REPUSDT', 'price': '12.18000000'},
#  {'symbol': 'LRCBUSD', 'price': '0.94990000'},
#  {'symbol': 'LRCUSDT', 'price': '0.94780000'},
#  {'symbol': 'IQBNB', 'price': '0.00002327'},
#  {'symbol': 'IQBUSD', 'price': '0.00842000'},
#  {'symbol': 'PNTBTC', 'price': '0.00001617'},
#  {'symbol': 'PNTUSDT', 'price': '0.57660000'},
#  {'symbol': 'BTCGBP', 'price': '26680.63000000'},
#  {'symbol': 'ETHGBP', 'price': '1745.72000000'},
#  {'symbol': 'XRPGBP', 'price': '0.44350000'},
#  {'symbol': 'BNBGBP', 'price': '270.30000000'},
#  {'symbol': 'GBPBUSD', 'price': '1.33800000'},
#  {'symbol': 'DGBBTC', 'price': '0.00000058'},
#  {'symbol': 'DGBBUSD', 'price': '0.02088000'},
#  {'symbol': 'BTCUAH', 'price': '1062801.00000000'},
#  {'symbol': 'USDTUAH', 'price': '29.78000000'},
#  {'symbol': 'COMPBTC', 'price': '0.00337000'},
#  {'symbol': 'COMPBNB', 'price': '5.71900000'},
#  {'symbol': 'COMPBUSD', 'price': '120.40000000'},
#  {'symbol': 'COMPUSDT', 'price': '120.30000000'},
#  {'symbol': 'BTCBIDR', 'price': '516192970.00'},
#  {'symbol': 'ETHBIDR', 'price': '33806769.00'},
#  {'symbol': 'BNBBIDR', 'price': '5221417.00'},
#  {'symbol': 'BUSDBIDR', 'price': '14439.00'},
#  {'symbol': 'USDTBIDR', 'price': '14450.00'},
#  {'symbol': 'BKRWUSDT', 'price': '0.00084530'},
#  {'symbol': 'BKRWBUSD', 'price': '0.00084550'},
#  {'symbol': 'SCUSDT', 'price': '0.00926000'},
#  {'symbol': 'ZENUSDT', 'price': '35.43000000'},
#  {'symbol': 'SXPBTC', 'price': '0.00003519'},
#  {'symbol': 'SXPBNB', 'price': '0.00347900'},
#  {'symbol': 'SXPBUSD', 'price': '1.25900000'},
#  {'symbol': 'SNXBTC', 'price': '0.00012340'},
#  {'symbol': 'SNXBNB', 'price': '0.01219000'},
#  {'symbol': 'SNXBUSD', 'price': '4.40900000'},
#  {'symbol': 'SNXUSDT', 'price': '4.40900000'},
#  {'symbol': 'ETHUPUSDT', 'price': '19.09300000'},
#  {'symbol': 'ETHDOWNUSDT', 'price': '1.45880000'},
#  {'symbol': 'ADAUPUSDT', 'price': '14.26700000'},
#  {'symbol': 'ADADOWNUSDT', 'price': '0.00682100'},
#  {'symbol': 'LINKUPUSDT', 'price': '0.16619000'},
#  {'symbol': 'LINKDOWNUSDT', 'price': '0.01557200'},
#  {'symbol': 'VTHOBNB', 'price': '0.00000988'},
#  {'symbol': 'VTHOBUSD', 'price': '0.00071800'},
#  {'symbol': 'VTHOUSDT', 'price': '0.00356700'},
#  {'symbol': 'DCRBUSD', 'price': '16.03500000'},
#  {'symbol': 'DGBUSDT', 'price': '0.02086000'},
#  {'symbol': 'GBPUSDT', 'price': '1.33800000'},
#  {'symbol': 'STORJBUSD', 'price': '1.03340000'},
#  {'symbol': 'SXPUSDT', 'price': '1.25600000'},
#  {'symbol': 'IRISBNB', 'price': '0.00166200'},
#  {'symbol': 'IRISBTC', 'price': '0.00000181'},
#  {'symbol': 'IRISBUSD', 'price': '0.06080000'},
#  {'symbol': 'MKRBNB', 'price': '6.90300000'},
#  {'symbol': 'MKRBTC', 'price': '0.04837000'},
#  {'symbol': 'MKRUSDT', 'price': '1718.00000000'},
#  {'symbol': 'MKRBUSD', 'price': '1724.00000000'},
#  {'symbol': 'DAIBNB', 'price': '0.04876000'},
#  {'symbol': 'DAIBTC', 'price': '0.00008966'},
#  {'symbol': 'DAIUSDT', 'price': '1.01890000'},
#  {'symbol': 'DAIBUSD', 'price': '1.01810000'},
#  {'symbol': 'RUNEBNB', 'price': '0.01058000'},
#  {'symbol': 'RUNEBTC', 'price': '0.00010730'},
#  {'symbol': 'RUNEBUSD', 'price': '3.83400000'},
#  {'symbol': 'MANABUSD', 'price': '2.12690000'},
#  {'symbol': 'DOGEBUSD', 'price': '0.13720000'},
#  {'symbol': 'LENDBUSD', 'price': '0.51530000'},
#  {'symbol': 'ZRXBUSD', 'price': '0.50850000'},
#  {'symbol': 'DCRUSDT', 'price': '58.30000000'},
#  {'symbol': 'STORJUSDT', 'price': '1.02850000'},
#  {'symbol': 'XRPBKRW', 'price': '319.76000000'},
#  {'symbol': 'ADABKRW', 'price': '327.55000000'},
#  {'symbol': 'BTCAUD', 'price': '50807.97000000'},
#  {'symbol': 'ETHAUD', 'price': '3322.45000000'},
#  {'symbol': 'AUDBUSD', 'price': '0.70300000'},
#  {'symbol': 'FIOBNB', 'price': '0.00025410'},
#  {'symbol': 'FIOBTC', 'price': '0.00000258'},
#  {'symbol': 'FIOBUSD', 'price': '0.09200000'},
#  {'symbol': 'BNBUPUSDT', 'price': '185.66000000'},
#  {'symbol': 'BNBDOWNUSDT', 'price': '0.13987000'},
#  {'symbol': 'XTZUPUSDT', 'price': '0.00255100'},
#  {'symbol': 'XTZDOWNUSDT', 'price': '2.60010000'},
#  {'symbol': 'AVABNB', 'price': '0.00296500'},
#  {'symbol': 'AVABTC', 'price': '0.00003002'},
#  {'symbol': 'AVABUSD', 'price': '1.07200000'},
#  {'symbol': 'USDTBKRW', 'price': '1125.00000000'},
#  {'symbol': 'BUSDBKRW', 'price': '1097.18000000'},
#  {'symbol': 'IOTABUSD', 'price': '0.77630000'},
#  {'symbol': 'MANAUSDT', 'price': '2.12740000'},
#  {'symbol': 'XRPAUD', 'price': '0.84270000'},
#  {'symbol': 'BNBAUD', 'price': '515.20000000'},
#  {'symbol': 'AUDUSDT', 'price': '0.70270000'},
#  {'symbol': 'BALBNB', 'price': '0.42580000'},
#  {'symbol': 'BALBTC', 'price': '0.00031700'},
#  {'symbol': 'BALBUSD', 'price': '11.33000000'},
#  {'symbol': 'YFIBNB', 'price': '82.19000000'},
#  {'symbol': 'YFIBTC', 'price': '0.64900000'},
#  {'symbol': 'YFIBUSD', 'price': '23181.34000000'},
#  {'symbol': 'YFIUSDT', 'price': '23152.48000000'},
#  {'symbol': 'BLZBUSD', 'price': '0.07104000'},
#  {'symbol': 'KMDBUSD', 'price': '0.46760000'},
#  {'symbol': 'BALUSDT', 'price': '11.28000000'},
#  {'symbol': 'BLZUSDT', 'price': '0.11680000'},
#  {'symbol': 'IRISUSDT', 'price': '0.06466000'},
#  {'symbol': 'KMDUSDT', 'price': '0.47580000'},
#  {'symbol': 'BTCDAI', 'price': '35728.56000000'},
#  {'symbol': 'ETHDAI', 'price': '2334.54000000'},
#  {'symbol': 'BNBDAI', 'price': '362.00000000'},
#  {'symbol': 'USDTDAI', 'price': '1.00040000'},
#  {'symbol': 'BUSDDAI', 'price': '1.00000000'},
#  {'symbol': 'JSTBNB', 'price': '0.00021850'},
#  {'symbol': 'JSTBTC', 'price': '0.00000112'},
#  {'symbol': 'JSTBUSD', 'price': '0.04019000'},
#  {'symbol': 'JSTUSDT', 'price': '0.04015000'},
#  {'symbol': 'SRMBNB', 'price': '0.00568000'},
#  {'symbol': 'SRMBTC', 'price': '0.00005760'},
#  {'symbol': 'SRMBUSD', 'price': '2.05200000'},
#  {'symbol': 'SRMUSDT', 'price': '2.04800000'},
#  {'symbol': 'ANTBNB', 'price': '0.01372000'},
#  {'symbol': 'ANTBTC', 'price': '0.00014108'},
#  {'symbol': 'ANTBUSD', 'price': '5.04600000'},
#  {'symbol': 'ANTUSDT', 'price': '5.02800000'},
#  {'symbol': 'CRVBNB', 'price': '0.00687000'},
#  {'symbol': 'CRVBTC', 'price': '0.00007605'},
#  {'symbol': 'CRVBUSD', 'price': '2.71400000'},
#  {'symbol': 'CRVUSDT', 'price': '2.71200000'},
#  {'symbol': 'SANDBNB', 'price': '0.00893600'},
#  {'symbol': 'SANDBTC', 'price': '0.00009043'},
#  {'symbol': 'SANDUSDT', 'price': '3.22750000'},
#  {'symbol': 'SANDBUSD', 'price': '3.22920000'},
#  {'symbol': 'OCEANBNB', 'price': '0.00144700'},
#  {'symbol': 'OCEANBTC', 'price': '0.00001463'},
#  {'symbol': 'OCEANBUSD', 'price': '0.52260000'},
#  {'symbol': 'OCEANUSDT', 'price': '0.52200000'},
#  {'symbol': 'NMRBTC', 'price': '0.00077400'},
#  {'symbol': 'NMRBUSD', 'price': '27.59000000'},
#  {'symbol': 'NMRUSDT', 'price': '27.58000000'},
#  {'symbol': 'DOTBNB', 'price': '0.04816000'},
#  {'symbol': 'DOTBTC', 'price': '0.00048810'},
#  {'symbol': 'DOTBUSD', 'price': '17.41000000'},
#  {'symbol': 'DOTUSDT', 'price': '17.41000000'},
#  {'symbol': 'LUNABNB', 'price': '0.15022000'},
#  {'symbol': 'LUNABTC', 'price': '0.00152150'},
#  {'symbol': 'LUNABUSD', 'price': '54.31000000'},
#  {'symbol': 'LUNAUSDT', 'price': '54.30000000'},
#  {'symbol': 'IDEXBTC', 'price': '0.00000340'},
#  {'symbol': 'IDEXBUSD', 'price': '0.12299000'},
#  {'symbol': 'RSRBNB', 'price': '0.00004800'},
#  {'symbol': 'RSRBTC', 'price': '0.00000048'},
#  {'symbol': 'RSRBUSD', 'price': '0.01734000'},
#  {'symbol': 'RSRUSDT', 'price': '0.01730000'},
#  {'symbol': 'PAXGBNB', 'price': '4.98300000'},
#  {'symbol': 'PAXGBTC', 'price': '0.05061000'},
#  {'symbol': 'PAXGBUSD', 'price': '1890.00000000'},
#  {'symbol': 'PAXGUSDT', 'price': '1805.00000000'},
#  {'symbol': 'WNXMBNB', 'price': '0.17350000'},
#  {'symbol': 'WNXMBTC', 'price': '0.00092800'},
#  {'symbol': 'WNXMBUSD', 'price': '22.16500000'},
#  {'symbol': 'WNXMUSDT', 'price': '33.20000000'},
#  {'symbol': 'TRBBNB', 'price': '0.51700000'},
#  {'symbol': 'TRBBTC', 'price': '0.00051100'},
#  {'symbol': 'TRBBUSD', 'price': '18.25000000'},
#  {'symbol': 'TRBUSDT', 'price': '18.24000000'},
#  {'symbol': 'ETHNGN', 'price': '805670.00000000'},
#  {'symbol': 'DOTBIDR', 'price': '252608.00'},
#  {'symbol': 'LINKAUD', 'price': '20.82000000'},
#  {'symbol': 'SXPAUD', 'price': '1.79600000'},
#  {'symbol': 'BZRXBNB', 'price': '0.00514000'},
#  {'symbol': 'BZRXBTC', 'price': '0.00000463'},
#  {'symbol': 'BZRXBUSD', 'price': '0.21640000'},
#  {'symbol': 'BZRXUSDT', 'price': '0.21560000'},
#  {'symbol': 'WBTCBTC', 'price': '1.00030000'},
#  {'symbol': 'WBTCETH', 'price': '15.28000000'},
#  {'symbol': 'SUSHIBNB', 'price': '0.01074000'},
#  {'symbol': 'SUSHIBTC', 'price': '0.00010880'},
#  {'symbol': 'SUSHIBUSD', 'price': '3.88700000'},
#  {'symbol': 'SUSHIUSDT', 'price': '3.88100000'},
#  {'symbol': 'YFIIBNB', 'price': '6.02000000'},
#  {'symbol': 'YFIIBTC', 'price': '0.06030000'},
#  {'symbol': 'YFIIBUSD', 'price': '2156.00000000'},
#  {'symbol': 'YFIIUSDT', 'price': '2151.00000000'},
#  {'symbol': 'KSMBNB', 'price': '0.43600000'},
#  {'symbol': 'KSMBTC', 'price': '0.00441200'},
#  {'symbol': 'KSMBUSD', 'price': '158.00000000'},
#  {'symbol': 'KSMUSDT', 'price': '157.40000000'},
#  {'symbol': 'EGLDBNB', 'price': '0.37900000'},
#  ...]

# %%
df = pd.DataFrame(prices)

# %%
df
# Out:
#        symbol       price
# 0      ETHBTC  0.06541900
# 1      LTCBTC  0.00290100
# 2      BNBBTC  0.01013000
# 3      NEOBTC  0.00048800
# 4     QTUMETH  0.00233600
# ...       ...         ...
# 1914  ACABUSD  1.51600000
# 1915  ACAUSDT  1.51600000
# 1916   ANCBTC  0.00003882
# 1917  ANCBUSD  1.38800000
# 1918  ANCUSDT  1.38800000
#
# [1919 rows x 2 columns]

# %%
df[df.symbol.str.contains("ETH")]
# Out:
#        symbol       price
# 0      ETHBTC  0.06541900
# 4     QTUMETH  0.00233600
# 5      EOSETH  0.00091600
# 6      SNTETH  0.00001960
# 7      BNTETH  0.00095700
# ...       ...         ...
# 1891  OOKIETH  0.00000467
# 1892  ROSEETH  0.00012840
# 1894   UNIETH  0.00427600
# 1895   XTZETH  0.00119500
# 1902   CRVETH  0.00115900
#
# [219 rows x 2 columns]
